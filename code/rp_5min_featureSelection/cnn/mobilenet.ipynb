# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, DepthwiseConv1D, BatchNormalization, ReLU, GlobalAveragePooling1D, Dense
from keras.layers import Conv1D, SeparableConv1D,GlobalAveragePooling1D,Add,concatenate, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\zazaz\AppData\Local\Temp\ipykernel_19380\265848756.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):    
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        
        recall = TP / (Positives+K.epsilon())    
        return recall 
    
    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
        precision = TP / (Pred_Positives+K.epsilon())
        return precision 
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
def depthwise_separable_conv_block(inputs, pointwise_conv_filters, alpha=1, depth_multiplier=1, strides=1, block_id=1):
    """Depthwise separable conv block.
    """
    pointwise_conv_filters = int(pointwise_conv_filters * alpha)

    x = DepthwiseConv1D((3,), padding='same', depth_multiplier=depth_multiplier, strides=strides)(inputs)
    x = BatchNormalization(name='conv_dw_%d_bn' % block_id)(x)
    x = ReLU(6., name='conv_dw_%d_relu' % block_id)(x)

    x = Conv1D(pointwise_conv_filters, (1,), padding='same', use_bias=False, strides=(1,))(x)
    x = BatchNormalization(name='conv_pw_%d_bn' % block_id)(x)
    x = ReLU(6., name='conv_pw_%d_relu' % block_id)(x)

    return x

def MobileNet1D(input_shape, alpha=1, depth_multiplier=1, classes=10):
    """Instantiates the MobileNet architecture.
    """
    inputs = Input(shape=input_shape)

    x = depthwise_separable_conv_block(inputs, 32, alpha, depth_multiplier, strides=2, block_id=1)
    x = depthwise_separable_conv_block(x, 64, alpha, depth_multiplier, strides=1, block_id=2)
    x = depthwise_separable_conv_block(x, 128, alpha, depth_multiplier, strides=2, block_id=3)
    x = depthwise_separable_conv_block(x, 128, alpha, depth_multiplier, strides=1, block_id=4)
    x = depthwise_separable_conv_block(x, 256, alpha, depth_multiplier, strides=2, block_id=5)
    x = depthwise_separable_conv_block(x, 256, alpha, depth_multiplier, strides=1, block_id=6)
    x = depthwise_separable_conv_block(x, 512, alpha, depth_multiplier, strides=2, block_id=7)

    # Add more depthwise separable blocks if needed
    x = GlobalAveragePooling1D()(x)
    x = Dense(256,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu')(x)
    x = Dense(classes,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='softmax')(x)

    model = Model(inputs, x)

    return model


input_shape = (3840,1)
alpha = 1.0
depth_multiplier = 1
classes = 4  # Number of output classes

model = MobileNet1D(input_shape, alpha, depth_multiplier, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3840, 1)]         0
#
#  depthwise_conv1d (Depthwise  (None, 1920, 1)          4
#  Conv1D)
#
#  conv_dw_1_bn (BatchNormaliz  (None, 1920, 1)          4
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 1920, 1)           0
#
#  conv1d (Conv1D)             (None, 1920, 32)          32
#
#  conv_pw_1_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 1920, 32)          0
#
#  depthwise_conv1d_1 (Depthwi  (None, 1920, 32)         128
#  seConv1D)
#
#  conv_dw_2_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 1920, 32)          0
#
#  conv1d_1 (Conv1D)           (None, 1920, 64)          2048
#
#  conv_pw_2_bn (BatchNormaliz  (None, 1920, 64)         256
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 1920, 64)          0
#
#  depthwise_conv1d_2 (Depthwi  (None, 960, 64)          256
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3840, 1)]         0
#
#  depthwise_conv1d (Depthwise  (None, 1920, 1)          4
#  Conv1D)
#
#  conv_dw_1_bn (BatchNormaliz  (None, 1920, 1)          4
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 1920, 1)           0
#
#  conv1d (Conv1D)             (None, 1920, 32)          32
#
#  conv_pw_1_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 1920, 32)          0
#
#  depthwise_conv1d_1 (Depthwi  (None, 1920, 32)         128
#  seConv1D)
#
#  conv_dw_2_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 1920, 32)          0
#
#  conv1d_1 (Conv1D)           (None, 1920, 64)          2048
#
#  conv_pw_2_bn (BatchNormaliz  (None, 1920, 64)         256
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 1920, 64)          0
#
#  depthwise_conv1d_2 (Depthwi  (None, 960, 64)          256
#  seConv1D)
#
#  conv_dw_3_bn (BatchNormaliz  (None, 960, 64)          256
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 960, 64)           0
#
#  conv1d_2 (Conv1D)           (None, 960, 128)          8192
#
#  conv_pw_3_bn (BatchNormaliz  (None, 960, 128)         512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 960, 128)          0
#
#  depthwise_conv1d_3 (Depthwi  (None, 960, 128)         512
#  seConv1D)
#
#  conv_dw_4_bn (BatchNormaliz  (None, 960, 128)         512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 960, 128)          0
#
#  conv1d_3 (Conv1D)           (None, 960, 128)          16384
#
#  conv_pw_4_bn (BatchNormaliz  (None, 960, 128)         512
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 960, 128)          0
#
#  depthwise_conv1d_4 (Depthwi  (None, 480, 128)         512
#  seConv1D)
#
#  conv_dw_5_bn (BatchNormaliz  (None, 480, 128)         512
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 480, 128)          0
#
#  conv1d_4 (Conv1D)           (None, 480, 256)          32768
#
#  conv_pw_5_bn (BatchNormaliz  (None, 480, 256)         1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 480, 256)          0
#
#  depthwise_conv1d_5 (Depthwi  (None, 480, 256)         1024
#  seConv1D)
#
#  conv_dw_6_bn (BatchNormaliz  (None, 480, 256)         1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 480, 256)          0
#
#  conv1d_5 (Conv1D)           (None, 480, 256)          65536
#
#  conv_pw_6_bn (BatchNormaliz  (None, 480, 256)         1024
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 480, 256)          0
#
#  depthwise_conv1d_6 (Depthwi  (None, 240, 256)         1024
#  seConv1D)
#
#  conv_dw_7_bn (BatchNormaliz  (None, 240, 256)         1024
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 240, 256)          0
#
#  conv1d_6 (Conv1D)           (None, 240, 512)          131072
#
#  conv_pw_7_bn (BatchNormaliz  (None, 240, 512)         2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 240, 512)          0
#
#  global_average_pooling1d (G  (None, 512)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 400,812
# Trainable params: 396,330
# Non-trainable params: 4,482
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/mobilenet.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=256,epochs=200,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/200
# 176/176 [==============================] - 47s 258ms/step - loss: 1.9716 - accuracy: 0.5850 - f1: 0.5269 - val_loss: 1.6621 - val_accuracy: 0.5040 - val_f1: 0.0000e+00
# Epoch 2/200
# 176/176 [==============================] - 45s 257ms/step - loss: 0.9055 - accuracy: 0.6763 - f1: 0.6502 - val_loss: 2.0094 - val_accuracy: 0.1319 - val_f1: 0.1307
# Epoch 3/200
# 176/176 [==============================] - 45s 258ms/step - loss: 0.7603 - accuracy: 0.7242 - f1: 0.7099 - val_loss: 2.2292 - val_accuracy: 0.1319 - val_f1: 0.1307
# Epoch 4/200
# 176/176 [==============================] - 45s 258ms/step - loss: 0.6730 - accuracy: 0.7660 - f1: 0.7570 - val_loss: 1.9704 - val_accuracy: 0.2177 - val_f1: 0.2000
# Epoch 5/200
# 176/176 [==============================] - 45s 259ms/step - loss: 0.6155 - accuracy: 0.7934 - f1: 0.7876 - val_loss: 1.3051 - val_accuracy: 0.5137 - val_f1: 0.4886
# Epoch 6/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.5573 - accuracy: 0.8223 - f1: 0.8167 - val_loss: 1.0270 - val_accuracy: 0.6663 - val_f1: 0.6600
# Epoch 7/200
# 176/176 [==============================] - 45s 253ms/step - loss: 0.5132 - accuracy: 0.8413 - f1: 0.8378 - val_loss: 1.4520 - val_accuracy: 0.5219 - val_f1: 0.5071
# Epoch 8/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.4606 - accuracy: 0.8694 - f1: 0.8671 - val_loss: 1.4070 - val_accuracy: 0.6191 - val_f1: 0.6196
# Epoch 9/200
# 176/176 [==============================] - 44s 252ms/step - loss: 0.4278 - accuracy: 0.8821 - f1: 0.8809 - val_loss: 1.2763 - val_accuracy: 0.5681 - val_f1: 0.5601
# Epoch 10/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.3993 - accuracy: 0.8955 - f1: 0.8941 - val_loss: 1.7517 - val_accuracy: 0.5373 - val_f1: 0.5369
# Epoch 11/200
# 176/176 [==============================] - 45s 254ms/step - loss: 0.3714 - accuracy: 0.9080 - f1: 0.9070 - val_loss: 1.3517 - val_accuracy: 0.6693 - val_f1: 0.6713
# Epoch 12/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.3470 - accuracy: 0.9181 - f1: 0.9150 - val_loss: 1.0975 - val_accuracy: 0.6303 - val_f1: 0.6267
# Epoch 13/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.3702 - accuracy: 0.9070 - f1: 0.9062 - val_loss: 1.9157 - val_accuracy: 0.4699 - val_f1: 0.4657
# Epoch 14/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.3087 - accuracy: 0.9345 - f1: 0.9326 - val_loss: 1.9592 - val_accuracy: 0.4560 - val_f1: 0.4505
# Epoch 15/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.3007 - accuracy: 0.9388 - f1: 0.9366 - val_loss: 2.1066 - val_accuracy: 0.4592 - val_f1: 0.4533
# Epoch 16/200
# 176/176 [==============================] - 44s 253ms/step - loss: 0.3099 - accuracy: 0.9322 - f1: 0.9319 - val_loss: 1.5820 - val_accuracy: 0.5122 - val_f1: 0.5091
# Epoch 17/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2649 - accuracy: 0.9515 - f1: 0.9498 - val_loss: 1.3509 - val_accuracy: 0.6576 - val_f1: 0.6592
# Epoch 18/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.2951 - accuracy: 0.9390 - f1: 0.9364 - val_loss: 0.5748 - val_accuracy: 0.8275 - val_f1: 0.8284
# Epoch 19/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2908 - accuracy: 0.9387 - f1: 0.9383 - val_loss: 0.6257 - val_accuracy: 0.8040 - val_f1: 0.8031
# Epoch 20/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2570 - accuracy: 0.9528 - f1: 0.9515 - val_loss: 1.6780 - val_accuracy: 0.5120 - val_f1: 0.5033
# Epoch 21/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.2363 - accuracy: 0.9627 - f1: 0.9600 - val_loss: 1.7292 - val_accuracy: 0.5058 - val_f1: 0.5007
# Epoch 22/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2790 - accuracy: 0.9427 - f1: 0.9415 - val_loss: 1.5548 - val_accuracy: 0.5542 - val_f1: 0.5477
# Epoch 23/200
# 176/176 [==============================] - 45s 253ms/step - loss: 0.2353 - accuracy: 0.9610 - f1: 0.9596 - val_loss: 0.5608 - val_accuracy: 0.8307 - val_f1: 0.8317
# Epoch 24/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2453 - accuracy: 0.9563 - f1: 0.9551 - val_loss: 1.3025 - val_accuracy: 0.6014 - val_f1: 0.5988
# Epoch 25/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.2196 - accuracy: 0.9659 - f1: 0.9639 - val_loss: 0.6098 - val_accuracy: 0.8183 - val_f1: 0.8175
# Epoch 26/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2605 - accuracy: 0.9510 - f1: 0.9507 - val_loss: 0.5799 - val_accuracy: 0.8185 - val_f1: 0.8192
# Epoch 27/200
# 176/176 [==============================] - 44s 248ms/step - loss: 0.1838 - accuracy: 0.9802 - f1: 0.9801 - val_loss: 1.0852 - val_accuracy: 0.7181 - val_f1: 0.7184
# Epoch 28/200
# 176/176 [==============================] - 44s 248ms/step - loss: 0.1719 - accuracy: 0.9839 - f1: 0.9831 - val_loss: 1.0970 - val_accuracy: 0.6781 - val_f1: 0.6767
# Epoch 29/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1920 - accuracy: 0.9764 - f1: 0.9746 - val_loss: 2.2293 - val_accuracy: 0.5813 - val_f1: 0.5808
# Epoch 30/200
# 176/176 [==============================] - 44s 248ms/step - loss: 0.2449 - accuracy: 0.9543 - f1: 0.9532 - val_loss: 0.9574 - val_accuracy: 0.7082 - val_f1: 0.7084
# Epoch 31/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.2358 - accuracy: 0.9574 - f1: 0.9568 - val_loss: 1.2088 - val_accuracy: 0.6817 - val_f1: 0.6803
# Epoch 32/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2025 - accuracy: 0.9709 - f1: 0.9698 - val_loss: 0.7852 - val_accuracy: 0.7492 - val_f1: 0.7450
# Epoch 33/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.2025 - accuracy: 0.9707 - f1: 0.9698 - val_loss: 1.1554 - val_accuracy: 0.6657 - val_f1: 0.6605
# Epoch 34/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1909 - accuracy: 0.9744 - f1: 0.9731 - val_loss: 0.7536 - val_accuracy: 0.7695 - val_f1: 0.7654
# Epoch 35/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.2127 - accuracy: 0.9662 - f1: 0.9636 - val_loss: 1.1517 - val_accuracy: 0.6450 - val_f1: 0.6428
# Epoch 36/200
# 176/176 [==============================] - 44s 252ms/step - loss: 0.2686 - accuracy: 0.9439 - f1: 0.9427 - val_loss: 0.5309 - val_accuracy: 0.8351 - val_f1: 0.8355
# Epoch 37/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1821 - accuracy: 0.9778 - f1: 0.9742 - val_loss: 1.5227 - val_accuracy: 0.5954 - val_f1: 0.5941
# Epoch 38/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.2458 - accuracy: 0.9517 - f1: 0.9505 - val_loss: 0.6752 - val_accuracy: 0.7992 - val_f1: 0.7998
# Epoch 39/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1681 - accuracy: 0.9824 - f1: 0.9820 - val_loss: 0.5948 - val_accuracy: 0.8167 - val_f1: 0.8164
# Epoch 40/200
# 176/176 [==============================] - 45s 254ms/step - loss: 0.1516 - accuracy: 0.9879 - f1: 0.9876 - val_loss: 0.5487 - val_accuracy: 0.8369 - val_f1: 0.8350
# Epoch 41/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1558 - accuracy: 0.9855 - f1: 0.9836 - val_loss: 0.7783 - val_accuracy: 0.7753 - val_f1: 0.7722
# Epoch 42/200
# 176/176 [==============================] - 45s 253ms/step - loss: 0.2059 - accuracy: 0.9652 - f1: 0.9643 - val_loss: 0.5278 - val_accuracy: 0.8404 - val_f1: 0.8412
# Epoch 43/200
# 176/176 [==============================] - 45s 254ms/step - loss: 0.1497 - accuracy: 0.9871 - f1: 0.9867 - val_loss: 0.9606 - val_accuracy: 0.7137 - val_f1: 0.7091
# Epoch 44/200
# 176/176 [==============================] - 45s 256ms/step - loss: 0.1636 - accuracy: 0.9811 - f1: 0.9800 - val_loss: 0.6220 - val_accuracy: 0.8251 - val_f1: 0.8295
# Epoch 45/200
# 176/176 [==============================] - 45s 256ms/step - loss: 0.1827 - accuracy: 0.9738 - f1: 0.9732 - val_loss: 0.3949 - val_accuracy: 0.8906 - val_f1: 0.8907
# Epoch 46/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1603 - accuracy: 0.9827 - f1: 0.9820 - val_loss: 0.6963 - val_accuracy: 0.7956 - val_f1: 0.7972
# Epoch 47/200
# 176/176 [==============================] - 45s 256ms/step - loss: 0.1577 - accuracy: 0.9827 - f1: 0.9826 - val_loss: 0.5018 - val_accuracy: 0.8468 - val_f1: 0.8472
# Epoch 48/200
# 176/176 [==============================] - 45s 258ms/step - loss: 0.1340 - accuracy: 0.9907 - f1: 0.9901 - val_loss: 0.5548 - val_accuracy: 0.8327 - val_f1: 0.8338
# Epoch 49/200
# 176/176 [==============================] - 45s 256ms/step - loss: 0.1672 - accuracy: 0.9791 - f1: 0.9786 - val_loss: 0.7435 - val_accuracy: 0.7610 - val_f1: 0.7612
# Epoch 50/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1511 - accuracy: 0.9858 - f1: 0.9858 - val_loss: 0.3388 - val_accuracy: 0.9159 - val_f1: 0.9155
# Epoch 51/200
# 176/176 [==============================] - 45s 256ms/step - loss: 0.1320 - accuracy: 0.9910 - f1: 0.9907 - val_loss: 0.4309 - val_accuracy: 0.8783 - val_f1: 0.8781
# Epoch 52/200
# 176/176 [==============================] - 45s 257ms/step - loss: 0.1352 - accuracy: 0.9896 - f1: 0.9884 - val_loss: 1.3043 - val_accuracy: 0.6880 - val_f1: 0.6887
# Epoch 53/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.2116 - accuracy: 0.9609 - f1: 0.9605 - val_loss: 0.7527 - val_accuracy: 0.7912 - val_f1: 0.7914
# Epoch 54/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1323 - accuracy: 0.9906 - f1: 0.9898 - val_loss: 0.5712 - val_accuracy: 0.8255 - val_f1: 0.8248
# Epoch 55/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1436 - accuracy: 0.9862 - f1: 0.9854 - val_loss: 0.5466 - val_accuracy: 0.8446 - val_f1: 0.8444
# Epoch 56/200
# 176/176 [==============================] - 45s 256ms/step - loss: 0.1728 - accuracy: 0.9757 - f1: 0.9746 - val_loss: 0.9390 - val_accuracy: 0.7520 - val_f1: 0.7547
# Epoch 57/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1714 - accuracy: 0.9752 - f1: 0.9753 - val_loss: 0.5937 - val_accuracy: 0.8301 - val_f1: 0.8305
# Epoch 58/200
# 176/176 [==============================] - 45s 258ms/step - loss: 0.1312 - accuracy: 0.9903 - f1: 0.9902 - val_loss: 0.4752 - val_accuracy: 0.8560 - val_f1: 0.8532
# Epoch 59/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1143 - accuracy: 0.9946 - f1: 0.9942 - val_loss: 0.4508 - val_accuracy: 0.8719 - val_f1: 0.8688
# Epoch 60/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1551 - accuracy: 0.9812 - f1: 0.9810 - val_loss: 0.6987 - val_accuracy: 0.8116 - val_f1: 0.8135
# Epoch 61/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1328 - accuracy: 0.9888 - f1: 0.9884 - val_loss: 0.4077 - val_accuracy: 0.8849 - val_f1: 0.8870
# Epoch 62/200
# 176/176 [==============================] - 45s 253ms/step - loss: 0.1383 - accuracy: 0.9867 - f1: 0.9847 - val_loss: 0.6823 - val_accuracy: 0.7990 - val_f1: 0.8002
# Epoch 63/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1993 - accuracy: 0.9651 - f1: 0.9649 - val_loss: 0.9165 - val_accuracy: 0.7641 - val_f1: 0.7650
# Epoch 64/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1353 - accuracy: 0.9877 - f1: 0.9863 - val_loss: 0.8998 - val_accuracy: 0.7203 - val_f1: 0.7164
# Epoch 65/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1841 - accuracy: 0.9706 - f1: 0.9704 - val_loss: 0.5672 - val_accuracy: 0.8450 - val_f1: 0.8461
# Epoch 66/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1261 - accuracy: 0.9909 - f1: 0.9889 - val_loss: 0.6272 - val_accuracy: 0.8052 - val_f1: 0.8044
# Epoch 67/200
# 176/176 [==============================] - 44s 252ms/step - loss: 0.1756 - accuracy: 0.9726 - f1: 0.9718 - val_loss: 0.6493 - val_accuracy: 0.8018 - val_f1: 0.8026
# Epoch 68/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1647 - accuracy: 0.9769 - f1: 0.9764 - val_loss: 0.7646 - val_accuracy: 0.7705 - val_f1: 0.7705
# Epoch 69/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1230 - accuracy: 0.9912 - f1: 0.9902 - val_loss: 0.4258 - val_accuracy: 0.8839 - val_f1: 0.8842
# Epoch 70/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1364 - accuracy: 0.9855 - f1: 0.9854 - val_loss: 0.3937 - val_accuracy: 0.8884 - val_f1: 0.8908
# Epoch 71/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1159 - accuracy: 0.9936 - f1: 0.9934 - val_loss: 0.3310 - val_accuracy: 0.9100 - val_f1: 0.9115
# Epoch 72/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1057 - accuracy: 0.9956 - f1: 0.9949 - val_loss: 0.3308 - val_accuracy: 0.9106 - val_f1: 0.9108
# Epoch 73/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1273 - accuracy: 0.9883 - f1: 0.9879 - val_loss: 0.4393 - val_accuracy: 0.8677 - val_f1: 0.8681
# Epoch 74/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1021 - accuracy: 0.9962 - f1: 0.9950 - val_loss: 1.5050 - val_accuracy: 0.6169 - val_f1: 0.6159
# Epoch 75/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1701 - accuracy: 0.9731 - f1: 0.9730 - val_loss: 0.4129 - val_accuracy: 0.8831 - val_f1: 0.8843
# Epoch 76/200
# 176/176 [==============================] - 44s 252ms/step - loss: 0.1299 - accuracy: 0.9877 - f1: 0.9864 - val_loss: 0.5969 - val_accuracy: 0.8289 - val_f1: 0.8301
# Epoch 77/200
# 176/176 [==============================] - 45s 258ms/step - loss: 0.1518 - accuracy: 0.9799 - f1: 0.9800 - val_loss: 0.5299 - val_accuracy: 0.8359 - val_f1: 0.8348
# Epoch 78/200
# 176/176 [==============================] - 45s 255ms/step - loss: 0.1116 - accuracy: 0.9935 - f1: 0.9934 - val_loss: 0.5785 - val_accuracy: 0.8293 - val_f1: 0.8270
# Epoch 79/200
# 176/176 [==============================] - 44s 252ms/step - loss: 0.0984 - accuracy: 0.9970 - f1: 0.9968 - val_loss: 0.4485 - val_accuracy: 0.8685 - val_f1: 0.8688
# Epoch 80/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1117 - accuracy: 0.9930 - f1: 0.9927 - val_loss: 0.3391 - val_accuracy: 0.9124 - val_f1: 0.9118
# Epoch 81/200
# 176/176 [==============================] - 45s 253ms/step - loss: 0.1007 - accuracy: 0.9956 - f1: 0.9956 - val_loss: 0.2945 - val_accuracy: 0.9231 - val_f1: 0.9260
# Epoch 82/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.0986 - accuracy: 0.9962 - f1: 0.9956 - val_loss: 0.4860 - val_accuracy: 0.8504 - val_f1: 0.8485
# Epoch 83/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1508 - accuracy: 0.9792 - f1: 0.9789 - val_loss: 0.7262 - val_accuracy: 0.7859 - val_f1: 0.7896
# Epoch 84/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1646 - accuracy: 0.9744 - f1: 0.9739 - val_loss: 0.6319 - val_accuracy: 0.8131 - val_f1: 0.8154
# Epoch 85/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1154 - accuracy: 0.9912 - f1: 0.9911 - val_loss: 0.5082 - val_accuracy: 0.8418 - val_f1: 0.8385
# Epoch 86/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1103 - accuracy: 0.9930 - f1: 0.9930 - val_loss: 0.5792 - val_accuracy: 0.8261 - val_f1: 0.8255
# Epoch 87/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1059 - accuracy: 0.9941 - f1: 0.9934 - val_loss: 0.8794 - val_accuracy: 0.7388 - val_f1: 0.7377
# Epoch 88/200
# 176/176 [==============================] - 44s 252ms/step - loss: 0.1441 - accuracy: 0.9815 - f1: 0.9799 - val_loss: 0.6154 - val_accuracy: 0.8229 - val_f1: 0.8230
# Epoch 89/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1659 - accuracy: 0.9728 - f1: 0.9724 - val_loss: 0.4643 - val_accuracy: 0.8544 - val_f1: 0.8564
# Epoch 90/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1283 - accuracy: 0.9871 - f1: 0.9858 - val_loss: 0.4957 - val_accuracy: 0.8508 - val_f1: 0.8515
# Epoch 91/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1410 - accuracy: 0.9827 - f1: 0.9820 - val_loss: 0.7641 - val_accuracy: 0.7916 - val_f1: 0.7913
# Epoch 92/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1032 - accuracy: 0.9955 - f1: 0.9948 - val_loss: 0.7245 - val_accuracy: 0.8161 - val_f1: 0.8170
# Epoch 93/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1181 - accuracy: 0.9892 - f1: 0.9883 - val_loss: 0.5078 - val_accuracy: 0.8542 - val_f1: 0.8522
# Epoch 94/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1539 - accuracy: 0.9782 - f1: 0.9772 - val_loss: 0.6213 - val_accuracy: 0.8100 - val_f1: 0.8085
# Epoch 95/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1328 - accuracy: 0.9849 - f1: 0.9845 - val_loss: 0.3580 - val_accuracy: 0.9066 - val_f1: 0.9063
# Epoch 96/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0937 - accuracy: 0.9970 - f1: 0.9962 - val_loss: 0.3704 - val_accuracy: 0.9084 - val_f1: 0.9103
# Epoch 97/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1421 - accuracy: 0.9810 - f1: 0.9809 - val_loss: 0.5689 - val_accuracy: 0.8365 - val_f1: 0.8382
# Epoch 98/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.0918 - accuracy: 0.9973 - f1: 0.9972 - val_loss: 0.2889 - val_accuracy: 0.9301 - val_f1: 0.9311
# Epoch 99/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0891 - accuracy: 0.9977 - f1: 0.9976 - val_loss: 0.2622 - val_accuracy: 0.9373 - val_f1: 0.9380
# Epoch 100/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0877 - accuracy: 0.9978 - f1: 0.9977 - val_loss: 0.3100 - val_accuracy: 0.9155 - val_f1: 0.9165
# Epoch 101/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.0844 - accuracy: 0.9985 - f1: 0.9981 - val_loss: 0.3306 - val_accuracy: 0.9092 - val_f1: 0.9090
# Epoch 102/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.0918 - accuracy: 0.9961 - f1: 0.9956 - val_loss: 0.4432 - val_accuracy: 0.8705 - val_f1: 0.8736
# Epoch 103/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1406 - accuracy: 0.9796 - f1: 0.9794 - val_loss: 0.3891 - val_accuracy: 0.8912 - val_f1: 0.8917
# Epoch 104/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1269 - accuracy: 0.9865 - f1: 0.9860 - val_loss: 0.4643 - val_accuracy: 0.8657 - val_f1: 0.8668
# Epoch 105/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1269 - accuracy: 0.9855 - f1: 0.9855 - val_loss: 0.5089 - val_accuracy: 0.8331 - val_f1: 0.8309
# Epoch 106/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0890 - accuracy: 0.9974 - f1: 0.9974 - val_loss: 0.2846 - val_accuracy: 0.9285 - val_f1: 0.9306
# Epoch 107/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0845 - accuracy: 0.9981 - f1: 0.9981 - val_loss: 0.3283 - val_accuracy: 0.9060 - val_f1: 0.9074
# Epoch 108/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0820 - accuracy: 0.9983 - f1: 0.9980 - val_loss: 0.2959 - val_accuracy: 0.9179 - val_f1: 0.9166
# Epoch 109/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0859 - accuracy: 0.9975 - f1: 0.9975 - val_loss: 0.2723 - val_accuracy: 0.9337 - val_f1: 0.9325
# Epoch 110/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0774 - accuracy: 0.9991 - f1: 0.9988 - val_loss: 0.2627 - val_accuracy: 0.9331 - val_f1: 0.9327
# Epoch 111/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1144 - accuracy: 0.9887 - f1: 0.9884 - val_loss: 1.0834 - val_accuracy: 0.7201 - val_f1: 0.7210
# Epoch 112/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1357 - accuracy: 0.9823 - f1: 0.9792 - val_loss: 1.8341 - val_accuracy: 0.5815 - val_f1: 0.5808
# Epoch 113/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.2198 - accuracy: 0.9528 - f1: 0.9526 - val_loss: 1.2707 - val_accuracy: 0.6994 - val_f1: 0.7000
# Epoch 114/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1112 - accuracy: 0.9913 - f1: 0.9913 - val_loss: 0.2645 - val_accuracy: 0.9351 - val_f1: 0.9364
# Epoch 115/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0989 - accuracy: 0.9943 - f1: 0.9943 - val_loss: 0.3959 - val_accuracy: 0.8835 - val_f1: 0.8842
# Epoch 116/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0815 - accuracy: 0.9988 - f1: 0.9971 - val_loss: 0.2577 - val_accuracy: 0.9323 - val_f1: 0.9318
# Epoch 117/200
# 176/176 [==============================] - 44s 247ms/step - loss: 0.1432 - accuracy: 0.9777 - f1: 0.9779 - val_loss: 0.4047 - val_accuracy: 0.8769 - val_f1: 0.8787
# Epoch 118/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.0926 - accuracy: 0.9954 - f1: 0.9955 - val_loss: 0.3091 - val_accuracy: 0.9137 - val_f1: 0.9130
# Epoch 119/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0810 - accuracy: 0.9986 - f1: 0.9986 - val_loss: 0.2494 - val_accuracy: 0.9357 - val_f1: 0.9365
# Epoch 120/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.0806 - accuracy: 0.9980 - f1: 0.9978 - val_loss: 0.3379 - val_accuracy: 0.9034 - val_f1: 0.9034
# Epoch 121/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0835 - accuracy: 0.9977 - f1: 0.9978 - val_loss: 0.2695 - val_accuracy: 0.9301 - val_f1: 0.9304
# Epoch 122/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0881 - accuracy: 0.9959 - f1: 0.9955 - val_loss: 0.2611 - val_accuracy: 0.9323 - val_f1: 0.9337
# Epoch 123/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.0896 - accuracy: 0.9960 - f1: 0.9955 - val_loss: 0.5848 - val_accuracy: 0.8327 - val_f1: 0.8342
# Epoch 124/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1422 - accuracy: 0.9798 - f1: 0.9795 - val_loss: 0.5294 - val_accuracy: 0.8402 - val_f1: 0.8390
# Epoch 125/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0860 - accuracy: 0.9972 - f1: 0.9972 - val_loss: 0.3314 - val_accuracy: 0.9096 - val_f1: 0.9093
# Epoch 126/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0819 - accuracy: 0.9976 - f1: 0.9977 - val_loss: 0.3442 - val_accuracy: 0.9048 - val_f1: 0.9057
# Epoch 127/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0730 - accuracy: 0.9992 - f1: 0.9986 - val_loss: 0.2908 - val_accuracy: 0.9227 - val_f1: 0.9241
# Epoch 128/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1080 - accuracy: 0.9900 - f1: 0.9898 - val_loss: 0.4736 - val_accuracy: 0.8566 - val_f1: 0.8580
# Epoch 129/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.1189 - accuracy: 0.9869 - f1: 0.9859 - val_loss: 0.8524 - val_accuracy: 0.7504 - val_f1: 0.7505
# Epoch 130/200
# 176/176 [==============================] - 44s 248ms/step - loss: 0.1411 - accuracy: 0.9786 - f1: 0.9775 - val_loss: 0.6271 - val_accuracy: 0.8243 - val_f1: 0.8260
# Epoch 131/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.1328 - accuracy: 0.9837 - f1: 0.9835 - val_loss: 0.6095 - val_accuracy: 0.8102 - val_f1: 0.8098
# Epoch 132/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0879 - accuracy: 0.9969 - f1: 0.9951 - val_loss: 1.0745 - val_accuracy: 0.6831 - val_f1: 0.6801
# Epoch 133/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1664 - accuracy: 0.9716 - f1: 0.9703 - val_loss: 0.7559 - val_accuracy: 0.7817 - val_f1: 0.7826
# Epoch 134/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1124 - accuracy: 0.9896 - f1: 0.9886 - val_loss: 0.5554 - val_accuracy: 0.8402 - val_f1: 0.8383
# Epoch 135/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1413 - accuracy: 0.9783 - f1: 0.9777 - val_loss: 0.3245 - val_accuracy: 0.9110 - val_f1: 0.9126
# Epoch 136/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0989 - accuracy: 0.9942 - f1: 0.9928 - val_loss: 0.3930 - val_accuracy: 0.8924 - val_f1: 0.8931
# Epoch 137/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1110 - accuracy: 0.9898 - f1: 0.9897 - val_loss: 0.3525 - val_accuracy: 0.9026 - val_f1: 0.9033
# Epoch 138/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0795 - accuracy: 0.9985 - f1: 0.9985 - val_loss: 0.2485 - val_accuracy: 0.9380 - val_f1: 0.9391
# Epoch 139/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0755 - accuracy: 0.9986 - f1: 0.9976 - val_loss: 0.3920 - val_accuracy: 0.8898 - val_f1: 0.8887
# Epoch 140/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1021 - accuracy: 0.9914 - f1: 0.9910 - val_loss: 0.3401 - val_accuracy: 0.9008 - val_f1: 0.9003
# Epoch 141/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0913 - accuracy: 0.9946 - f1: 0.9939 - val_loss: 0.6399 - val_accuracy: 0.8155 - val_f1: 0.8159
# Epoch 142/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1175 - accuracy: 0.9878 - f1: 0.9876 - val_loss: 0.3270 - val_accuracy: 0.9096 - val_f1: 0.9104
# Epoch 143/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0853 - accuracy: 0.9967 - f1: 0.9961 - val_loss: 0.3441 - val_accuracy: 0.9100 - val_f1: 0.9116
# Epoch 144/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0950 - accuracy: 0.9933 - f1: 0.9933 - val_loss: 0.4717 - val_accuracy: 0.8616 - val_f1: 0.8622
# Epoch 145/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0781 - accuracy: 0.9979 - f1: 0.9962 - val_loss: 0.8072 - val_accuracy: 0.7456 - val_f1: 0.7455
# Epoch 146/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1366 - accuracy: 0.9787 - f1: 0.9778 - val_loss: 0.6086 - val_accuracy: 0.8133 - val_f1: 0.8154
# Epoch 147/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1164 - accuracy: 0.9875 - f1: 0.9871 - val_loss: 0.7205 - val_accuracy: 0.8008 - val_f1: 0.8007
# Epoch 148/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0981 - accuracy: 0.9932 - f1: 0.9923 - val_loss: 0.3731 - val_accuracy: 0.8902 - val_f1: 0.8912
# Epoch 149/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1060 - accuracy: 0.9907 - f1: 0.9898 - val_loss: 0.3435 - val_accuracy: 0.9086 - val_f1: 0.9090
# Epoch 150/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.1073 - accuracy: 0.9909 - f1: 0.9908 - val_loss: 0.4619 - val_accuracy: 0.8618 - val_f1: 0.8621
# Epoch 151/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0759 - accuracy: 0.9985 - f1: 0.9980 - val_loss: 0.2473 - val_accuracy: 0.9353 - val_f1: 0.9358
# Epoch 152/200
# 176/176 [==============================] - 44s 250ms/step - loss: 0.0890 - accuracy: 0.9951 - f1: 0.9950 - val_loss: 0.2531 - val_accuracy: 0.9317 - val_f1: 0.9325
# Epoch 153/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0718 - accuracy: 0.9990 - f1: 0.9991 - val_loss: 0.2157 - val_accuracy: 0.9484 - val_f1: 0.9491
# Epoch 154/200
# 176/176 [==============================] - 44s 248ms/step - loss: 0.0668 - accuracy: 0.9996 - f1: 0.9990 - val_loss: 1.4646 - val_accuracy: 0.6512 - val_f1: 0.6517
# Epoch 155/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1302 - accuracy: 0.9809 - f1: 0.9804 - val_loss: 0.5252 - val_accuracy: 0.8410 - val_f1: 0.8389
# Epoch 156/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0927 - accuracy: 0.9947 - f1: 0.9941 - val_loss: 0.3968 - val_accuracy: 0.8869 - val_f1: 0.8865
# Epoch 157/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1197 - accuracy: 0.9866 - f1: 0.9859 - val_loss: 0.3054 - val_accuracy: 0.9163 - val_f1: 0.9190
# Epoch 158/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1059 - accuracy: 0.9907 - f1: 0.9900 - val_loss: 0.2843 - val_accuracy: 0.9291 - val_f1: 0.9291
# Epoch 159/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0915 - accuracy: 0.9946 - f1: 0.9939 - val_loss: 0.3283 - val_accuracy: 0.9092 - val_f1: 0.9104
# Epoch 160/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0857 - accuracy: 0.9959 - f1: 0.9950 - val_loss: 0.3402 - val_accuracy: 0.9094 - val_f1: 0.9101
# Epoch 161/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.1002 - accuracy: 0.9917 - f1: 0.9886 - val_loss: 0.3601 - val_accuracy: 0.8962 - val_f1: 0.8982
# Epoch 162/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1602 - accuracy: 0.9718 - f1: 0.9714 - val_loss: 0.3441 - val_accuracy: 0.9014 - val_f1: 0.9018
# Epoch 163/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0859 - accuracy: 0.9965 - f1: 0.9965 - val_loss: 0.3432 - val_accuracy: 0.8986 - val_f1: 0.8997
# Epoch 164/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0739 - accuracy: 0.9987 - f1: 0.9988 - val_loss: 0.2351 - val_accuracy: 0.9424 - val_f1: 0.9431
# Epoch 165/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0688 - accuracy: 0.9995 - f1: 0.9994 - val_loss: 0.2280 - val_accuracy: 0.9420 - val_f1: 0.9432
# Epoch 166/200
# 176/176 [==============================] - 44s 247ms/step - loss: 0.0659 - accuracy: 0.9998 - f1: 0.9995 - val_loss: 0.2159 - val_accuracy: 0.9458 - val_f1: 0.9459
# Epoch 167/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0693 - accuracy: 0.9991 - f1: 0.9988 - val_loss: 0.2271 - val_accuracy: 0.9424 - val_f1: 0.9431
# Epoch 168/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0886 - accuracy: 0.9944 - f1: 0.9942 - val_loss: 0.3471 - val_accuracy: 0.9048 - val_f1: 0.9057
# Epoch 169/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0776 - accuracy: 0.9976 - f1: 0.9975 - val_loss: 0.3167 - val_accuracy: 0.9127 - val_f1: 0.9126
# Epoch 170/200
# 176/176 [==============================] - 43s 244ms/step - loss: 0.0691 - accuracy: 0.9991 - f1: 0.9976 - val_loss: 0.6691 - val_accuracy: 0.7912 - val_f1: 0.7890
# Epoch 171/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1222 - accuracy: 0.9842 - f1: 0.9833 - val_loss: 0.5436 - val_accuracy: 0.8331 - val_f1: 0.8342
# Epoch 172/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1339 - accuracy: 0.9798 - f1: 0.9791 - val_loss: 0.3462 - val_accuracy: 0.9056 - val_f1: 0.9064
# Epoch 173/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0983 - accuracy: 0.9922 - f1: 0.9919 - val_loss: 0.3911 - val_accuracy: 0.8986 - val_f1: 0.8995
# Epoch 174/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0906 - accuracy: 0.9946 - f1: 0.9939 - val_loss: 0.2789 - val_accuracy: 0.9263 - val_f1: 0.9260
# Epoch 175/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0865 - accuracy: 0.9953 - f1: 0.9951 - val_loss: 0.2336 - val_accuracy: 0.9416 - val_f1: 0.9425
# Epoch 176/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0706 - accuracy: 0.9990 - f1: 0.9976 - val_loss: 0.3186 - val_accuracy: 0.9092 - val_f1: 0.9092
# Epoch 177/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1193 - accuracy: 0.9843 - f1: 0.9843 - val_loss: 0.4299 - val_accuracy: 0.8637 - val_f1: 0.8654
# Epoch 178/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0741 - accuracy: 0.9985 - f1: 0.9985 - val_loss: 0.2154 - val_accuracy: 0.9470 - val_f1: 0.9475
# Epoch 179/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0711 - accuracy: 0.9988 - f1: 0.9987 - val_loss: 0.2131 - val_accuracy: 0.9474 - val_f1: 0.9483
# Epoch 180/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0776 - accuracy: 0.9973 - f1: 0.9971 - val_loss: 0.3311 - val_accuracy: 0.9143 - val_f1: 0.9141
# Epoch 181/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0716 - accuracy: 0.9985 - f1: 0.9974 - val_loss: 1.2637 - val_accuracy: 0.7030 - val_f1: 0.7025
# Epoch 182/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1098 - accuracy: 0.9877 - f1: 0.9876 - val_loss: 0.3200 - val_accuracy: 0.9092 - val_f1: 0.9101
# Epoch 183/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0798 - accuracy: 0.9969 - f1: 0.9968 - val_loss: 0.3216 - val_accuracy: 0.9139 - val_f1: 0.9141
# Epoch 184/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0705 - accuracy: 0.9984 - f1: 0.9981 - val_loss: 0.3717 - val_accuracy: 0.8948 - val_f1: 0.8974
# Epoch 185/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0760 - accuracy: 0.9973 - f1: 0.9962 - val_loss: 0.2985 - val_accuracy: 0.9155 - val_f1: 0.9169
# Epoch 186/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1194 - accuracy: 0.9840 - f1: 0.9839 - val_loss: 0.3698 - val_accuracy: 0.8928 - val_f1: 0.8933
# Epoch 187/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0741 - accuracy: 0.9984 - f1: 0.9969 - val_loss: 0.2896 - val_accuracy: 0.9199 - val_f1: 0.9201
# Epoch 188/200
# 176/176 [==============================] - 1201s 7s/step - loss: 0.1303 - accuracy: 0.9822 - f1: 0.9814 - val_loss: 0.3809 - val_accuracy: 0.8906 - val_f1: 0.8896
# Epoch 189/200
# 176/176 [==============================] - 43s 244ms/step - loss: 0.1089 - accuracy: 0.9890 - f1: 0.9878 - val_loss: 0.4874 - val_accuracy: 0.8574 - val_f1: 0.8568
# Epoch 190/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.1189 - accuracy: 0.9854 - f1: 0.9851 - val_loss: 0.3046 - val_accuracy: 0.9167 - val_f1: 0.9187
# Epoch 191/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.0864 - accuracy: 0.9950 - f1: 0.9944 - val_loss: 0.3029 - val_accuracy: 0.9177 - val_f1: 0.9192
# Epoch 192/200
# 176/176 [==============================] - 44s 248ms/step - loss: 0.0882 - accuracy: 0.9940 - f1: 0.9938 - val_loss: 0.3903 - val_accuracy: 0.8843 - val_f1: 0.8855
# Epoch 193/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0772 - accuracy: 0.9974 - f1: 0.9974 - val_loss: 0.4158 - val_accuracy: 0.8831 - val_f1: 0.8816
# Epoch 194/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0713 - accuracy: 0.9984 - f1: 0.9983 - val_loss: 0.2422 - val_accuracy: 0.9404 - val_f1: 0.9407
# Epoch 195/200
# 176/176 [==============================] - 44s 249ms/step - loss: 0.0694 - accuracy: 0.9988 - f1: 0.9988 - val_loss: 0.2281 - val_accuracy: 0.9428 - val_f1: 0.9432
# Epoch 196/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.0623 - accuracy: 0.9996 - f1: 0.9993 - val_loss: 0.2782 - val_accuracy: 0.9265 - val_f1: 0.9284
# Epoch 197/200
# 176/176 [==============================] - 43s 247ms/step - loss: 0.0824 - accuracy: 0.9952 - f1: 0.9949 - val_loss: 0.4917 - val_accuracy: 0.8466 - val_f1: 0.8461
# Epoch 198/200
# 176/176 [==============================] - 43s 245ms/step - loss: 0.0906 - accuracy: 0.9932 - f1: 0.9930 - val_loss: 0.5291 - val_accuracy: 0.8526 - val_f1: 0.8495
# Epoch 199/200
# 176/176 [==============================] - 43s 246ms/step - loss: 0.0692 - accuracy: 0.9989 - f1: 0.9975 - val_loss: 0.3949 - val_accuracy: 0.8821 - val_f1: 0.8833
# Epoch 200/200
# 176/176 [==============================] - 44s 251ms/step - loss: 0.1083 - accuracy: 0.9873 - f1: 0.9872 - val_loss: 0.3012 - val_accuracy: 0.9175 - val_f1: 0.9181

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/mobilenet.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=256)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 49/49 [==============================] - 2s 49ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.92      0.88      0.90      2810
#          REM       0.87      0.95      0.91      1809
#        LIGHT       0.93      0.93      0.93      6233
#         DEEP       0.93      0.88      0.91      1598
#
#     accuracy                           0.92     12450
#    macro avg       0.91      0.91      0.91     12450
# weighted avg       0.92      0.92      0.92     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()
