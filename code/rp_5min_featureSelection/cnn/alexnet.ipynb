# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from tensorflow.keras.models import Model
from keras.layers import Conv1D, SeparableConv1D,GlobalAveragePooling1D,Add, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):    
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        
        recall = TP / (Positives+K.epsilon())    
        return recall 
    
    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
        precision = TP / (Pred_Positives+K.epsilon())
        return precision 
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
def create_1d_alexnet(input_shape, num_classes):
    model = Sequential()
    model.add(BatchNormalization(input_shape=input_shape))
    # First convolutional layer
    model.add(Conv1D(filters=96, kernel_size=11, strides=4, padding='valid', activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=3, strides=2))

    # Second convolutional layer
    model.add(Conv1D(filters=256, kernel_size=5, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2))

    # Third convolutional layer
    model.add(Conv1D(filters=384, kernel_size=3, padding='same', activation='relu'))

    # Fourth convolutional layer
    model.add(Conv1D(filters=384, kernel_size=3, padding='same', activation='relu'))

    # Fifth convolutional layer
    model.add(Conv1D(filters=256, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2))

    # Flatten layer
    model.add(Flatten())

    # Fully connected layers
    model.add(Dense(4096, activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dropout(0.25))
    model.add(Dense(4096, activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dropout(0.25))
    model.add(Dense(num_classes, activation='softmax',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))

    return model


input_shape = (3840,1)
num_classes = 4 
model = create_1d_alexnet(input_shape, num_classes)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_1 (Batc  (None, 3840, 1)          4
#  hNormalization)
#
#  conv1d_5 (Conv1D)           (None, 958, 96)           1152
#
#  max_pooling1d_3 (MaxPooling  (None, 478, 96)          0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 478, 256)          123136
#
#  max_pooling1d_4 (MaxPooling  (None, 238, 256)         0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 238, 384)          295296
#
#  conv1d_8 (Conv1D)           (None, 238, 384)          442752
#
#  conv1d_9 (Conv1D)           (None, 238, 256)          295168
#
#  max_pooling1d_5 (MaxPooling  (None, 118, 256)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 30208)             0
#
#  dense_3 (Dense)             (None, 4096)              123736064
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 141,691,272
# Trainable params: 141,691,270
# Non-trainable params: 2
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/alexnet.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=256,epochs=100,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 24s 132ms/step - loss: 7.1013 - accuracy: 0.4947 - f1: 0.2457 - val_loss: 1.3273 - val_accuracy: 0.5040 - val_f1: 0.0000e+00
# Epoch 2/100
# 176/176 [==============================] - 22s 127ms/step - loss: 1.2709 - accuracy: 0.5026 - f1: 0.2915 - val_loss: 1.2581 - val_accuracy: 0.5163 - val_f1: 0.4626
# Epoch 3/100
# 176/176 [==============================] - 22s 123ms/step - loss: 1.2384 - accuracy: 0.5194 - f1: 0.3766 - val_loss: 1.2257 - val_accuracy: 0.5331 - val_f1: 0.4404
# Epoch 4/100
# 176/176 [==============================] - 21s 120ms/step - loss: 1.2124 - accuracy: 0.5407 - f1: 0.4315 - val_loss: 1.2298 - val_accuracy: 0.5554 - val_f1: 0.5563
# Epoch 5/100
# 176/176 [==============================] - 21s 121ms/step - loss: 1.1715 - accuracy: 0.5585 - f1: 0.4771 - val_loss: 1.2052 - val_accuracy: 0.5600 - val_f1: 0.5224
# Epoch 6/100
# 176/176 [==============================] - 21s 120ms/step - loss: 1.1243 - accuracy: 0.5742 - f1: 0.5168 - val_loss: 1.5797 - val_accuracy: 0.3855 - val_f1: 0.3542
# Epoch 7/100
# 176/176 [==============================] - 21s 120ms/step - loss: 1.1445 - accuracy: 0.5712 - f1: 0.5005 - val_loss: 1.1054 - val_accuracy: 0.5940 - val_f1: 0.4847
# Epoch 8/100
# 176/176 [==============================] - 21s 120ms/step - loss: 1.0667 - accuracy: 0.6047 - f1: 0.5474 - val_loss: 1.0881 - val_accuracy: 0.6082 - val_f1: 0.4055
# Epoch 9/100
# 176/176 [==============================] - 21s 119ms/step - loss: 1.0519 - accuracy: 0.6303 - f1: 0.5698 - val_loss: 1.3793 - val_accuracy: 0.4255 - val_f1: 0.3526
# Epoch 10/100
# 176/176 [==============================] - 21s 120ms/step - loss: 1.0275 - accuracy: 0.6545 - f1: 0.6180 - val_loss: 1.1008 - val_accuracy: 0.6145 - val_f1: 0.6111
# Epoch 11/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.9677 - accuracy: 0.6805 - f1: 0.6557 - val_loss: 0.9832 - val_accuracy: 0.6653 - val_f1: 0.6409
# Epoch 12/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.9171 - accuracy: 0.7018 - f1: 0.6837 - val_loss: 0.9693 - val_accuracy: 0.6737 - val_f1: 0.6513
# Epoch 13/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.8829 - accuracy: 0.7205 - f1: 0.7051 - val_loss: 0.9856 - val_accuracy: 0.6476 - val_f1: 0.6264
# Epoch 14/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.8442 - accuracy: 0.7370 - f1: 0.7260 - val_loss: 1.0361 - val_accuracy: 0.6388 - val_f1: 0.6314
# Epoch 15/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.8237 - accuracy: 0.7479 - f1: 0.7393 - val_loss: 0.8626 - val_accuracy: 0.7373 - val_f1: 0.7351
# Epoch 16/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.7827 - accuracy: 0.7607 - f1: 0.7537 - val_loss: 0.8477 - val_accuracy: 0.7382 - val_f1: 0.7329
# Epoch 17/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.7803 - accuracy: 0.7687 - f1: 0.7633 - val_loss: 0.7603 - val_accuracy: 0.7681 - val_f1: 0.7709
# Epoch 18/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.7342 - accuracy: 0.7815 - f1: 0.7754 - val_loss: 0.7620 - val_accuracy: 0.7705 - val_f1: 0.7672
# Epoch 19/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.7410 - accuracy: 0.7835 - f1: 0.7779 - val_loss: 0.7896 - val_accuracy: 0.7661 - val_f1: 0.7658
# Epoch 20/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.7035 - accuracy: 0.7972 - f1: 0.7931 - val_loss: 0.9313 - val_accuracy: 0.6837 - val_f1: 0.6648
# Epoch 21/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.6854 - accuracy: 0.8010 - f1: 0.7980 - val_loss: 0.8974 - val_accuracy: 0.7203 - val_f1: 0.7188
# Epoch 22/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.6641 - accuracy: 0.8146 - f1: 0.8121 - val_loss: 0.8647 - val_accuracy: 0.7319 - val_f1: 0.7303
# Epoch 23/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.6726 - accuracy: 0.8153 - f1: 0.8129 - val_loss: 0.7081 - val_accuracy: 0.7920 - val_f1: 0.7904
# Epoch 24/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.6251 - accuracy: 0.8299 - f1: 0.8278 - val_loss: 0.6634 - val_accuracy: 0.8199 - val_f1: 0.8202
# Epoch 25/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.6159 - accuracy: 0.8374 - f1: 0.8350 - val_loss: 0.7022 - val_accuracy: 0.7990 - val_f1: 0.7986
# Epoch 26/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.5897 - accuracy: 0.8448 - f1: 0.8429 - val_loss: 0.8190 - val_accuracy: 0.7651 - val_f1: 0.7643
# Epoch 27/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.5981 - accuracy: 0.8443 - f1: 0.8412 - val_loss: 0.6619 - val_accuracy: 0.8163 - val_f1: 0.8142
# Epoch 28/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.5752 - accuracy: 0.8575 - f1: 0.8562 - val_loss: 0.6682 - val_accuracy: 0.8205 - val_f1: 0.8179
# Epoch 29/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.5580 - accuracy: 0.8617 - f1: 0.8610 - val_loss: 0.6325 - val_accuracy: 0.8347 - val_f1: 0.8348
# Epoch 30/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.5101 - accuracy: 0.8781 - f1: 0.8780 - val_loss: 0.6682 - val_accuracy: 0.8064 - val_f1: 0.8076
# Epoch 31/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.5129 - accuracy: 0.8860 - f1: 0.8852 - val_loss: 0.6449 - val_accuracy: 0.8295 - val_f1: 0.8306
# Epoch 32/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.4905 - accuracy: 0.8915 - f1: 0.8899 - val_loss: 0.8256 - val_accuracy: 0.7839 - val_f1: 0.7848
# Epoch 33/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.5153 - accuracy: 0.8941 - f1: 0.8944 - val_loss: 0.6408 - val_accuracy: 0.8359 - val_f1: 0.8350
# Epoch 34/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.4716 - accuracy: 0.9036 - f1: 0.9031 - val_loss: 1.3746 - val_accuracy: 0.6667 - val_f1: 0.6610
# Epoch 35/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.4998 - accuracy: 0.9062 - f1: 0.9053 - val_loss: 0.7047 - val_accuracy: 0.8432 - val_f1: 0.8459
# Epoch 36/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.4316 - accuracy: 0.9171 - f1: 0.9167 - val_loss: 0.6497 - val_accuracy: 0.8500 - val_f1: 0.8526
# Epoch 37/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.4163 - accuracy: 0.9211 - f1: 0.9210 - val_loss: 0.7558 - val_accuracy: 0.8157 - val_f1: 0.8191
# Epoch 38/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.4581 - accuracy: 0.9213 - f1: 0.9204 - val_loss: 0.7093 - val_accuracy: 0.8131 - val_f1: 0.8116
# Epoch 39/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3887 - accuracy: 0.9337 - f1: 0.9336 - val_loss: 0.6199 - val_accuracy: 0.8620 - val_f1: 0.8647
# Epoch 40/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3890 - accuracy: 0.9356 - f1: 0.9354 - val_loss: 0.7421 - val_accuracy: 0.8151 - val_f1: 0.8151
# Epoch 41/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3893 - accuracy: 0.9375 - f1: 0.9374 - val_loss: 0.6613 - val_accuracy: 0.8434 - val_f1: 0.8444
# Epoch 42/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.4176 - accuracy: 0.9332 - f1: 0.9321 - val_loss: 0.6831 - val_accuracy: 0.8287 - val_f1: 0.8308
# Epoch 43/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3941 - accuracy: 0.9386 - f1: 0.9376 - val_loss: 1.7692 - val_accuracy: 0.6086 - val_f1: 0.6033
# Epoch 44/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.5427 - accuracy: 0.9264 - f1: 0.9261 - val_loss: 0.6964 - val_accuracy: 0.8534 - val_f1: 0.8542
# Epoch 45/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3332 - accuracy: 0.9530 - f1: 0.9526 - val_loss: 0.6104 - val_accuracy: 0.8735 - val_f1: 0.8753
# Epoch 46/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.3244 - accuracy: 0.9556 - f1: 0.9561 - val_loss: 0.6244 - val_accuracy: 0.8699 - val_f1: 0.8712
# Epoch 47/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2970 - accuracy: 0.9612 - f1: 0.9606 - val_loss: 0.6200 - val_accuracy: 0.8695 - val_f1: 0.8710
# Epoch 48/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.3209 - accuracy: 0.9589 - f1: 0.9584 - val_loss: 0.6612 - val_accuracy: 0.8631 - val_f1: 0.8654
# Epoch 49/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3317 - accuracy: 0.9565 - f1: 0.9564 - val_loss: 0.5365 - val_accuracy: 0.8888 - val_f1: 0.8896
# Epoch 50/100
# 176/176 [==============================] - 21s 121ms/step - loss: 0.3142 - accuracy: 0.9606 - f1: 0.9602 - val_loss: 0.6223 - val_accuracy: 0.8789 - val_f1: 0.8800
# Epoch 51/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.3493 - accuracy: 0.9595 - f1: 0.9593 - val_loss: 0.6438 - val_accuracy: 0.8590 - val_f1: 0.8613
# Epoch 52/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3059 - accuracy: 0.9638 - f1: 0.9635 - val_loss: 0.6404 - val_accuracy: 0.8781 - val_f1: 0.8795
# Epoch 53/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3318 - accuracy: 0.9637 - f1: 0.9639 - val_loss: 0.5349 - val_accuracy: 0.8958 - val_f1: 0.8986
# Epoch 54/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2702 - accuracy: 0.9715 - f1: 0.9709 - val_loss: 0.6285 - val_accuracy: 0.8795 - val_f1: 0.8805
# Epoch 55/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3723 - accuracy: 0.9615 - f1: 0.9612 - val_loss: 0.5522 - val_accuracy: 0.8876 - val_f1: 0.8909
# Epoch 56/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3319 - accuracy: 0.9656 - f1: 0.9657 - val_loss: 0.5310 - val_accuracy: 0.8936 - val_f1: 0.8950
# Epoch 57/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2579 - accuracy: 0.9737 - f1: 0.9739 - val_loss: 0.5537 - val_accuracy: 0.8904 - val_f1: 0.8918
# Epoch 58/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.2525 - accuracy: 0.9763 - f1: 0.9758 - val_loss: 0.6481 - val_accuracy: 0.8614 - val_f1: 0.8602
# Epoch 59/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3614 - accuracy: 0.9640 - f1: 0.9643 - val_loss: 0.6535 - val_accuracy: 0.8807 - val_f1: 0.8821
# Epoch 60/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.2524 - accuracy: 0.9761 - f1: 0.9759 - val_loss: 0.5797 - val_accuracy: 0.8867 - val_f1: 0.8882
# Epoch 61/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3007 - accuracy: 0.9716 - f1: 0.9716 - val_loss: 0.6782 - val_accuracy: 0.8699 - val_f1: 0.8721
# Epoch 62/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3965 - accuracy: 0.9595 - f1: 0.9592 - val_loss: 0.5483 - val_accuracy: 0.8906 - val_f1: 0.8929
# Epoch 63/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2845 - accuracy: 0.9755 - f1: 0.9753 - val_loss: 0.6709 - val_accuracy: 0.8741 - val_f1: 0.8764
# Epoch 64/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2693 - accuracy: 0.9767 - f1: 0.9764 - val_loss: 0.6481 - val_accuracy: 0.8747 - val_f1: 0.8766
# Epoch 65/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3204 - accuracy: 0.9725 - f1: 0.9727 - val_loss: 0.5353 - val_accuracy: 0.8966 - val_f1: 0.8987
# Epoch 66/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2493 - accuracy: 0.9793 - f1: 0.9791 - val_loss: 0.6117 - val_accuracy: 0.8924 - val_f1: 0.8941
# Epoch 67/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2794 - accuracy: 0.9759 - f1: 0.9757 - val_loss: 0.7295 - val_accuracy: 0.8482 - val_f1: 0.8499
# Epoch 68/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.3567 - accuracy: 0.9655 - f1: 0.9654 - val_loss: 0.6763 - val_accuracy: 0.8578 - val_f1: 0.8603
# Epoch 69/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.4221 - accuracy: 0.9644 - f1: 0.9642 - val_loss: 0.5243 - val_accuracy: 0.9116 - val_f1: 0.9115
# Epoch 70/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.1829 - accuracy: 0.9864 - f1: 0.9866 - val_loss: 0.5204 - val_accuracy: 0.9018 - val_f1: 0.9029
# Epoch 71/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.1982 - accuracy: 0.9839 - f1: 0.9835 - val_loss: 0.5672 - val_accuracy: 0.8952 - val_f1: 0.8962
# Epoch 72/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.2723 - accuracy: 0.9779 - f1: 0.9774 - val_loss: 0.5584 - val_accuracy: 0.9044 - val_f1: 0.9061
# Epoch 73/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3138 - accuracy: 0.9742 - f1: 0.9741 - val_loss: 0.8158 - val_accuracy: 0.8622 - val_f1: 0.8644
# Epoch 74/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3465 - accuracy: 0.9731 - f1: 0.9732 - val_loss: 0.5422 - val_accuracy: 0.9020 - val_f1: 0.9042
# Epoch 75/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2028 - accuracy: 0.9855 - f1: 0.9854 - val_loss: 0.7938 - val_accuracy: 0.8610 - val_f1: 0.8634
# Epoch 76/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.3033 - accuracy: 0.9780 - f1: 0.9782 - val_loss: 0.5502 - val_accuracy: 0.9004 - val_f1: 0.9009
# Epoch 77/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2327 - accuracy: 0.9824 - f1: 0.9823 - val_loss: 0.5285 - val_accuracy: 0.8958 - val_f1: 0.8984
# Epoch 78/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.3133 - accuracy: 0.9783 - f1: 0.9779 - val_loss: 0.8839 - val_accuracy: 0.8267 - val_f1: 0.8294
# Epoch 79/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3704 - accuracy: 0.9724 - f1: 0.9723 - val_loss: 0.6584 - val_accuracy: 0.8745 - val_f1: 0.8755
# Epoch 80/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.3405 - accuracy: 0.9768 - f1: 0.9768 - val_loss: 0.5314 - val_accuracy: 0.9110 - val_f1: 0.9124
# Epoch 81/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2283 - accuracy: 0.9836 - f1: 0.9835 - val_loss: 0.5382 - val_accuracy: 0.9050 - val_f1: 0.9076
# Epoch 82/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.2340 - accuracy: 0.9831 - f1: 0.9830 - val_loss: 0.6010 - val_accuracy: 0.9032 - val_f1: 0.9057
# Epoch 83/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2782 - accuracy: 0.9788 - f1: 0.9786 - val_loss: 0.6259 - val_accuracy: 0.8914 - val_f1: 0.8934
# Epoch 84/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3457 - accuracy: 0.9763 - f1: 0.9764 - val_loss: 0.5743 - val_accuracy: 0.8996 - val_f1: 0.9015
# Epoch 85/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2103 - accuracy: 0.9861 - f1: 0.9854 - val_loss: 1.1612 - val_accuracy: 0.8271 - val_f1: 0.8293
# Epoch 86/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3907 - accuracy: 0.9703 - f1: 0.9706 - val_loss: 0.5942 - val_accuracy: 0.8964 - val_f1: 0.8976
# Epoch 87/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.1618 - accuracy: 0.9901 - f1: 0.9901 - val_loss: 0.4816 - val_accuracy: 0.9129 - val_f1: 0.9150
# Epoch 88/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.1937 - accuracy: 0.9880 - f1: 0.9877 - val_loss: 0.5990 - val_accuracy: 0.8841 - val_f1: 0.8839
# Epoch 89/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2398 - accuracy: 0.9822 - f1: 0.9824 - val_loss: 0.5284 - val_accuracy: 0.9098 - val_f1: 0.9115
# Epoch 90/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2164 - accuracy: 0.9867 - f1: 0.9867 - val_loss: 0.6628 - val_accuracy: 0.8657 - val_f1: 0.8688
# Epoch 91/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3091 - accuracy: 0.9802 - f1: 0.9800 - val_loss: 0.6824 - val_accuracy: 0.8847 - val_f1: 0.8864
# Epoch 92/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.2424 - accuracy: 0.9859 - f1: 0.9856 - val_loss: 0.7348 - val_accuracy: 0.8783 - val_f1: 0.8795
# Epoch 93/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3964 - accuracy: 0.9743 - f1: 0.9746 - val_loss: 0.6839 - val_accuracy: 0.8976 - val_f1: 0.8988
# Epoch 94/100
# 176/176 [==============================] - 21s 118ms/step - loss: 0.2119 - accuracy: 0.9867 - f1: 0.9867 - val_loss: 0.4834 - val_accuracy: 0.9149 - val_f1: 0.9157
# Epoch 95/100
# 176/176 [==============================] - 21s 120ms/step - loss: 0.2198 - accuracy: 0.9867 - f1: 0.9868 - val_loss: 0.5264 - val_accuracy: 0.9088 - val_f1: 0.9103
# Epoch 96/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2043 - accuracy: 0.9875 - f1: 0.9872 - val_loss: 0.7385 - val_accuracy: 0.8629 - val_f1: 0.8646
# Epoch 97/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.3107 - accuracy: 0.9779 - f1: 0.9779 - val_loss: 0.6088 - val_accuracy: 0.9038 - val_f1: 0.9068
# Epoch 98/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2417 - accuracy: 0.9851 - f1: 0.9851 - val_loss: 0.5695 - val_accuracy: 0.9131 - val_f1: 0.9148
# Epoch 99/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.2260 - accuracy: 0.9865 - f1: 0.9863 - val_loss: 0.5736 - val_accuracy: 0.9048 - val_f1: 0.9066
# Epoch 100/100
# 176/176 [==============================] - 21s 119ms/step - loss: 0.5418 - accuracy: 0.9716 - f1: 0.9713 - val_loss: 0.5947 - val_accuracy: 0.9110 - val_f1: 0.9125

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/alexnet.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=256)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 49/49 [==============================] - 1s 28ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.83      0.93      0.88      2810
#          REM       0.93      0.92      0.92      1809
#        LIGHT       0.93      0.90      0.92      6233
#         DEEP       0.93      0.89      0.91      1598
#
#     accuracy                           0.91     12450
#    macro avg       0.91      0.91      0.91     12450
# weighted avg       0.91      0.91      0.91     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()
