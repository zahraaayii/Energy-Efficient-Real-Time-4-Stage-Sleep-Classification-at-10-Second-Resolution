# %%
# !pip install scikit-optimize
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
from sklearnex import patch_sklearn
patch_sklearn()
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition, datasets
from sklearn.pipeline import Pipeline
from skopt import BayesSearchCV
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
np.int = np.int_
import warnings
warnings.filterwarnings("ignore")
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/uxlfoundation/scikit-learn-intelex)

# %%
data_base=[f'ucddb{i:003d}' for i in range(2, 29)]
data_base.remove('ucddb004')
data_base.remove('ucddb016')
print(data_base)
# Out:
# ['ucddb002', 'ucddb003', 'ucddb005', 'ucddb006', 'ucddb007', 'ucddb008', 'ucddb009', 'ucddb010', 'ucddb011', 'ucddb012', 'ucddb013', 'ucddb014', 'ucddb015', 'ucddb017', 'ucddb018', 'ucddb019', 'ucddb020', 'ucddb021', 'ucddb022', 'ucddb023', 'ucddb024', 'ucddb025', 'ucddb026', 'ucddb027', 'ucddb028']

# %%
# df = pd.DataFrame()
# for file in data_base:
#     i=pd.read_csv(base_dir+f'feature/{file}_win.csv')
#     df = pd.concat([df, i], ignore_index=True)
# df.dropna(how='all', axis=1,inplace=True)
# df.to_csv(base_dir+f'all/all_win.csv', index=False)

# %%
data_set = pd.read_csv(base_dir+f'all/all_win.csv')
data_set = data_set.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
data_set
# Out:
#        HRV_MeanNN_x  HRV_SDNN_x  HRV_RMSSD_x  HRV_SDSD_x  HRV_CVNN_x  \
# 0        941.406250   13.877191    10.461470   10.590011    0.014741
# 1        932.963710   19.740977    10.578175   10.598053    0.021159
# 2        784.417230   84.031488    92.695165   94.005934    0.107126
# 3        915.826613   27.783640    20.768127   21.063296    0.030337
# 4        851.562500  115.654429    69.943265   71.024059    0.135814
# ...             ...         ...          ...         ...         ...
# 20399    803.819444   42.248541    22.410536   22.369303    0.052560
# 20400    740.985577   57.787447    17.377094   17.605423    0.077987
# 20401    805.555556   13.043136    11.587810   11.754803    0.016191
# 20402    808.159722   16.004808    10.889563   11.048543    0.019804
# 20403    792.229730   19.527731    10.001492    9.948072    0.024649
#
#        HRV_CVSD_x  HRV_MedianNN_x  HRV_MadNN_x  HRV_MCVNN_x  HRV_IQRNN_x  ...  \
# 0        0.011113       937.50000    11.582812     0.012355    23.437500  ...
# 1        0.011338       937.50000    11.582812     0.012355    15.625000  ...
# 2        0.118171       773.43750    57.914062     0.074879    93.750000  ...
# 3        0.022677       914.06250    23.165625     0.025344    27.343750  ...
# 4        0.082135       878.90625    98.453906     0.112019   146.484375  ...
# ...           ...             ...          ...          ...          ...  ...
# 20399    0.027880       808.59375    28.957031     0.035812    33.203125  ...
# 20400    0.023451       734.37500    69.496875     0.094634    85.937500  ...
# 20401    0.014385       804.68750    11.582812     0.014394    15.625000  ...
# 20402    0.013475       812.50000    23.165625     0.028512    23.437500  ...
# 20403    0.012624       796.87500    23.165625     0.029071    23.437500  ...
#
#        peak_to_peak_y    rmse_y  kurtosis_y  skewness_y  waveform_factor_y  \
# 0            3.426618  0.499383    3.728094   -0.717594           0.220546
# 1            3.426618  0.510929    3.205934   -0.847646           0.219974
# 2            3.426618  0.512045    3.090319   -1.034765           0.213657
# 3            3.409035  0.460080    3.062617   -0.937992           0.185486
# 4            3.409035  0.469791    4.127472   -1.289496           0.184498
# ...               ...       ...         ...         ...                ...
# 20399        0.238339  0.114037   -1.477381    0.240137           0.037104
# 20400        0.238339  0.114434   -1.474395    0.259257           0.037259
# 20401        0.236386  0.113433   -1.441417    0.320433           0.036976
# 20402        0.236386  0.112289   -1.428370    0.317029           0.036602
# 20403        0.238339  0.113477   -1.419373    0.332327           0.036994
#
#        peak_factor_y  impulse_factor_y  margin_factor_y     rms_y  anns
# 0           6.861699          1.513324         2.803092  2.316825     0
# 1           6.706639          1.475284         2.785778  2.378262     0
# 2           6.692021          1.429797         2.764269  2.453831     0
# 3           7.409661          1.374385         2.723429  2.526806     0
# 4           7.256494          1.338809         2.705254  2.589996     0
# ...              ...               ...              ...       ...   ...
# 20399       2.090020          0.077549         0.180015  3.074504     0
# 20400       2.082769          0.077601         0.180046  3.072412     0
# 20401       2.083932          0.077055         0.178622  3.068847     0
# 20402       2.105157          0.077054         0.178621  3.068897     2
# 20403       2.100331          0.077699         0.180102  3.068573     2
#
# [20404 rows x 188 columns]

# %%
# Assuming your target variable is named 'target'
x = data_set.drop('anns', axis=1)  # Features
y = data_set['anns']  # Target variable

# Create the estimator (in this case, LogisticRegression)
estimator = RandomForestClassifier()

# Create the RFE object
rfe = RFE(estimator, n_features_to_select=30, step=3,verbose=10)

# Fit the RFE object to the data
rfe.fit(x, y)

# Get the column names of the selected features
selected_features = x.columns[rfe.support_]

# Create a new DataFrame with the selected features
x = data_set[selected_features]
# Out:
# Fitting estimator with 187 features.
# Fitting estimator with 184 features.
# Fitting estimator with 181 features.
# Fitting estimator with 178 features.
# Fitting estimator with 175 features.
# Fitting estimator with 172 features.
# Fitting estimator with 169 features.
# Fitting estimator with 166 features.
# Fitting estimator with 163 features.
# Fitting estimator with 160 features.
# Fitting estimator with 157 features.
# Fitting estimator with 154 features.
# Fitting estimator with 151 features.
# Fitting estimator with 148 features.
# Fitting estimator with 145 features.
# Fitting estimator with 142 features.
# Fitting estimator with 139 features.
# Fitting estimator with 136 features.
# Fitting estimator with 133 features.
# Fitting estimator with 130 features.
# Fitting estimator with 127 features.
# Fitting estimator with 124 features.
# Fitting estimator with 121 features.
# Fitting estimator with 118 features.
# Fitting estimator with 115 features.
# Fitting estimator with 112 features.
# Fitting estimator with 109 features.
# Fitting estimator with 106 features.
# Fitting estimator with 103 features.
# Fitting estimator with 100 features.
# Fitting estimator with 97 features.
# Fitting estimator with 94 features.
# Fitting estimator with 91 features.
# Fitting estimator with 88 features.
# Fitting estimator with 85 features.
# Fitting estimator with 82 features.
# Fitting estimator with 79 features.
# Fitting estimator with 76 features.
# Fitting estimator with 73 features.
# Fitting estimator with 70 features.
# Fitting estimator with 67 features.
# Fitting estimator with 64 features.
# Fitting estimator with 61 features.
# Fitting estimator with 58 features.
# Fitting estimator with 55 features.
# Fitting estimator with 52 features.
# Fitting estimator with 49 features.
# Fitting estimator with 46 features.
# Fitting estimator with 43 features.
# Fitting estimator with 40 features.
# Fitting estimator with 37 features.
# Fitting estimator with 34 features.
# Fitting estimator with 31 features.

# %%
x
# Out:
#        HRV_MeanNN_x  HRV_Prc20NN_x  HRV_MeanNN_y  HRV_SDANN1_y  HRV_MCVNN_y  \
# 0        941.406250       929.6875    887.054896     55.045392     0.062822
# 1        932.963710       929.6875    890.181903     34.516891     0.062822
# 2        784.417230       750.0000    893.314933     59.306612     0.062294
# 3        915.826613       898.4375    911.847370     38.943009     0.049420
# 4        851.562500       789.0625    913.560780     54.877815     0.036759
# ...             ...            ...           ...           ...          ...
# 20399    803.819444       789.0625    793.849469     14.224312     0.029071
# 20400    740.985577       692.1875    794.921875     16.700587     0.028788
# 20401    805.555556       796.8750    800.289042      6.541426     0.028788
# 20402    808.159722       796.8750    793.662964     18.535262     0.029071
# 20403    792.229730       775.0000    792.390046     14.811247     0.029071
#
#        HRV_pNN20_y  HRV_MinNN_y  HRV_MaxNN_y  HRV_CSI_y  HRV_CSI_Modified_y  \
# 0        32.937685     304.6875    1656.2500   2.135823         1283.142942
# 1        35.223881     304.6875    1656.2500   2.141173         1298.638356
# 2        35.928144     304.6875    1656.2500   2.174932         1341.854801
# 3        32.926829     304.6875    1656.2500   2.104974         1209.650164
# 4        32.110092     304.6875    1656.2500   2.111037         1218.780913
# ...            ...          ...          ...        ...                 ...
# 20399    12.466844     632.8125     882.8125   4.259738          832.470166
# 20400    12.500000     632.8125     882.8125   4.384533          831.505991
# 20401    10.723861     726.5625     882.8125   2.976027          368.869150
# 20402    10.344828     679.6875     882.8125   4.014655          664.841042
# 20403    10.582011     679.6875     882.8125   4.012428          664.539325
#
#        ...     std_y     var_y    rmse_y  kurtosis_y  skewness_y  \
# 0      ...  0.490537  0.240627  0.499383    3.728094   -0.717594
# 1      ...  0.511149  0.261274  0.510929    3.205934   -0.847646
# 2      ...  0.526978  0.277706  0.512045    3.090319   -1.034765
# 3      ...  0.482002  0.232326  0.460080    3.062617   -0.937992
# 4      ...  0.473641  0.224336  0.469791    4.127472   -1.289496
# ...    ...       ...       ...       ...         ...         ...
# 20399  ...  0.081616  0.006661  0.114037   -1.477381    0.240137
# 20400  ...  0.081651  0.006667  0.114434   -1.474395    0.259257
# 20401  ...  0.082016  0.006727  0.113433   -1.441417    0.320433
# 20402  ...  0.081559  0.006652  0.112289   -1.428370    0.317029
# 20403  ...  0.081682  0.006672  0.113477   -1.419373    0.332327
#
#        waveform_factor_y  peak_factor_y  impulse_factor_y  margin_factor_y  \
# 0               0.220546       6.861699          1.513324         2.803092
# 1               0.219974       6.706639          1.475284         2.785778
# 2               0.213657       6.692021          1.429797         2.764269
# 3               0.185486       7.409661          1.374385         2.723429
# 4               0.184498       7.256494          1.338809         2.705254
# ...                  ...            ...               ...              ...
# 20399           0.037104       2.090020          0.077549         0.180015
# 20400           0.037259       2.082769          0.077601         0.180046
# 20401           0.036976       2.083932          0.077055         0.178622
# 20402           0.036602       2.105157          0.077054         0.178621
# 20403           0.036994       2.100331          0.077699         0.180102
#
#           rms_y
# 0      2.316825
# 1      2.378262
# 2      2.453831
# 3      2.526806
# 4      2.589996
# ...         ...
# 20399  3.074504
# 20400  3.072412
# 20401  3.068847
# 20402  3.068897
# 20403  3.068573
#
# [20404 rows x 30 columns]

# %%
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
 per = v / len(y) * 100
 print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=0, n=4405 (21.589%)
# Class=2, n=10347 (50.711%)
# Class=3, n=2661 (13.042%)
# Class=1, n=2991 (14.659%)

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2,stratify=y,random_state=1)

# %%
# model = RandomForestClassifier()
# model.fit(x_train, y_train)
# y_pred= model.predict(x_test)
# print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))

# %%
m = RandomForestClassifier()

param_grid = {
    'n_estimators': [80,100,120,150],  # Number of trees in the forest
    'criterion': ['gini', 'entropy'],  # The function to measure the quality of a split
    'max_depth': [None],  # The maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # The minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # The minimum number of samples required to be at a leaf node
    'bootstrap': [True, False],  # Whether bootstrap samples are used when building trees
}

# %%
clf = BayesSearchCV(m, param_grid,n_iter=50,cv=5,verbose=3,n_jobs=-1,refit=True,scoring='f1_macro')
clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.843 total time=   4.2s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.852 total time=   5.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.843 total time=   5.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.829 total time=   5.9s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.834 total time=   6.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.895 total time=   0.8s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.889 total time=   1.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.875 total time=   1.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.877 total time=   1.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.878 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.882 total time=   1.0s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.890 total time=   0.9s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.880 total time=   0.9s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.877 total time=   0.9s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.869 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.838 total time=   5.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.865 total time=   5.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.852 total time=   7.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.848 total time=   7.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.846 total time=   7.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.870 total time=  11.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.864 total time=  12.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.860 total time=  15.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.879 total time=  16.1s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.865 total time=  17.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=80;, score=0.848 total time=   4.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=80;, score=0.841 total time=   6.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=80;, score=0.859 total time=   6.2s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=80;, score=0.835 total time=   5.7s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=80;, score=0.839 total time=   6.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.843 total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.832 total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.856 total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.843 total time=   0.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.830 total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150;, score=0.867 total time=   1.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150;, score=0.873 total time=   1.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150;, score=0.857 total time=   1.6s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150;, score=0.863 total time=   1.8s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150;, score=0.854 total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.838 total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.858 total time=   0.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.835 total time=   0.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.840 total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.842 total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=0.877 total time=  11.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=0.866 total time=  12.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=0.884 total time=  14.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=0.881 total time=  14.7s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=0.879 total time=  15.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.860 total time=   6.3s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.866 total time=   6.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.874 total time=   6.8s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.866 total time=   8.4s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.857 total time=   9.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.890 total time=   8.7s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.878 total time=  11.1s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.886 total time=  11.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.885 total time=  11.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.879 total time=  12.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=120;, score=0.866 total time=  13.4s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=120;, score=0.885 total time=  13.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=120;, score=0.876 total time=  15.2s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=120;, score=0.874 total time=  15.7s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=120;, score=0.872 total time=  16.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.886 total time=  19.1s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.886 total time=  19.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.873 total time=  20.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.882 total time=  20.2s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.869 total time=  20.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.871 total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.876 total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.881 total time=   1.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.863 total time=   1.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.871 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.848 total time=   1.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.859 total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.842 total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.853 total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.845 total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.858 total time=   1.5s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.860 total time=   1.5s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.863 total time=   1.5s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.876 total time=   1.5s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.857 total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.879 total time=   2.1s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.881 total time=   2.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.891 total time=   2.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.887 total time=   2.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.883 total time=   2.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.858 total time=   8.3s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.839 total time=   8.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.833 total time=   8.9s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.835 total time=   9.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=120;, score=0.830 total time=   9.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.882 total time=  15.9s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.884 total time=  16.8s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.890 total time=  17.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.892 total time=  18.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.879 total time=  19.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.861 total time=   9.8s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.875 total time=  11.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.860 total time=  11.5s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.854 total time=  11.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.865 total time=  12.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.861 total time=   1.9s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.873 total time=   1.9s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.872 total time=   2.0s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.869 total time=   2.0s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.882 total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.861 total time=   1.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.855 total time=   1.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.869 total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.874 total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.864 total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=0.881 total time=  15.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=0.870 total time=  16.7s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=0.872 total time=  17.5s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=0.873 total time=  18.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=0.862 total time=  19.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.861 total time=   1.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.854 total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.865 total time=   2.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.848 total time=   2.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.874 total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.882 total time=  15.8s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.876 total time=  16.3s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.874 total time=  18.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.890 total time=  18.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.887 total time=  19.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.869 total time=   1.9s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.873 total time=   2.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.887 total time=   2.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.878 total time=   2.4s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.884 total time=   2.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.868 total time=  10.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.865 total time=  10.5s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.868 total time=  11.4s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.875 total time=  12.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.883 total time=  12.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=120;, score=0.861 total time=   1.0s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=120;, score=0.880 total time=   1.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=120;, score=0.864 total time=   1.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=120;, score=0.869 total time=   1.4s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=120;, score=0.866 total time=   1.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.876 total time=  10.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.888 total time=  12.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.884 total time=  13.8s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.886 total time=  15.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=0.892 total time=  15.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.869 total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.885 total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.868 total time=   1.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.866 total time=   2.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=0.860 total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.879 total time=   8.5s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.878 total time=  10.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.886 total time=  10.2s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.871 total time=  11.3s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.887 total time=  12.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.881 total time=  12.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.871 total time=  12.8s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.888 total time=  13.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.890 total time=  13.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.875 total time=  15.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.869 total time=  10.7s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.882 total time=  12.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.873 total time=  12.3s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.875 total time=  12.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.865 total time=  13.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.870 total time=   1.1s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.872 total time=   1.5s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.876 total time=   1.7s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.877 total time=   1.8s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.886 total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.872 total time=   1.1s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.886 total time=   1.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.893 total time=   1.4s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.884 total time=   1.5s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.882 total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.879 total time=   1.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.868 total time=   1.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.856 total time=   2.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.862 total time=   2.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.862 total time=   2.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.860 total time=   8.9s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.861 total time=   9.2s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.867 total time=  10.8s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.876 total time=  11.3s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.869 total time=  11.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.862 total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.862 total time=   1.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.874 total time=   1.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.868 total time=   1.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.882 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.882 total time=  15.7s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.883 total time=  16.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.873 total time=  16.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.885 total time=  16.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=0.869 total time=  18.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.839 total time=   6.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.833 total time=   6.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.833 total time=   6.2s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.833 total time=   6.3s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=0.852 total time=   6.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.854 total time=   1.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.862 total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.860 total time=   1.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.854 total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.873 total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.824 total time=   5.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.845 total time=   5.8s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.839 total time=   6.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.832 total time=   6.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=0.829 total time=   6.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.881 total time=   1.1s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.881 total time=   1.1s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.893 total time=   1.1s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.879 total time=   1.2s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.875 total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.847 total time=   7.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.855 total time=   7.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.856 total time=   7.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.868 total time=   7.8s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.864 total time=   7.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.860 total time=   1.5s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.873 total time=   1.6s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.864 total time=   1.6s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.855 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.855 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.828 total time=   4.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.838 total time=   5.4s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.838 total time=   6.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.853 total time=   6.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=80;, score=0.831 total time=   6.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.860 total time=   7.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.879 total time=   8.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.863 total time=   9.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.857 total time=   9.1s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=120;, score=0.868 total time=   9.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.873 total time=   1.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.861 total time=   1.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.871 total time=   2.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.869 total time=   2.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.882 total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.835 total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.845 total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.842 total time=   0.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.839 total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.856 total time=   1.0s
# BayesSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#               scoring='f1_macro',
#               search_spaces={'bootstrap': [True, False],
#                              'criterion': ['gini', 'entropy'],
#                              'max_depth': [None], 'min_samples_leaf': [1, 2, 4],
#                              'min_samples_split': [2, 5, 10],
#                              'n_estimators': [80, 100, 120, 150]},
#               verbose=3)

# %%
print(clf.best_estimator_)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', n_estimators=120)

# %%
y_pred= clf.predict(x_test)
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.88      0.74      0.81       881
#          REM       0.93      0.96      0.95       598
#        LIGHT       0.88      0.94      0.91      2070
#         DEEP       0.94      0.89      0.92       532
#
#     accuracy                           0.90      4081
#    macro avg       0.91      0.88      0.89      4081
# weighted avg       0.90      0.90      0.89      4081

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()
