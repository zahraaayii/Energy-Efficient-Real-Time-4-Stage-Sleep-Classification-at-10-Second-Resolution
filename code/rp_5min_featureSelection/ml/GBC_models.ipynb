# %%
# # !pip install scikit-optimize
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
from sklearnex import patch_sklearn
patch_sklearn()
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition, datasets
from sklearn.pipeline import Pipeline
from skopt import BayesSearchCV
from collections import Counter
from sklearn.preprocessing import LabelEncoder
# from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import RFE
np.int = np.int_
import warnings
warnings.filterwarnings("ignore")
# Out:
# c:\Users\zazaz\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
with open(base_dir+f'feature/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train
# Out:
#        HRV_MeanNN_x  HRV_Prc20NN_x  HRV_MeanNN_y  HRV_SDANN1_y  HRV_CVSD_y  \
# 626     1042.245370       979.6875   1016.342474     28.317425    0.023356
# 19717    748.560855       729.6875    721.542874     29.932062    0.038912
# 4206     615.071615       601.5625    618.430398      5.159246    0.025584
# 1387    1093.750000      1015.6250   1080.474411     33.230741    0.182521
# 12006    823.883929       796.8750    824.132424     12.458836    0.041901
# ...             ...            ...           ...           ...         ...
# 9197     779.560811       765.6250    787.434037     18.071498    0.012054
# 385     1044.849537      1015.6250   1047.998904     19.188980    0.024972
# 10510    703.315549       687.5000    702.665441      8.958925    0.021666
# 9187     822.098214       812.5000    813.479223     25.604744    0.015954
# 9699     930.947581       914.0625    911.204268     17.316130    0.013301
#
#        HRV_MCVNN_y  HRV_SDRMSSD_y  HRV_Prc80NN_y  HRV_pNN20_y  HRV_MinNN_y  \
# 626       0.045270       2.384525      1054.6875    17.006803     859.3750
# 19717     0.047826       1.749449       757.8125    16.183575     546.8750
# 4206      0.037534       1.203803       632.8125    11.983471     570.3125
# 1387      0.120494       0.801258      1203.1250    73.188406     507.8125
# 12006     0.049656       1.392413       859.3750    59.668508     726.5625
# ...            ...            ...            ...          ...          ...
# 9197      0.029071       3.031653       812.5000     2.374670     687.5000
# 385       0.043929       2.036312      1085.9375    39.298246     812.5000
# 10510     0.032947       1.943540       726.5625    16.705882     601.5625
# 9187      0.042360       2.946089       843.7500    12.534060     679.6875
# 9699      0.025129       3.160690       937.5000     9.146341     781.2500
#
#        ...     max_y    mean_y     var_y    rmse_y  skewness_y  \
# 626    ...  3.155067  2.734235  0.067062  0.357530   -0.018707
# 19717  ...  3.125763  2.441649  0.112012  0.354853    0.246204
# 4206   ...  3.237118  3.135209  0.005601  0.109154   -0.353346
# 1387   ...  2.416606  2.044300  0.026530  0.203166   -3.504167
# 12006  ...  2.244689  1.807227  0.041084  0.235958   -0.673158
# ...    ...       ...       ...       ...       ...         ...
# 9197   ...  3.155067  3.073401  0.007034  0.113537   -4.115353
# 385    ...  3.151160  2.289512  0.096654  0.457046    1.593587
# 10510  ...  3.182418  3.106438  0.003348  0.081132   -0.373779
# 9187   ...  3.147253  3.066730  0.007360  0.102715   -6.650320
# 9699   ...  3.153114  3.072974  0.002889  0.075869   -0.184591
#
#        waveform_factor_y  peak_factor_y  impulse_factor_y  margin_factor_y  \
# 626             0.130761       2.666512          0.348674         0.741809
# 19717           0.145333       4.442843          0.645693         1.262691
# 4206            0.034815       2.183521          0.076020         0.179120
# 1387            0.099382       6.836813          0.679456         1.162188
# 12006           0.130564       5.124971          0.669135         1.043840
# ...                  ...            ...               ...              ...
# 9197            0.036942       8.362497          0.308925         0.717115
# 385             0.199626       2.748445          0.548661         1.022277
# 10510           0.026117       2.239385          0.058487         0.136856
# 9187            0.033493      10.118444          0.338900         0.785421
# 9699            0.024689       2.291707          0.056581         0.131324
#
#           rms_y
# 626    2.746471
# 19717  2.464480
# 4206   3.136102
# 1387   2.050778
# 12006  1.818558
# ...         ...
# 9197   3.074546
# 385    2.310524
# 10510  3.106977
# 9187   3.067930
# 9699   3.073444
#
# [16344 rows x 30 columns]

# %%
with open(base_dir+f'feature/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test
# Out:
#        HRV_MeanNN_x  HRV_Prc20NN_x  HRV_MeanNN_y  HRV_SDANN1_y  HRV_CVSD_y  \
# 14127    808.376736       773.4375    798.462567     25.454976    0.033039
# 871      816.517857       762.5000    833.630745     22.535177    0.072862
# 12854    894.775391       859.3750    865.896739     52.977594    0.019567
# 11008    873.342803       859.3750    910.500570     24.758663    0.025720
# 3818     963.020833       935.9375    985.557155     20.062975    0.031956
# ...             ...            ...           ...           ...         ...
# 1793    1086.538462      1078.1250   1089.758212      1.155593    0.015644
# 5640     983.593750       968.7500   1002.621644     29.069919    0.022783
# 14142    805.580357       789.0625    809.006606     15.248255    0.028689
# 2220    1064.236111       985.9375   1079.224955     13.005370    0.102502
# 8572     869.255515       864.0625    783.111093     58.459650    0.096854
#
#        HRV_MCVNN_y  HRV_SDRMSSD_y  HRV_Prc80NN_y  HRV_pNN20_y  HRV_MinNN_y  \
# 14127     0.058717       1.901437       843.7500    36.898396     671.8750
# 871       0.041183       1.000848       867.1875    40.111421     562.5000
# 12854     0.052481       4.036421       921.8750    23.768116     617.1875
# 11008     0.038343       1.766638       937.5000    39.817629     804.6875
# 3818      0.070600       2.387563      1046.8750    43.750000     734.3750
# ...            ...            ...            ...          ...          ...
# 1793      0.010590       1.004784      1101.5625    25.547445    1046.8750
# 5640      0.081080       2.954722      1070.3125    35.234899     843.7500
# 14142     0.043183       1.877992       839.0625    37.669377     710.9375
# 2220      0.042665       0.679491      1132.8125    65.703971     828.1250
# 8572      0.110094       1.280160       867.1875    29.057592     359.3750
#
#        ...     max_y    mean_y     var_y    rmse_y  skewness_y  \
# 14127  ...  3.149206  2.894733  0.081956  0.388872   -1.270611
# 871    ...  3.115995  2.789103  0.117787  0.432447   -0.889477
# 12854  ...  3.219536  3.122720  0.004646  0.100555   -0.320761
# 11008  ...  1.703541  1.398282  0.017265  0.186555    0.067631
# 3818   ...  3.188278  3.083822  0.014400  0.124008   -4.298527
# ...    ...       ...       ...       ...       ...         ...
# 1793   ...  3.192186  3.092353  0.007739  0.125128   -1.042385
# 5640   ...  3.168742  3.090154  0.003206  0.081360   -0.255421
# 14142  ...  3.149206  2.915365  0.073064  0.375290   -1.511429
# 2220   ...  3.117949  2.374280  0.132735  0.328814    0.324849
# 8572   ...  3.157021  2.767851  0.304653  0.631574   -2.302918
#
#        waveform_factor_y  peak_factor_y  impulse_factor_y  margin_factor_y  \
# 14127           0.134338       2.577192          0.346214         0.768842
# 871             0.155049       3.401719          0.527432         1.139474
# 12854           0.032201       2.214824          0.071319         0.167541
# 11008           0.133417       3.162543          0.421938         0.542856
# 3818            0.040212       8.318059          0.334488         0.778472
# ...                  ...            ...               ...              ...
# 1793            0.040464       2.935212          0.118769         0.276977
# 5640            0.026329       2.737331          0.072071         0.167979
# 14142           0.128728       2.889100          0.371908         0.830250
# 2220            0.138490       4.004479          0.554580         1.062295
# 8572            0.228182       6.217391          1.418696         3.050575
#
#           rms_y
# 14127  2.908854
# 871    2.810139
# 12854  3.123464
# 11008  1.404442
# 3818   3.086155
# ...         ...
# 1793   3.093604
# 5640   3.090673
# 14142  2.927869
# 2220   2.402070
# 8572   2.822349
#
# [4086 rows x 30 columns]

# %%
m = GradientBoostingClassifier()
param_grid = {
    'learning_rate':[0.2,0.7],
    'max_depth': [9,12,15],
    'n_estimators': [80,100]

}
clf= BayesSearchCV(m, param_grid,n_iter=20,cv=5,verbose=3,n_jobs=-1,refit=True,scoring='f1_macro')
clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END learning_rate=0.36857013577098185, max_depth=15, n_estimators=98;, score=0.885 total time= 2.8min
# [CV 1/5] END learning_rate=0.36857013577098185, max_depth=15, n_estimators=98;, score=0.875 total time= 2.9min
# [CV 5/5] END learning_rate=0.36857013577098185, max_depth=15, n_estimators=98;, score=0.891 total time= 2.9min
# [CV 4/5] END learning_rate=0.36857013577098185, max_depth=15, n_estimators=98;, score=0.875 total time= 3.0min
# [CV 2/5] END learning_rate=0.36857013577098185, max_depth=15, n_estimators=98;, score=0.872 total time= 3.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END learning_rate=0.32250851296776045, max_depth=12, n_estimators=95;, score=0.874 total time= 3.2min
# [CV 5/5] END learning_rate=0.32250851296776045, max_depth=12, n_estimators=95;, score=0.893 total time= 3.2min
# [CV 1/5] END learning_rate=0.32250851296776045, max_depth=12, n_estimators=95;, score=0.873 total time= 3.2min
# [CV 4/5] END learning_rate=0.32250851296776045, max_depth=12, n_estimators=95;, score=0.872 total time= 3.3min
# [CV 3/5] END learning_rate=0.32250851296776045, max_depth=12, n_estimators=95;, score=0.889 total time= 3.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END learning_rate=0.5456541313837446, max_depth=12, n_estimators=95;, score=0.871 total time= 3.2min
# [CV 4/5] END learning_rate=0.5456541313837446, max_depth=12, n_estimators=95;, score=0.873 total time= 3.2min
# [CV 3/5] END learning_rate=0.5456541313837446, max_depth=12, n_estimators=95;, score=0.886 total time= 3.2min
# [CV 5/5] END learning_rate=0.5456541313837446, max_depth=12, n_estimators=95;, score=0.891 total time= 3.3min
# [CV 2/5] END learning_rate=0.5456541313837446, max_depth=12, n_estimators=95;, score=0.876 total time= 3.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END learning_rate=0.3151694687131536, max_depth=12, n_estimators=83;, score=0.871 total time= 3.0min
# [CV 2/5] END learning_rate=0.3151694687131536, max_depth=12, n_estimators=83;, score=0.867 total time= 3.0min
# [CV 5/5] END learning_rate=0.3151694687131536, max_depth=12, n_estimators=83;, score=0.890 total time= 3.0min
# [CV 3/5] END learning_rate=0.3151694687131536, max_depth=12, n_estimators=83;, score=0.892 total time= 3.0min
# [CV 4/5] END learning_rate=0.3151694687131536, max_depth=12, n_estimators=83;, score=0.874 total time= 3.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END learning_rate=0.3752620765133296, max_depth=9, n_estimators=92;, score=0.877 total time= 2.4min
# [CV 2/5] END learning_rate=0.3752620765133296, max_depth=9, n_estimators=92;, score=0.865 total time= 2.4min
# [CV 4/5] END learning_rate=0.3752620765133296, max_depth=9, n_estimators=92;, score=0.875 total time= 2.6min
# [CV 5/5] END learning_rate=0.3752620765133296, max_depth=9, n_estimators=92;, score=0.882 total time= 2.6min
# [CV 1/5] END learning_rate=0.3752620765133296, max_depth=9, n_estimators=92;, score=0.871 total time= 2.6min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END learning_rate=0.38094240899282134, max_depth=12, n_estimators=84;, score=0.893 total time= 3.0min
# [CV 2/5] END learning_rate=0.38094240899282134, max_depth=12, n_estimators=84;, score=0.867 total time= 3.1min
# [CV 4/5] END learning_rate=0.38094240899282134, max_depth=12, n_estimators=84;, score=0.877 total time= 3.1min
# [CV 1/5] END learning_rate=0.38094240899282134, max_depth=12, n_estimators=84;, score=0.874 total time= 3.2min
# [CV 3/5] END learning_rate=0.38094240899282134, max_depth=12, n_estimators=84;, score=0.885 total time= 3.2min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END learning_rate=0.34889867334422314, max_depth=9, n_estimators=88;, score=0.881 total time= 2.3min
# [CV 2/5] END learning_rate=0.34889867334422314, max_depth=9, n_estimators=88;, score=0.865 total time= 2.4min
# [CV 1/5] END learning_rate=0.34889867334422314, max_depth=9, n_estimators=88;, score=0.869 total time= 2.4min
# [CV 3/5] END learning_rate=0.34889867334422314, max_depth=9, n_estimators=88;, score=0.875 total time= 2.5min
# [CV 4/5] END learning_rate=0.34889867334422314, max_depth=9, n_estimators=88;, score=0.866 total time= 2.5min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END learning_rate=0.3962809668395155, max_depth=15, n_estimators=97;, score=0.877 total time= 3.0min
# [CV 3/5] END learning_rate=0.3962809668395155, max_depth=15, n_estimators=97;, score=0.888 total time= 3.0min
# [CV 1/5] END learning_rate=0.3962809668395155, max_depth=15, n_estimators=97;, score=0.874 total time= 3.0min
# [CV 5/5] END learning_rate=0.3962809668395155, max_depth=15, n_estimators=97;, score=0.894 total time= 3.2min
# [CV 4/5] END learning_rate=0.3962809668395155, max_depth=15, n_estimators=97;, score=0.880 total time= 3.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END learning_rate=0.23158676414516693, max_depth=9, n_estimators=83;, score=0.866 total time= 2.2min
# [CV 1/5] END learning_rate=0.23158676414516693, max_depth=9, n_estimators=83;, score=0.868 total time= 2.2min
# [CV 5/5] END learning_rate=0.23158676414516693, max_depth=9, n_estimators=83;, score=0.882 total time= 2.2min
# [CV 2/5] END learning_rate=0.23158676414516693, max_depth=9, n_estimators=83;, score=0.862 total time= 2.2min
# [CV 3/5] END learning_rate=0.23158676414516693, max_depth=9, n_estimators=83;, score=0.877 total time= 2.4min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END learning_rate=0.6074689887290036, max_depth=9, n_estimators=81;, score=0.876 total time= 2.2min
# [CV 4/5] END learning_rate=0.6074689887290036, max_depth=9, n_estimators=81;, score=0.865 total time= 2.2min
# [CV 5/5] END learning_rate=0.6074689887290036, max_depth=9, n_estimators=81;, score=0.878 total time= 2.3min
# [CV 2/5] END learning_rate=0.6074689887290036, max_depth=9, n_estimators=81;, score=0.859 total time= 2.3min
# [CV 1/5] END learning_rate=0.6074689887290036, max_depth=9, n_estimators=81;, score=0.865 total time= 2.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5] END learning_rate=0.6931419258680809, max_depth=15, n_estimators=100;, score=0.884 total time= 1.7min
# [CV 4/5] END learning_rate=0.6931419258680809, max_depth=15, n_estimators=100;, score=0.874 total time= 1.7min
# [CV 2/5] END learning_rate=0.6931419258680809, max_depth=15, n_estimators=100;, score=0.869 total time= 1.7min
# [CV 3/5] END learning_rate=0.6931419258680809, max_depth=15, n_estimators=100;, score=0.883 total time= 1.7min
# [CV 1/5] END learning_rate=0.6931419258680809, max_depth=15, n_estimators=100;, score=0.874 total time= 1.8min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END learning_rate=0.6947084863964244, max_depth=9, n_estimators=100;, score=0.862 total time= 2.7min
# [CV 2/5] END learning_rate=0.6947084863964244, max_depth=9, n_estimators=100;, score=0.865 total time= 2.8min
# [CV 5/5] END learning_rate=0.6947084863964244, max_depth=9, n_estimators=100;, score=0.883 total time= 2.8min
# [CV 3/5] END learning_rate=0.6947084863964244, max_depth=9, n_estimators=100;, score=0.876 total time= 2.8min
# [CV 1/5] END learning_rate=0.6947084863964244, max_depth=9, n_estimators=100;, score=0.866 total time= 2.9min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END learning_rate=0.20000333023731148, max_depth=15, n_estimators=89;, score=0.874 total time= 4.0min
# [CV 2/5] END learning_rate=0.20000333023731148, max_depth=15, n_estimators=89;, score=0.860 total time= 4.1min
# [CV 5/5] END learning_rate=0.20000333023731148, max_depth=15, n_estimators=89;, score=0.890 total time= 4.1min
# [CV 3/5] END learning_rate=0.20000333023731148, max_depth=15, n_estimators=89;, score=0.883 total time= 4.1min
# [CV 1/5] END learning_rate=0.20000333023731148, max_depth=15, n_estimators=89;, score=0.872 total time= 4.2min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5] END learning_rate=0.45607821945542815, max_depth=15, n_estimators=100;, score=0.884 total time= 2.6min
# [CV 2/5] END learning_rate=0.45607821945542815, max_depth=15, n_estimators=100;, score=0.878 total time= 2.6min
# [CV 4/5] END learning_rate=0.45607821945542815, max_depth=15, n_estimators=100;, score=0.873 total time= 2.6min
# [CV 5/5] END learning_rate=0.45607821945542815, max_depth=15, n_estimators=100;, score=0.894 total time= 2.7min
# [CV 1/5] END learning_rate=0.45607821945542815, max_depth=15, n_estimators=100;, score=0.875 total time= 2.7min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END learning_rate=0.44495750515752797, max_depth=12, n_estimators=100;, score=0.875 total time= 3.5min
# [CV 3/5] END learning_rate=0.44495750515752797, max_depth=12, n_estimators=100;, score=0.890 total time= 3.6min
# [CV 1/5] END learning_rate=0.44495750515752797, max_depth=12, n_estimators=100;, score=0.879 total time= 3.7min
# [CV 2/5] END learning_rate=0.44495750515752797, max_depth=12, n_estimators=100;, score=0.876 total time= 3.8min
# [CV 5/5] END learning_rate=0.44495750515752797, max_depth=12, n_estimators=100;, score=0.892 total time= 3.8min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END learning_rate=0.6958030360304384, max_depth=15, n_estimators=80;, score=0.871 total time= 1.8min
# [CV 3/5] END learning_rate=0.6958030360304384, max_depth=15, n_estimators=80;, score=0.884 total time= 1.9min
# [CV 4/5] END learning_rate=0.6958030360304384, max_depth=15, n_estimators=80;, score=0.877 total time= 2.0min
# [CV 5/5] END learning_rate=0.6958030360304384, max_depth=15, n_estimators=80;, score=0.885 total time= 2.0min
# [CV 2/5] END learning_rate=0.6958030360304384, max_depth=15, n_estimators=80;, score=0.865 total time= 2.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END learning_rate=0.4503352938457638, max_depth=12, n_estimators=100;, score=0.877 total time= 3.3min
# [CV 2/5] END learning_rate=0.4503352938457638, max_depth=12, n_estimators=100;, score=0.879 total time= 3.4min
# [CV 3/5] END learning_rate=0.4503352938457638, max_depth=12, n_estimators=100;, score=0.888 total time= 3.5min
# [CV 5/5] END learning_rate=0.4503352938457638, max_depth=12, n_estimators=100;, score=0.891 total time= 3.5min
# [CV 1/5] END learning_rate=0.4503352938457638, max_depth=12, n_estimators=100;, score=0.877 total time= 3.6min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5] END learning_rate=0.20159482175418253, max_depth=9, n_estimators=100;, score=0.869 total time= 2.7min
# [CV 3/5] END learning_rate=0.20159482175418253, max_depth=9, n_estimators=100;, score=0.871 total time= 2.7min
# [CV 5/5] END learning_rate=0.20159482175418253, max_depth=9, n_estimators=100;, score=0.884 total time= 2.7min
# [CV 1/5] END learning_rate=0.20159482175418253, max_depth=9, n_estimators=100;, score=0.868 total time= 2.7min
# [CV 2/5] END learning_rate=0.20159482175418253, max_depth=9, n_estimators=100;, score=0.862 total time= 2.8min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5] END learning_rate=0.4578353379827114, max_depth=15, n_estimators=80;, score=0.875 total time= 2.5min
# [CV 4/5] END learning_rate=0.4578353379827114, max_depth=15, n_estimators=80;, score=0.876 total time= 2.7min
# [CV 1/5] END learning_rate=0.4578353379827114, max_depth=15, n_estimators=80;, score=0.874 total time= 2.7min
# [CV 5/5] END learning_rate=0.4578353379827114, max_depth=15, n_estimators=80;, score=0.892 total time= 2.7min
# [CV 3/5] END learning_rate=0.4578353379827114, max_depth=15, n_estimators=80;, score=0.879 total time= 2.7min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END learning_rate=0.4347008185168491, max_depth=12, n_estimators=100;, score=0.874 total time= 3.4min
# [CV 2/5] END learning_rate=0.4347008185168491, max_depth=12, n_estimators=100;, score=0.872 total time= 3.4min
# [CV 3/5] END learning_rate=0.4347008185168491, max_depth=12, n_estimators=100;, score=0.886 total time= 3.5min
# [CV 5/5] END learning_rate=0.4347008185168491, max_depth=12, n_estimators=100;, score=0.891 total time= 3.5min
# [CV 4/5] END learning_rate=0.4347008185168491, max_depth=12, n_estimators=100;, score=0.875 total time= 3.6min
# BayesSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_iter=20,
#               n_jobs=-1, scoring='f1_macro',
#               search_spaces={'learning_rate': [0.2, 0.7],
#                              'max_depth': [9, 12, 15],
#                              'n_estimators': [80, 100]},
#               verbose=3)

# %%
print(clf.best_estimator_)
# Out:
# GradientBoostingClassifier(learning_rate=0.4503352938457638, max_depth=12)

# %%
model = GradientBoostingClassifier(learning_rate=0.4503352938457638, max_depth=12)
model.fit(x_train, y_train)
y_pred= model.predict(x_test)
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.88      0.76      0.82       883
#          REM       0.95      0.90      0.93       598
#        LIGHT       0.87      0.95      0.91      2070
#         DEEP       0.95      0.88      0.91       535
#
#     accuracy                           0.89      4086
#    macro avg       0.91      0.87      0.89      4086
# weighted avg       0.89      0.89      0.89      4086

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()
