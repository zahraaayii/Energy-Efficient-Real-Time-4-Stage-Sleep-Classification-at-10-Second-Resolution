# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from keras.layers import Conv1D, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\zazaz\AppData\Local\Temp\ipykernel_23576\430062562.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install QKeras
from qkeras import *
import pprint
from qkeras.autoqkeras import *
from qkeras import *
from qkeras.qtools import run_qtools
from qkeras.qtools import settings as qtools_settings

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))

        recall = TP / (Positives+K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

        precision = TP / (Pred_Positives+K.epsilon())
        return precision
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(3840,1)))
model.add(QConv1D(5, kernel_size=(10),strides=2,kernel_quantizer=quantized_bits(8, 1,alpha=1),  bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(QActivation("quantized_relu(8,1)"))
model.add(MaxPooling1D(pool_size=(2),strides=2))
model.add(QConv1D(45, (10),kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(pool_size=(2),strides=2))
model.add(QActivation("quantized_relu(8,1)"))
model.add(QConv1D(25, (30),kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(pool_size=(4)))
model.add(QActivation("quantized_relu(8,1)"))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dropout(0.25))
model.add(QDense(4,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),activation='softmax',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 3840, 1)          4
#  ormalization)
#
#  q_conv1d (QConv1D)          (None, 1916, 5)           55
#
#  q_activation (QActivation)  (None, 1916, 5)           0
#
#  max_pooling1d (MaxPooling1D  (None, 958, 5)           0
#  )
#
#  q_conv1d_1 (QConv1D)        (None, 949, 45)           2295
#
#  max_pooling1d_1 (MaxPooling  (None, 474, 45)          0
#  1D)
#
#  q_activation_1 (QActivation  (None, 474, 45)          0
#  )
#
#  q_conv1d_2 (QConv1D)        (None, 445, 25)           33775
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 3840, 1)          4
#  ormalization)
#
#  q_conv1d (QConv1D)          (None, 1916, 5)           55
#
#  q_activation (QActivation)  (None, 1916, 5)           0
#
#  max_pooling1d (MaxPooling1D  (None, 958, 5)           0
#  )
#
#  q_conv1d_1 (QConv1D)        (None, 949, 45)           2295
#
#  max_pooling1d_1 (MaxPooling  (None, 474, 45)          0
#  1D)
#
#  q_activation_1 (QActivation  (None, 474, 45)          0
#  )
#
#  q_conv1d_2 (QConv1D)        (None, 445, 25)           33775
#
#  max_pooling1d_2 (MaxPooling  (None, 111, 25)          0
#  1D)
#
#  q_activation_2 (QActivation  (None, 111, 25)          0
#  )
#
#  batch_normalization_1 (Batc  (None, 111, 25)          100
#  hNormalization)
#
#  flatten (Flatten)           (None, 2775)              0
#
#  dropout (Dropout)           (None, 2775)              0
#
#  q_dense (QDense)            (None, 4)                 11104
#
# =================================================================
# Total params: 47,333
# Trainable params: 47,281
# Non-trainable params: 52
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/cnn_fp8.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=256,epochs=600,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/600
# 176/176 [==============================] - 7s 25ms/step - loss: 1.4045 - accuracy: 0.4568 - f1: 0.4017 - val_loss: 1.3529 - val_accuracy: 0.5203 - val_f1: 0.5060
# Epoch 2/600
# 176/176 [==============================] - 3s 19ms/step - loss: 1.0585 - accuracy: 0.5804 - f1: 0.5396 - val_loss: 1.4851 - val_accuracy: 0.3398 - val_f1: 0.3040
# Epoch 3/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.9433 - accuracy: 0.6238 - f1: 0.5919 - val_loss: 1.0463 - val_accuracy: 0.5898 - val_f1: 0.5849
# Epoch 4/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.8714 - accuracy: 0.6544 - f1: 0.6318 - val_loss: 0.9197 - val_accuracy: 0.6456 - val_f1: 0.6210
# Epoch 5/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.8236 - accuracy: 0.6759 - f1: 0.6570 - val_loss: 0.8341 - val_accuracy: 0.6777 - val_f1: 0.6627
# Epoch 6/600
# 176/176 [==============================] - 5s 27ms/step - loss: 0.7868 - accuracy: 0.6925 - f1: 0.6765 - val_loss: 1.3368 - val_accuracy: 0.5978 - val_f1: 0.5992
# Epoch 7/600
# 176/176 [==============================] - 5s 27ms/step - loss: 0.7582 - accuracy: 0.7065 - f1: 0.6921 - val_loss: 0.9362 - val_accuracy: 0.5938 - val_f1: 0.5616
# Epoch 8/600
# 176/176 [==============================] - 5s 31ms/step - loss: 0.7419 - accuracy: 0.7106 - f1: 0.6983 - val_loss: 0.8952 - val_accuracy: 0.6396 - val_f1: 0.6256
# Epoch 9/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.6971 - accuracy: 0.7326 - f1: 0.7221 - val_loss: 0.9639 - val_accuracy: 0.6651 - val_f1: 0.6617
# Epoch 10/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.6770 - accuracy: 0.7418 - f1: 0.7331 - val_loss: 1.2570 - val_accuracy: 0.5882 - val_f1: 0.5881
# Epoch 11/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.6661 - accuracy: 0.7478 - f1: 0.7384 - val_loss: 0.8892 - val_accuracy: 0.6620 - val_f1: 0.6572
# Epoch 12/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.6456 - accuracy: 0.7571 - f1: 0.7500 - val_loss: 1.0738 - val_accuracy: 0.5948 - val_f1: 0.5905
# Epoch 13/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.6261 - accuracy: 0.7652 - f1: 0.7577 - val_loss: 0.9997 - val_accuracy: 0.6169 - val_f1: 0.6079
# Epoch 14/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.6084 - accuracy: 0.7739 - f1: 0.7690 - val_loss: 0.8999 - val_accuracy: 0.6516 - val_f1: 0.6427
# Epoch 15/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.5911 - accuracy: 0.7811 - f1: 0.7746 - val_loss: 0.9540 - val_accuracy: 0.6191 - val_f1: 0.6051
# Epoch 16/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.5768 - accuracy: 0.7885 - f1: 0.7850 - val_loss: 0.6914 - val_accuracy: 0.7394 - val_f1: 0.7305
# Epoch 17/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.5644 - accuracy: 0.7940 - f1: 0.7896 - val_loss: 0.7192 - val_accuracy: 0.7386 - val_f1: 0.7348
# Epoch 18/600
# 176/176 [==============================] - 4s 24ms/step - loss: 0.5458 - accuracy: 0.8035 - f1: 0.7977 - val_loss: 0.8215 - val_accuracy: 0.6896 - val_f1: 0.6828
# Epoch 19/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.5474 - accuracy: 0.8028 - f1: 0.7996 - val_loss: 0.6370 - val_accuracy: 0.7685 - val_f1: 0.7647
# Epoch 20/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.5274 - accuracy: 0.8109 - f1: 0.8063 - val_loss: 0.7660 - val_accuracy: 0.7135 - val_f1: 0.7103
# Epoch 21/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.5121 - accuracy: 0.8194 - f1: 0.8163 - val_loss: 0.7153 - val_accuracy: 0.7566 - val_f1: 0.7548
# Epoch 22/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.5054 - accuracy: 0.8231 - f1: 0.8203 - val_loss: 0.6377 - val_accuracy: 0.7701 - val_f1: 0.7668
# Epoch 23/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.4985 - accuracy: 0.8266 - f1: 0.8245 - val_loss: 0.6051 - val_accuracy: 0.7799 - val_f1: 0.7772
# Epoch 24/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.4861 - accuracy: 0.8299 - f1: 0.8261 - val_loss: 0.6086 - val_accuracy: 0.7805 - val_f1: 0.7753
# Epoch 25/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.4815 - accuracy: 0.8318 - f1: 0.8301 - val_loss: 0.7398 - val_accuracy: 0.7448 - val_f1: 0.7442
# Epoch 26/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.4611 - accuracy: 0.8413 - f1: 0.8394 - val_loss: 0.8176 - val_accuracy: 0.6805 - val_f1: 0.6753
# Epoch 27/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.4584 - accuracy: 0.8439 - f1: 0.8415 - val_loss: 0.8634 - val_accuracy: 0.6641 - val_f1: 0.6486
# Epoch 28/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.4472 - accuracy: 0.8477 - f1: 0.8460 - val_loss: 0.6002 - val_accuracy: 0.7878 - val_f1: 0.7878
# Epoch 29/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.4415 - accuracy: 0.8491 - f1: 0.8484 - val_loss: 0.7826 - val_accuracy: 0.7452 - val_f1: 0.7476
# Epoch 30/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.4315 - accuracy: 0.8538 - f1: 0.8512 - val_loss: 0.9125 - val_accuracy: 0.6948 - val_f1: 0.6928
# Epoch 31/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.4281 - accuracy: 0.8554 - f1: 0.8548 - val_loss: 0.6714 - val_accuracy: 0.7713 - val_f1: 0.7711
# Epoch 32/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.4165 - accuracy: 0.8614 - f1: 0.8603 - val_loss: 0.7048 - val_accuracy: 0.7707 - val_f1: 0.7689
# Epoch 33/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.4203 - accuracy: 0.8593 - f1: 0.8576 - val_loss: 0.7549 - val_accuracy: 0.7592 - val_f1: 0.7554
# Epoch 34/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.4100 - accuracy: 0.8622 - f1: 0.8612 - val_loss: 0.6179 - val_accuracy: 0.7851 - val_f1: 0.7840
# Epoch 35/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.4030 - accuracy: 0.8671 - f1: 0.8655 - val_loss: 0.7077 - val_accuracy: 0.7629 - val_f1: 0.7636
# Epoch 36/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.4027 - accuracy: 0.8669 - f1: 0.8667 - val_loss: 0.6550 - val_accuracy: 0.7845 - val_f1: 0.7849
# Epoch 37/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3925 - accuracy: 0.8702 - f1: 0.8702 - val_loss: 0.6510 - val_accuracy: 0.7934 - val_f1: 0.7923
# Epoch 38/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3958 - accuracy: 0.8697 - f1: 0.8678 - val_loss: 0.7732 - val_accuracy: 0.7251 - val_f1: 0.7238
# Epoch 39/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.3843 - accuracy: 0.8748 - f1: 0.8730 - val_loss: 1.0380 - val_accuracy: 0.6472 - val_f1: 0.6447
# Epoch 40/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3818 - accuracy: 0.8743 - f1: 0.8729 - val_loss: 0.7105 - val_accuracy: 0.7703 - val_f1: 0.7710
# Epoch 41/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3821 - accuracy: 0.8756 - f1: 0.8746 - val_loss: 1.0733 - val_accuracy: 0.7086 - val_f1: 0.7082
# Epoch 42/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3659 - accuracy: 0.8821 - f1: 0.8811 - val_loss: 0.5433 - val_accuracy: 0.8169 - val_f1: 0.8157
# Epoch 43/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3577 - accuracy: 0.8846 - f1: 0.8831 - val_loss: 0.6495 - val_accuracy: 0.7779 - val_f1: 0.7742
# Epoch 44/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.3765 - accuracy: 0.8783 - f1: 0.8778 - val_loss: 0.6580 - val_accuracy: 0.7867 - val_f1: 0.7868
# Epoch 45/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3504 - accuracy: 0.8878 - f1: 0.8879 - val_loss: 0.6035 - val_accuracy: 0.7962 - val_f1: 0.7945
# Epoch 46/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.3468 - accuracy: 0.8893 - f1: 0.8889 - val_loss: 0.6878 - val_accuracy: 0.7645 - val_f1: 0.7646
# Epoch 47/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3457 - accuracy: 0.8895 - f1: 0.8885 - val_loss: 0.7579 - val_accuracy: 0.7542 - val_f1: 0.7544
# Epoch 48/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3543 - accuracy: 0.8863 - f1: 0.8859 - val_loss: 0.6891 - val_accuracy: 0.7490 - val_f1: 0.7470
# Epoch 49/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.3397 - accuracy: 0.8915 - f1: 0.8902 - val_loss: 0.7029 - val_accuracy: 0.7588 - val_f1: 0.7601
# Epoch 50/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.3506 - accuracy: 0.8886 - f1: 0.8890 - val_loss: 0.5875 - val_accuracy: 0.7986 - val_f1: 0.7979
# Epoch 51/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3328 - accuracy: 0.8944 - f1: 0.8938 - val_loss: 0.6537 - val_accuracy: 0.7978 - val_f1: 0.7989
# Epoch 52/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3319 - accuracy: 0.8963 - f1: 0.8950 - val_loss: 0.6162 - val_accuracy: 0.8032 - val_f1: 0.8039
# Epoch 53/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3364 - accuracy: 0.8935 - f1: 0.8934 - val_loss: 0.6218 - val_accuracy: 0.7910 - val_f1: 0.7896
# Epoch 54/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3227 - accuracy: 0.8992 - f1: 0.8988 - val_loss: 0.7115 - val_accuracy: 0.7869 - val_f1: 0.7869
# Epoch 55/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3243 - accuracy: 0.8970 - f1: 0.8978 - val_loss: 0.5309 - val_accuracy: 0.8229 - val_f1: 0.8234
# Epoch 56/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3246 - accuracy: 0.8968 - f1: 0.8965 - val_loss: 0.6534 - val_accuracy: 0.7952 - val_f1: 0.7937
# Epoch 57/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.3110 - accuracy: 0.9053 - f1: 0.9046 - val_loss: 0.6655 - val_accuracy: 0.7940 - val_f1: 0.7938
# Epoch 58/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.3150 - accuracy: 0.9012 - f1: 0.9005 - val_loss: 0.6278 - val_accuracy: 0.7894 - val_f1: 0.7892
# Epoch 59/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3256 - accuracy: 0.8996 - f1: 0.9000 - val_loss: 0.6724 - val_accuracy: 0.7791 - val_f1: 0.7797
# Epoch 60/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.3027 - accuracy: 0.9073 - f1: 0.9069 - val_loss: 0.6680 - val_accuracy: 0.7713 - val_f1: 0.7717
# Epoch 61/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.3111 - accuracy: 0.9028 - f1: 0.9030 - val_loss: 0.7202 - val_accuracy: 0.7857 - val_f1: 0.7861
# Epoch 62/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.3065 - accuracy: 0.9050 - f1: 0.9036 - val_loss: 0.8252 - val_accuracy: 0.7187 - val_f1: 0.7157
# Epoch 63/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.3095 - accuracy: 0.9033 - f1: 0.9029 - val_loss: 0.5121 - val_accuracy: 0.8327 - val_f1: 0.8340
# Epoch 64/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.3055 - accuracy: 0.9059 - f1: 0.9060 - val_loss: 0.5963 - val_accuracy: 0.8058 - val_f1: 0.8080
# Epoch 65/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2928 - accuracy: 0.9113 - f1: 0.9110 - val_loss: 0.5143 - val_accuracy: 0.8329 - val_f1: 0.8331
# Epoch 66/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2982 - accuracy: 0.9089 - f1: 0.9084 - val_loss: 0.5691 - val_accuracy: 0.8275 - val_f1: 0.8269
# Epoch 67/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2883 - accuracy: 0.9128 - f1: 0.9126 - val_loss: 0.6253 - val_accuracy: 0.8004 - val_f1: 0.8017
# Epoch 68/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2960 - accuracy: 0.9092 - f1: 0.9098 - val_loss: 0.5822 - val_accuracy: 0.8159 - val_f1: 0.8171
# Epoch 69/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2836 - accuracy: 0.9129 - f1: 0.9137 - val_loss: 0.6022 - val_accuracy: 0.8259 - val_f1: 0.8274
# Epoch 70/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.2787 - accuracy: 0.9156 - f1: 0.9148 - val_loss: 0.6541 - val_accuracy: 0.8018 - val_f1: 0.8026
# Epoch 71/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.3005 - accuracy: 0.9075 - f1: 0.9074 - val_loss: 0.6416 - val_accuracy: 0.8068 - val_f1: 0.8064
# Epoch 72/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.2809 - accuracy: 0.9156 - f1: 0.9158 - val_loss: 0.8093 - val_accuracy: 0.7382 - val_f1: 0.7336
# Epoch 73/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2774 - accuracy: 0.9170 - f1: 0.9176 - val_loss: 0.5050 - val_accuracy: 0.8406 - val_f1: 0.8406
# Epoch 74/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.2725 - accuracy: 0.9186 - f1: 0.9173 - val_loss: 0.6089 - val_accuracy: 0.8086 - val_f1: 0.8078
# Epoch 75/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.2867 - accuracy: 0.9135 - f1: 0.9140 - val_loss: 0.6849 - val_accuracy: 0.7932 - val_f1: 0.7941
# Epoch 76/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2817 - accuracy: 0.9151 - f1: 0.9148 - val_loss: 0.5576 - val_accuracy: 0.8147 - val_f1: 0.8142
# Epoch 77/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.2793 - accuracy: 0.9152 - f1: 0.9142 - val_loss: 0.6799 - val_accuracy: 0.7859 - val_f1: 0.7858
# Epoch 78/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2711 - accuracy: 0.9205 - f1: 0.9199 - val_loss: 0.5090 - val_accuracy: 0.8400 - val_f1: 0.8416
# Epoch 79/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2642 - accuracy: 0.9228 - f1: 0.9229 - val_loss: 0.7648 - val_accuracy: 0.7783 - val_f1: 0.7773
# Epoch 80/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2738 - accuracy: 0.9183 - f1: 0.9180 - val_loss: 0.5310 - val_accuracy: 0.8369 - val_f1: 0.8336
# Epoch 81/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2659 - accuracy: 0.9222 - f1: 0.9217 - val_loss: 0.6076 - val_accuracy: 0.8161 - val_f1: 0.8166
# Epoch 82/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2774 - accuracy: 0.9151 - f1: 0.9147 - val_loss: 0.5512 - val_accuracy: 0.8279 - val_f1: 0.8284
# Epoch 83/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2704 - accuracy: 0.9197 - f1: 0.9196 - val_loss: 0.5224 - val_accuracy: 0.8444 - val_f1: 0.8465
# Epoch 84/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2560 - accuracy: 0.9254 - f1: 0.9253 - val_loss: 0.5257 - val_accuracy: 0.8396 - val_f1: 0.8405
# Epoch 85/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2605 - accuracy: 0.9234 - f1: 0.9237 - val_loss: 0.6791 - val_accuracy: 0.8151 - val_f1: 0.8157
# Epoch 86/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2547 - accuracy: 0.9251 - f1: 0.9246 - val_loss: 0.5332 - val_accuracy: 0.8365 - val_f1: 0.8369
# Epoch 87/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2597 - accuracy: 0.9222 - f1: 0.9217 - val_loss: 0.5683 - val_accuracy: 0.8313 - val_f1: 0.8339
# Epoch 88/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2665 - accuracy: 0.9219 - f1: 0.9220 - val_loss: 0.5533 - val_accuracy: 0.8313 - val_f1: 0.8338
# Epoch 89/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2559 - accuracy: 0.9243 - f1: 0.9249 - val_loss: 0.5614 - val_accuracy: 0.8255 - val_f1: 0.8266
# Epoch 90/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.2483 - accuracy: 0.9276 - f1: 0.9277 - val_loss: 0.6673 - val_accuracy: 0.7910 - val_f1: 0.7917
# Epoch 91/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2531 - accuracy: 0.9265 - f1: 0.9263 - val_loss: 0.4954 - val_accuracy: 0.8496 - val_f1: 0.8508
# Epoch 92/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2512 - accuracy: 0.9254 - f1: 0.9258 - val_loss: 0.5304 - val_accuracy: 0.8410 - val_f1: 0.8408
# Epoch 93/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2561 - accuracy: 0.9239 - f1: 0.9238 - val_loss: 0.6039 - val_accuracy: 0.8201 - val_f1: 0.8217
# Epoch 94/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2618 - accuracy: 0.9235 - f1: 0.9235 - val_loss: 0.4992 - val_accuracy: 0.8518 - val_f1: 0.8528
# Epoch 95/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2523 - accuracy: 0.9266 - f1: 0.9256 - val_loss: 0.5152 - val_accuracy: 0.8359 - val_f1: 0.8360
# Epoch 96/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2647 - accuracy: 0.9207 - f1: 0.9207 - val_loss: 0.6456 - val_accuracy: 0.8080 - val_f1: 0.8085
# Epoch 97/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2483 - accuracy: 0.9282 - f1: 0.9273 - val_loss: 0.5744 - val_accuracy: 0.8147 - val_f1: 0.8153
# Epoch 98/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2597 - accuracy: 0.9244 - f1: 0.9241 - val_loss: 0.6459 - val_accuracy: 0.8165 - val_f1: 0.8189
# Epoch 99/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2466 - accuracy: 0.9296 - f1: 0.9292 - val_loss: 0.6155 - val_accuracy: 0.8102 - val_f1: 0.8115
# Epoch 100/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2454 - accuracy: 0.9295 - f1: 0.9292 - val_loss: 0.4862 - val_accuracy: 0.8530 - val_f1: 0.8555
# Epoch 101/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2466 - accuracy: 0.9298 - f1: 0.9286 - val_loss: 0.4975 - val_accuracy: 0.8502 - val_f1: 0.8510
# Epoch 102/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2528 - accuracy: 0.9260 - f1: 0.9255 - val_loss: 0.6286 - val_accuracy: 0.8149 - val_f1: 0.8162
# Epoch 103/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2552 - accuracy: 0.9256 - f1: 0.9252 - val_loss: 0.5295 - val_accuracy: 0.8410 - val_f1: 0.8432
# Epoch 104/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2419 - accuracy: 0.9309 - f1: 0.9300 - val_loss: 0.6238 - val_accuracy: 0.8137 - val_f1: 0.8132
# Epoch 105/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2526 - accuracy: 0.9274 - f1: 0.9275 - val_loss: 0.4924 - val_accuracy: 0.8556 - val_f1: 0.8559
# Epoch 106/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2352 - accuracy: 0.9336 - f1: 0.9326 - val_loss: 0.4820 - val_accuracy: 0.8516 - val_f1: 0.8515
# Epoch 107/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2330 - accuracy: 0.9347 - f1: 0.9341 - val_loss: 0.4994 - val_accuracy: 0.8498 - val_f1: 0.8500
# Epoch 108/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2313 - accuracy: 0.9354 - f1: 0.9346 - val_loss: 0.7235 - val_accuracy: 0.7962 - val_f1: 0.7984
# Epoch 109/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2498 - accuracy: 0.9284 - f1: 0.9272 - val_loss: 0.4894 - val_accuracy: 0.8454 - val_f1: 0.8476
# Epoch 110/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2456 - accuracy: 0.9293 - f1: 0.9285 - val_loss: 0.5786 - val_accuracy: 0.8285 - val_f1: 0.8303
# Epoch 111/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2408 - accuracy: 0.9308 - f1: 0.9305 - val_loss: 0.5230 - val_accuracy: 0.8480 - val_f1: 0.8493
# Epoch 112/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2369 - accuracy: 0.9328 - f1: 0.9329 - val_loss: 0.4992 - val_accuracy: 0.8624 - val_f1: 0.8629
# Epoch 113/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2271 - accuracy: 0.9358 - f1: 0.9354 - val_loss: 0.7368 - val_accuracy: 0.7627 - val_f1: 0.7640
# Epoch 114/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2352 - accuracy: 0.9341 - f1: 0.9332 - val_loss: 0.5785 - val_accuracy: 0.8323 - val_f1: 0.8344
# Epoch 115/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.2362 - accuracy: 0.9316 - f1: 0.9321 - val_loss: 0.5001 - val_accuracy: 0.8510 - val_f1: 0.8532
# Epoch 116/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2312 - accuracy: 0.9347 - f1: 0.9344 - val_loss: 0.7168 - val_accuracy: 0.7859 - val_f1: 0.7874
# Epoch 117/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2313 - accuracy: 0.9358 - f1: 0.9353 - val_loss: 0.5155 - val_accuracy: 0.8492 - val_f1: 0.8494
# Epoch 118/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.2261 - accuracy: 0.9362 - f1: 0.9356 - val_loss: 0.5237 - val_accuracy: 0.8416 - val_f1: 0.8419
# Epoch 119/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2366 - accuracy: 0.9333 - f1: 0.9329 - val_loss: 0.5379 - val_accuracy: 0.8315 - val_f1: 0.8308
# Epoch 120/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2307 - accuracy: 0.9340 - f1: 0.9339 - val_loss: 0.4975 - val_accuracy: 0.8530 - val_f1: 0.8540
# Epoch 121/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2327 - accuracy: 0.9348 - f1: 0.9345 - val_loss: 0.5781 - val_accuracy: 0.8289 - val_f1: 0.8303
# Epoch 122/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2294 - accuracy: 0.9352 - f1: 0.9351 - val_loss: 0.6434 - val_accuracy: 0.8223 - val_f1: 0.8217
# Epoch 123/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2228 - accuracy: 0.9392 - f1: 0.9388 - val_loss: 0.5413 - val_accuracy: 0.8367 - val_f1: 0.8361
# Epoch 124/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2199 - accuracy: 0.9384 - f1: 0.9383 - val_loss: 0.6579 - val_accuracy: 0.7994 - val_f1: 0.7998
# Epoch 125/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2342 - accuracy: 0.9337 - f1: 0.9335 - val_loss: 0.5773 - val_accuracy: 0.8313 - val_f1: 0.8318
# Epoch 126/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2175 - accuracy: 0.9403 - f1: 0.9400 - val_loss: 0.5366 - val_accuracy: 0.8410 - val_f1: 0.8420
# Epoch 127/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2247 - accuracy: 0.9371 - f1: 0.9363 - val_loss: 0.4898 - val_accuracy: 0.8578 - val_f1: 0.8606
# Epoch 128/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.2299 - accuracy: 0.9344 - f1: 0.9343 - val_loss: 0.6084 - val_accuracy: 0.8313 - val_f1: 0.8326
# Epoch 129/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2208 - accuracy: 0.9398 - f1: 0.9400 - val_loss: 0.5174 - val_accuracy: 0.8452 - val_f1: 0.8481
# Epoch 130/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2146 - accuracy: 0.9412 - f1: 0.9414 - val_loss: 0.6226 - val_accuracy: 0.8054 - val_f1: 0.8066
# Epoch 131/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2174 - accuracy: 0.9400 - f1: 0.9389 - val_loss: 0.5692 - val_accuracy: 0.8464 - val_f1: 0.8459
# Epoch 132/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2462 - accuracy: 0.9305 - f1: 0.9305 - val_loss: 0.6499 - val_accuracy: 0.8195 - val_f1: 0.8210
# Epoch 133/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2131 - accuracy: 0.9424 - f1: 0.9419 - val_loss: 0.4658 - val_accuracy: 0.8655 - val_f1: 0.8660
# Epoch 134/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2186 - accuracy: 0.9397 - f1: 0.9389 - val_loss: 0.5458 - val_accuracy: 0.8402 - val_f1: 0.8411
# Epoch 135/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2296 - accuracy: 0.9362 - f1: 0.9357 - val_loss: 0.6454 - val_accuracy: 0.8219 - val_f1: 0.8239
# Epoch 136/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2203 - accuracy: 0.9388 - f1: 0.9388 - val_loss: 0.4891 - val_accuracy: 0.8572 - val_f1: 0.8583
# Epoch 137/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.2126 - accuracy: 0.9420 - f1: 0.9414 - val_loss: 0.5371 - val_accuracy: 0.8464 - val_f1: 0.8482
# Epoch 138/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2155 - accuracy: 0.9415 - f1: 0.9404 - val_loss: 0.8280 - val_accuracy: 0.7454 - val_f1: 0.7484
# Epoch 139/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2272 - accuracy: 0.9369 - f1: 0.9370 - val_loss: 0.5168 - val_accuracy: 0.8476 - val_f1: 0.8492
# Epoch 140/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2086 - accuracy: 0.9423 - f1: 0.9425 - val_loss: 0.8210 - val_accuracy: 0.7404 - val_f1: 0.7413
# Epoch 141/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2201 - accuracy: 0.9379 - f1: 0.9377 - val_loss: 0.5956 - val_accuracy: 0.8396 - val_f1: 0.8395
# Epoch 142/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2070 - accuracy: 0.9435 - f1: 0.9437 - val_loss: 0.7174 - val_accuracy: 0.8114 - val_f1: 0.8125
# Epoch 143/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2131 - accuracy: 0.9406 - f1: 0.9408 - val_loss: 0.6629 - val_accuracy: 0.8064 - val_f1: 0.8080
# Epoch 144/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2116 - accuracy: 0.9423 - f1: 0.9423 - val_loss: 0.5891 - val_accuracy: 0.8404 - val_f1: 0.8402
# Epoch 145/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1932 - accuracy: 0.9489 - f1: 0.9488 - val_loss: 0.5414 - val_accuracy: 0.8402 - val_f1: 0.8416
# Epoch 146/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2135 - accuracy: 0.9406 - f1: 0.9399 - val_loss: 0.5915 - val_accuracy: 0.8404 - val_f1: 0.8417
# Epoch 147/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2223 - accuracy: 0.9386 - f1: 0.9385 - val_loss: 0.4504 - val_accuracy: 0.8635 - val_f1: 0.8644
# Epoch 148/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2045 - accuracy: 0.9447 - f1: 0.9451 - val_loss: 0.4879 - val_accuracy: 0.8570 - val_f1: 0.8579
# Epoch 149/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.2056 - accuracy: 0.9441 - f1: 0.9439 - val_loss: 0.5127 - val_accuracy: 0.8520 - val_f1: 0.8511
# Epoch 150/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2136 - accuracy: 0.9420 - f1: 0.9415 - val_loss: 0.5131 - val_accuracy: 0.8548 - val_f1: 0.8550
# Epoch 151/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2215 - accuracy: 0.9402 - f1: 0.9403 - val_loss: 0.5379 - val_accuracy: 0.8442 - val_f1: 0.8461
# Epoch 152/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1983 - accuracy: 0.9462 - f1: 0.9460 - val_loss: 0.5564 - val_accuracy: 0.8365 - val_f1: 0.8390
# Epoch 153/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2214 - accuracy: 0.9371 - f1: 0.9371 - val_loss: 0.4921 - val_accuracy: 0.8500 - val_f1: 0.8504
# Epoch 154/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2138 - accuracy: 0.9415 - f1: 0.9405 - val_loss: 0.5083 - val_accuracy: 0.8554 - val_f1: 0.8573
# Epoch 155/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2232 - accuracy: 0.9369 - f1: 0.9373 - val_loss: 0.4378 - val_accuracy: 0.8719 - val_f1: 0.8747
# Epoch 156/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2033 - accuracy: 0.9449 - f1: 0.9451 - val_loss: 0.4730 - val_accuracy: 0.8627 - val_f1: 0.8644
# Epoch 157/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1893 - accuracy: 0.9501 - f1: 0.9497 - val_loss: 0.5086 - val_accuracy: 0.8570 - val_f1: 0.8588
# Epoch 158/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2011 - accuracy: 0.9462 - f1: 0.9468 - val_loss: 0.4614 - val_accuracy: 0.8645 - val_f1: 0.8661
# Epoch 159/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1914 - accuracy: 0.9501 - f1: 0.9494 - val_loss: 0.5094 - val_accuracy: 0.8520 - val_f1: 0.8525
# Epoch 160/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2238 - accuracy: 0.9366 - f1: 0.9364 - val_loss: 0.4355 - val_accuracy: 0.8703 - val_f1: 0.8724
# Epoch 161/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2130 - accuracy: 0.9405 - f1: 0.9406 - val_loss: 0.5617 - val_accuracy: 0.8386 - val_f1: 0.8390
# Epoch 162/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2090 - accuracy: 0.9431 - f1: 0.9436 - val_loss: 0.5052 - val_accuracy: 0.8610 - val_f1: 0.8611
# Epoch 163/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1989 - accuracy: 0.9464 - f1: 0.9464 - val_loss: 0.4799 - val_accuracy: 0.8620 - val_f1: 0.8634
# Epoch 164/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1994 - accuracy: 0.9472 - f1: 0.9471 - val_loss: 0.4350 - val_accuracy: 0.8729 - val_f1: 0.8741
# Epoch 165/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1961 - accuracy: 0.9484 - f1: 0.9470 - val_loss: 0.4431 - val_accuracy: 0.8701 - val_f1: 0.8704
# Epoch 166/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2218 - accuracy: 0.9377 - f1: 0.9381 - val_loss: 0.4289 - val_accuracy: 0.8765 - val_f1: 0.8788
# Epoch 167/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1920 - accuracy: 0.9498 - f1: 0.9496 - val_loss: 0.4749 - val_accuracy: 0.8675 - val_f1: 0.8682
# Epoch 168/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1947 - accuracy: 0.9476 - f1: 0.9475 - val_loss: 0.8649 - val_accuracy: 0.7566 - val_f1: 0.7548
# Epoch 169/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2072 - accuracy: 0.9424 - f1: 0.9424 - val_loss: 0.4559 - val_accuracy: 0.8695 - val_f1: 0.8715
# Epoch 170/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2008 - accuracy: 0.9457 - f1: 0.9461 - val_loss: 0.4684 - val_accuracy: 0.8651 - val_f1: 0.8676
# Epoch 171/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1961 - accuracy: 0.9475 - f1: 0.9467 - val_loss: 0.6188 - val_accuracy: 0.8371 - val_f1: 0.8399
# Epoch 172/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2145 - accuracy: 0.9407 - f1: 0.9410 - val_loss: 0.4448 - val_accuracy: 0.8751 - val_f1: 0.8762
# Epoch 173/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2006 - accuracy: 0.9467 - f1: 0.9458 - val_loss: 0.5843 - val_accuracy: 0.8450 - val_f1: 0.8466
# Epoch 174/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2117 - accuracy: 0.9410 - f1: 0.9405 - val_loss: 0.5201 - val_accuracy: 0.8452 - val_f1: 0.8470
# Epoch 175/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2122 - accuracy: 0.9418 - f1: 0.9406 - val_loss: 0.7467 - val_accuracy: 0.7841 - val_f1: 0.7854
# Epoch 176/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2206 - accuracy: 0.9388 - f1: 0.9385 - val_loss: 0.4698 - val_accuracy: 0.8649 - val_f1: 0.8645
# Epoch 177/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1995 - accuracy: 0.9464 - f1: 0.9468 - val_loss: 0.5093 - val_accuracy: 0.8629 - val_f1: 0.8632
# Epoch 178/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1926 - accuracy: 0.9487 - f1: 0.9489 - val_loss: 0.4564 - val_accuracy: 0.8699 - val_f1: 0.8706
# Epoch 179/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1852 - accuracy: 0.9523 - f1: 0.9515 - val_loss: 0.4648 - val_accuracy: 0.8697 - val_f1: 0.8704
# Epoch 180/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1990 - accuracy: 0.9467 - f1: 0.9464 - val_loss: 0.4332 - val_accuracy: 0.8763 - val_f1: 0.8772
# Epoch 181/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1942 - accuracy: 0.9489 - f1: 0.9488 - val_loss: 0.4341 - val_accuracy: 0.8745 - val_f1: 0.8759
# Epoch 182/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1867 - accuracy: 0.9516 - f1: 0.9521 - val_loss: 0.5759 - val_accuracy: 0.8303 - val_f1: 0.8304
# Epoch 183/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1876 - accuracy: 0.9510 - f1: 0.9500 - val_loss: 0.4467 - val_accuracy: 0.8731 - val_f1: 0.8728
# Epoch 184/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2214 - accuracy: 0.9389 - f1: 0.9385 - val_loss: 0.4349 - val_accuracy: 0.8753 - val_f1: 0.8761
# Epoch 185/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2009 - accuracy: 0.9460 - f1: 0.9451 - val_loss: 0.9673 - val_accuracy: 0.7506 - val_f1: 0.7500
# Epoch 186/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2153 - accuracy: 0.9414 - f1: 0.9415 - val_loss: 0.6932 - val_accuracy: 0.8197 - val_f1: 0.8213
# Epoch 187/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1897 - accuracy: 0.9502 - f1: 0.9504 - val_loss: 0.7450 - val_accuracy: 0.8153 - val_f1: 0.8163
# Epoch 188/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1856 - accuracy: 0.9523 - f1: 0.9522 - val_loss: 0.4225 - val_accuracy: 0.8771 - val_f1: 0.8790
# Epoch 189/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1903 - accuracy: 0.9495 - f1: 0.9490 - val_loss: 0.4510 - val_accuracy: 0.8785 - val_f1: 0.8793
# Epoch 190/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1900 - accuracy: 0.9498 - f1: 0.9499 - val_loss: 0.5001 - val_accuracy: 0.8582 - val_f1: 0.8610
# Epoch 191/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1909 - accuracy: 0.9492 - f1: 0.9488 - val_loss: 0.6427 - val_accuracy: 0.8131 - val_f1: 0.8120
# Epoch 192/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.2020 - accuracy: 0.9469 - f1: 0.9468 - val_loss: 0.4633 - val_accuracy: 0.8657 - val_f1: 0.8652
# Epoch 193/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1878 - accuracy: 0.9506 - f1: 0.9505 - val_loss: 0.4664 - val_accuracy: 0.8711 - val_f1: 0.8734
# Epoch 194/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1881 - accuracy: 0.9506 - f1: 0.9499 - val_loss: 0.5528 - val_accuracy: 0.8341 - val_f1: 0.8354
# Epoch 195/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2073 - accuracy: 0.9440 - f1: 0.9440 - val_loss: 0.4612 - val_accuracy: 0.8669 - val_f1: 0.8668
# Epoch 196/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1909 - accuracy: 0.9489 - f1: 0.9485 - val_loss: 0.5370 - val_accuracy: 0.8540 - val_f1: 0.8545
# Epoch 197/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.1931 - accuracy: 0.9485 - f1: 0.9472 - val_loss: 0.5461 - val_accuracy: 0.8289 - val_f1: 0.8316
# Epoch 198/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2181 - accuracy: 0.9391 - f1: 0.9390 - val_loss: 0.5327 - val_accuracy: 0.8510 - val_f1: 0.8532
# Epoch 199/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1952 - accuracy: 0.9489 - f1: 0.9490 - val_loss: 0.4212 - val_accuracy: 0.8803 - val_f1: 0.8805
# Epoch 200/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1889 - accuracy: 0.9506 - f1: 0.9508 - val_loss: 0.4334 - val_accuracy: 0.8801 - val_f1: 0.8815
# Epoch 201/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1779 - accuracy: 0.9547 - f1: 0.9541 - val_loss: 0.5361 - val_accuracy: 0.8426 - val_f1: 0.8434
# Epoch 202/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.1947 - accuracy: 0.9479 - f1: 0.9472 - val_loss: 0.5564 - val_accuracy: 0.8522 - val_f1: 0.8528
# Epoch 203/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1954 - accuracy: 0.9476 - f1: 0.9474 - val_loss: 0.7149 - val_accuracy: 0.8183 - val_f1: 0.8189
# Epoch 204/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1870 - accuracy: 0.9514 - f1: 0.9510 - val_loss: 0.4892 - val_accuracy: 0.8594 - val_f1: 0.8602
# Epoch 205/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1780 - accuracy: 0.9531 - f1: 0.9527 - val_loss: 0.5078 - val_accuracy: 0.8506 - val_f1: 0.8514
# Epoch 206/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2002 - accuracy: 0.9457 - f1: 0.9452 - val_loss: 0.5874 - val_accuracy: 0.8299 - val_f1: 0.8323
# Epoch 207/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1968 - accuracy: 0.9473 - f1: 0.9475 - val_loss: 0.5141 - val_accuracy: 0.8616 - val_f1: 0.8637
# Epoch 208/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1841 - accuracy: 0.9521 - f1: 0.9522 - val_loss: 0.4503 - val_accuracy: 0.8755 - val_f1: 0.8772
# Epoch 209/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.1822 - accuracy: 0.9526 - f1: 0.9526 - val_loss: 0.4660 - val_accuracy: 0.8677 - val_f1: 0.8701
# Epoch 210/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1782 - accuracy: 0.9548 - f1: 0.9544 - val_loss: 0.6729 - val_accuracy: 0.8012 - val_f1: 0.8057
# Epoch 211/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1922 - accuracy: 0.9495 - f1: 0.9486 - val_loss: 0.4900 - val_accuracy: 0.8665 - val_f1: 0.8664
# Epoch 212/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1996 - accuracy: 0.9470 - f1: 0.9475 - val_loss: 0.5477 - val_accuracy: 0.8530 - val_f1: 0.8543
# Epoch 213/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1750 - accuracy: 0.9556 - f1: 0.9544 - val_loss: 0.4912 - val_accuracy: 0.8633 - val_f1: 0.8635
# Epoch 214/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.2309 - accuracy: 0.9341 - f1: 0.9342 - val_loss: 0.4170 - val_accuracy: 0.8851 - val_f1: 0.8871
# Epoch 215/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1962 - accuracy: 0.9473 - f1: 0.9479 - val_loss: 0.5680 - val_accuracy: 0.8255 - val_f1: 0.8252
# Epoch 216/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1739 - accuracy: 0.9557 - f1: 0.9555 - val_loss: 0.5721 - val_accuracy: 0.8494 - val_f1: 0.8506
# Epoch 217/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1803 - accuracy: 0.9526 - f1: 0.9522 - val_loss: 0.4305 - val_accuracy: 0.8793 - val_f1: 0.8803
# Epoch 218/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1894 - accuracy: 0.9505 - f1: 0.9505 - val_loss: 0.5258 - val_accuracy: 0.8540 - val_f1: 0.8543
# Epoch 219/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1814 - accuracy: 0.9526 - f1: 0.9522 - val_loss: 0.4640 - val_accuracy: 0.8765 - val_f1: 0.8773
# Epoch 220/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1837 - accuracy: 0.9527 - f1: 0.9525 - val_loss: 0.4139 - val_accuracy: 0.8773 - val_f1: 0.8793
# Epoch 221/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1840 - accuracy: 0.9515 - f1: 0.9509 - val_loss: 0.4463 - val_accuracy: 0.8685 - val_f1: 0.8703
# Epoch 222/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1990 - accuracy: 0.9472 - f1: 0.9472 - val_loss: 0.5277 - val_accuracy: 0.8482 - val_f1: 0.8507
# Epoch 223/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1843 - accuracy: 0.9519 - f1: 0.9517 - val_loss: 0.5232 - val_accuracy: 0.8550 - val_f1: 0.8560
# Epoch 224/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1809 - accuracy: 0.9528 - f1: 0.9525 - val_loss: 0.5427 - val_accuracy: 0.8440 - val_f1: 0.8447
# Epoch 225/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1817 - accuracy: 0.9527 - f1: 0.9527 - val_loss: 0.4710 - val_accuracy: 0.8606 - val_f1: 0.8616
# Epoch 226/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1820 - accuracy: 0.9533 - f1: 0.9532 - val_loss: 0.4432 - val_accuracy: 0.8839 - val_f1: 0.8843
# Epoch 227/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1712 - accuracy: 0.9562 - f1: 0.9563 - val_loss: 0.5535 - val_accuracy: 0.8335 - val_f1: 0.8343
# Epoch 228/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1711 - accuracy: 0.9564 - f1: 0.9567 - val_loss: 0.5206 - val_accuracy: 0.8624 - val_f1: 0.8648
# Epoch 229/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1742 - accuracy: 0.9552 - f1: 0.9549 - val_loss: 0.4175 - val_accuracy: 0.8865 - val_f1: 0.8872
# Epoch 230/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1802 - accuracy: 0.9533 - f1: 0.9516 - val_loss: 0.6341 - val_accuracy: 0.8219 - val_f1: 0.8243
# Epoch 231/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2219 - accuracy: 0.9381 - f1: 0.9384 - val_loss: 0.8970 - val_accuracy: 0.7460 - val_f1: 0.7458
# Epoch 232/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1797 - accuracy: 0.9540 - f1: 0.9540 - val_loss: 0.4293 - val_accuracy: 0.8749 - val_f1: 0.8772
# Epoch 233/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1676 - accuracy: 0.9590 - f1: 0.9585 - val_loss: 0.4382 - val_accuracy: 0.8745 - val_f1: 0.8765
# Epoch 234/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1776 - accuracy: 0.9539 - f1: 0.9539 - val_loss: 0.5506 - val_accuracy: 0.8528 - val_f1: 0.8535
# Epoch 235/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1793 - accuracy: 0.9543 - f1: 0.9537 - val_loss: 0.5967 - val_accuracy: 0.8277 - val_f1: 0.8296
# Epoch 236/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1866 - accuracy: 0.9512 - f1: 0.9514 - val_loss: 0.4357 - val_accuracy: 0.8793 - val_f1: 0.8818
# Epoch 237/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1736 - accuracy: 0.9570 - f1: 0.9567 - val_loss: 0.4144 - val_accuracy: 0.8817 - val_f1: 0.8837
# Epoch 238/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1723 - accuracy: 0.9559 - f1: 0.9561 - val_loss: 0.5228 - val_accuracy: 0.8542 - val_f1: 0.8570
# Epoch 239/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1713 - accuracy: 0.9576 - f1: 0.9573 - val_loss: 0.4649 - val_accuracy: 0.8769 - val_f1: 0.8780
# Epoch 240/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1831 - accuracy: 0.9518 - f1: 0.9520 - val_loss: 0.5165 - val_accuracy: 0.8594 - val_f1: 0.8604
# Epoch 241/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.1777 - accuracy: 0.9548 - f1: 0.9550 - val_loss: 0.4600 - val_accuracy: 0.8723 - val_f1: 0.8734
# Epoch 242/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1728 - accuracy: 0.9559 - f1: 0.9557 - val_loss: 0.4829 - val_accuracy: 0.8675 - val_f1: 0.8693
# Epoch 243/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1781 - accuracy: 0.9550 - f1: 0.9551 - val_loss: 0.4465 - val_accuracy: 0.8741 - val_f1: 0.8761
# Epoch 244/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1770 - accuracy: 0.9537 - f1: 0.9532 - val_loss: 0.4763 - val_accuracy: 0.8713 - val_f1: 0.8727
# Epoch 245/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1865 - accuracy: 0.9513 - f1: 0.9505 - val_loss: 0.4326 - val_accuracy: 0.8749 - val_f1: 0.8766
# Epoch 246/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1860 - accuracy: 0.9518 - f1: 0.9505 - val_loss: 0.4721 - val_accuracy: 0.8669 - val_f1: 0.8679
# Epoch 247/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.2116 - accuracy: 0.9432 - f1: 0.9436 - val_loss: 0.5142 - val_accuracy: 0.8416 - val_f1: 0.8427
# Epoch 248/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1738 - accuracy: 0.9567 - f1: 0.9564 - val_loss: 0.4569 - val_accuracy: 0.8767 - val_f1: 0.8781
# Epoch 249/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.1762 - accuracy: 0.9545 - f1: 0.9544 - val_loss: 0.5609 - val_accuracy: 0.8454 - val_f1: 0.8451
# Epoch 250/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1820 - accuracy: 0.9534 - f1: 0.9534 - val_loss: 0.4681 - val_accuracy: 0.8673 - val_f1: 0.8703
# Epoch 251/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1701 - accuracy: 0.9572 - f1: 0.9569 - val_loss: 0.7749 - val_accuracy: 0.8112 - val_f1: 0.8115
# Epoch 252/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1836 - accuracy: 0.9518 - f1: 0.9523 - val_loss: 0.4949 - val_accuracy: 0.8713 - val_f1: 0.8720
# Epoch 253/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1636 - accuracy: 0.9593 - f1: 0.9582 - val_loss: 0.4184 - val_accuracy: 0.8813 - val_f1: 0.8836
# Epoch 254/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1895 - accuracy: 0.9514 - f1: 0.9515 - val_loss: 0.4032 - val_accuracy: 0.8851 - val_f1: 0.8863
# Epoch 255/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.1637 - accuracy: 0.9600 - f1: 0.9599 - val_loss: 0.4254 - val_accuracy: 0.8755 - val_f1: 0.8790
# Epoch 256/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1671 - accuracy: 0.9581 - f1: 0.9583 - val_loss: 0.5400 - val_accuracy: 0.8498 - val_f1: 0.8504
# Epoch 257/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1669 - accuracy: 0.9589 - f1: 0.9589 - val_loss: 0.5406 - val_accuracy: 0.8460 - val_f1: 0.8475
# Epoch 258/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1736 - accuracy: 0.9558 - f1: 0.9558 - val_loss: 0.4530 - val_accuracy: 0.8769 - val_f1: 0.8790
# Epoch 259/600
# 176/176 [==============================] - 4s 23ms/step - loss: 0.1783 - accuracy: 0.9551 - f1: 0.9552 - val_loss: 0.4638 - val_accuracy: 0.8703 - val_f1: 0.8716
# Epoch 260/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1648 - accuracy: 0.9597 - f1: 0.9594 - val_loss: 0.4457 - val_accuracy: 0.8721 - val_f1: 0.8730
# Epoch 261/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1781 - accuracy: 0.9544 - f1: 0.9548 - val_loss: 0.6154 - val_accuracy: 0.8219 - val_f1: 0.8232
# Epoch 262/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1713 - accuracy: 0.9571 - f1: 0.9565 - val_loss: 0.5049 - val_accuracy: 0.8711 - val_f1: 0.8730
# Epoch 263/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1895 - accuracy: 0.9491 - f1: 0.9494 - val_loss: 0.4982 - val_accuracy: 0.8564 - val_f1: 0.8572
# Epoch 264/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1781 - accuracy: 0.9552 - f1: 0.9551 - val_loss: 0.5817 - val_accuracy: 0.8480 - val_f1: 0.8485
# Epoch 265/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1792 - accuracy: 0.9534 - f1: 0.9533 - val_loss: 0.4989 - val_accuracy: 0.8683 - val_f1: 0.8683
# Epoch 266/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1821 - accuracy: 0.9529 - f1: 0.9530 - val_loss: 0.4853 - val_accuracy: 0.8600 - val_f1: 0.8609
# Epoch 267/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1684 - accuracy: 0.9573 - f1: 0.9575 - val_loss: 0.6195 - val_accuracy: 0.8506 - val_f1: 0.8514
# Epoch 268/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1726 - accuracy: 0.9568 - f1: 0.9568 - val_loss: 0.4205 - val_accuracy: 0.8835 - val_f1: 0.8844
# Epoch 269/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1721 - accuracy: 0.9568 - f1: 0.9565 - val_loss: 0.5074 - val_accuracy: 0.8516 - val_f1: 0.8532
# Epoch 270/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1658 - accuracy: 0.9578 - f1: 0.9568 - val_loss: 0.4075 - val_accuracy: 0.8873 - val_f1: 0.8885
# Epoch 271/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1814 - accuracy: 0.9531 - f1: 0.9525 - val_loss: 0.4892 - val_accuracy: 0.8743 - val_f1: 0.8764
# Epoch 272/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1878 - accuracy: 0.9509 - f1: 0.9508 - val_loss: 0.4780 - val_accuracy: 0.8721 - val_f1: 0.8748
# Epoch 273/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1819 - accuracy: 0.9551 - f1: 0.9548 - val_loss: 0.4700 - val_accuracy: 0.8665 - val_f1: 0.8693
# Epoch 274/600
# ...
# Epoch 511/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1407 - accuracy: 0.9672 - f1: 0.9667 - val_loss: 0.5349 - val_accuracy: 0.8618 - val_f1: 0.8629
# Epoch 512/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1532 - accuracy: 0.9639 - f1: 0.9629 - val_loss: 0.3957 - val_accuracy: 0.8922 - val_f1: 0.8937
# Epoch 513/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1668 - accuracy: 0.9591 - f1: 0.9592 - val_loss: 0.4234 - val_accuracy: 0.8859 - val_f1: 0.8869
# Epoch 514/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1475 - accuracy: 0.9664 - f1: 0.9661 - val_loss: 0.3823 - val_accuracy: 0.8958 - val_f1: 0.8975
# Epoch 515/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1512 - accuracy: 0.9646 - f1: 0.9643 - val_loss: 0.3957 - val_accuracy: 0.9006 - val_f1: 0.9015
# Epoch 516/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1557 - accuracy: 0.9637 - f1: 0.9637 - val_loss: 0.4122 - val_accuracy: 0.8940 - val_f1: 0.8952
# Epoch 517/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1406 - accuracy: 0.9676 - f1: 0.9679 - val_loss: 0.4787 - val_accuracy: 0.8735 - val_f1: 0.8744
# Epoch 518/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1288 - accuracy: 0.9707 - f1: 0.9702 - val_loss: 0.3951 - val_accuracy: 0.8996 - val_f1: 0.9000
# Epoch 519/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1611 - accuracy: 0.9608 - f1: 0.9607 - val_loss: 0.4105 - val_accuracy: 0.8960 - val_f1: 0.8963
# Epoch 520/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1449 - accuracy: 0.9666 - f1: 0.9668 - val_loss: 0.4601 - val_accuracy: 0.8821 - val_f1: 0.8842
# Epoch 521/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1290 - accuracy: 0.9714 - f1: 0.9710 - val_loss: 0.5479 - val_accuracy: 0.8699 - val_f1: 0.8702
# Epoch 522/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1469 - accuracy: 0.9645 - f1: 0.9645 - val_loss: 0.4069 - val_accuracy: 0.8944 - val_f1: 0.8961
# Epoch 523/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1272 - accuracy: 0.9715 - f1: 0.9712 - val_loss: 0.5588 - val_accuracy: 0.8624 - val_f1: 0.8618
# Epoch 524/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1481 - accuracy: 0.9646 - f1: 0.9649 - val_loss: 0.4484 - val_accuracy: 0.8789 - val_f1: 0.8811
# Epoch 525/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1314 - accuracy: 0.9709 - f1: 0.9710 - val_loss: 0.3994 - val_accuracy: 0.8986 - val_f1: 0.8989
# Epoch 526/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1277 - accuracy: 0.9720 - f1: 0.9719 - val_loss: 0.4333 - val_accuracy: 0.8892 - val_f1: 0.8907
# Epoch 527/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1346 - accuracy: 0.9695 - f1: 0.9697 - val_loss: 0.4266 - val_accuracy: 0.8890 - val_f1: 0.8901
# Epoch 528/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.1370 - accuracy: 0.9680 - f1: 0.9676 - val_loss: 0.4252 - val_accuracy: 0.8849 - val_f1: 0.8855
# Epoch 529/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1564 - accuracy: 0.9620 - f1: 0.9618 - val_loss: 0.4695 - val_accuracy: 0.8771 - val_f1: 0.8772
# Epoch 530/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1542 - accuracy: 0.9633 - f1: 0.9633 - val_loss: 0.4002 - val_accuracy: 0.8952 - val_f1: 0.8967
# Epoch 531/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1443 - accuracy: 0.9672 - f1: 0.9672 - val_loss: 0.5461 - val_accuracy: 0.8739 - val_f1: 0.8742
# Epoch 532/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1423 - accuracy: 0.9676 - f1: 0.9679 - val_loss: 0.3840 - val_accuracy: 0.9050 - val_f1: 0.9053
# Epoch 533/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1297 - accuracy: 0.9712 - f1: 0.9703 - val_loss: 0.3925 - val_accuracy: 0.8984 - val_f1: 0.9007
# Epoch 534/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1657 - accuracy: 0.9588 - f1: 0.9592 - val_loss: 0.4389 - val_accuracy: 0.8938 - val_f1: 0.8941
# Epoch 535/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1403 - accuracy: 0.9684 - f1: 0.9680 - val_loss: 0.4631 - val_accuracy: 0.8813 - val_f1: 0.8822
# Epoch 536/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1549 - accuracy: 0.9629 - f1: 0.9634 - val_loss: 0.4310 - val_accuracy: 0.8892 - val_f1: 0.8906
# Epoch 537/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1347 - accuracy: 0.9700 - f1: 0.9699 - val_loss: 0.4269 - val_accuracy: 0.8871 - val_f1: 0.8873
# Epoch 538/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1473 - accuracy: 0.9656 - f1: 0.9655 - val_loss: 0.4242 - val_accuracy: 0.8908 - val_f1: 0.8918
# Epoch 539/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1389 - accuracy: 0.9692 - f1: 0.9689 - val_loss: 0.4208 - val_accuracy: 0.8968 - val_f1: 0.8979
# Epoch 540/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1459 - accuracy: 0.9661 - f1: 0.9657 - val_loss: 0.5174 - val_accuracy: 0.8775 - val_f1: 0.8789
# Epoch 541/600
# 176/176 [==============================] - 4s 22ms/step - loss: 0.1506 - accuracy: 0.9646 - f1: 0.9648 - val_loss: 0.4751 - val_accuracy: 0.8683 - val_f1: 0.8683
# Epoch 542/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1460 - accuracy: 0.9660 - f1: 0.9651 - val_loss: 0.5525 - val_accuracy: 0.8450 - val_f1: 0.8460
# Epoch 543/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1579 - accuracy: 0.9622 - f1: 0.9621 - val_loss: 0.3735 - val_accuracy: 0.9046 - val_f1: 0.9048
# Epoch 544/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1423 - accuracy: 0.9658 - f1: 0.9653 - val_loss: 0.4009 - val_accuracy: 0.8994 - val_f1: 0.9017
# Epoch 545/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1523 - accuracy: 0.9640 - f1: 0.9641 - val_loss: 0.4575 - val_accuracy: 0.8759 - val_f1: 0.8771
# Epoch 546/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1509 - accuracy: 0.9650 - f1: 0.9649 - val_loss: 0.6298 - val_accuracy: 0.8602 - val_f1: 0.8613
# Epoch 547/600
# 176/176 [==============================] - 4s 21ms/step - loss: 0.1426 - accuracy: 0.9665 - f1: 0.9664 - val_loss: 0.4916 - val_accuracy: 0.8719 - val_f1: 0.8731
# Epoch 548/600
# 176/176 [==============================] - 4s 20ms/step - loss: 0.1357 - accuracy: 0.9691 - f1: 0.9685 - val_loss: 0.3951 - val_accuracy: 0.8990 - val_f1: 0.8991
# Epoch 549/600
# 176/176 [==============================] - 3s 17ms/step - loss: 0.1509 - accuracy: 0.9647 - f1: 0.9646 - val_loss: 0.4111 - val_accuracy: 0.8956 - val_f1: 0.8971
# Epoch 550/600
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1319 - accuracy: 0.9713 - f1: 0.9709 - val_loss: 0.3810 - val_accuracy: 0.8990 - val_f1: 0.8993
# Epoch 551/600
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1348 - accuracy: 0.9693 - f1: 0.9696 - val_loss: 0.4228 - val_accuracy: 0.8970 - val_f1: 0.8980
# Epoch 552/600
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1313 - accuracy: 0.9703 - f1: 0.9705 - val_loss: 0.3863 - val_accuracy: 0.8982 - val_f1: 0.8998
# Epoch 553/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1295 - accuracy: 0.9711 - f1: 0.9713 - val_loss: 0.3842 - val_accuracy: 0.9050 - val_f1: 0.9060
# Epoch 554/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1296 - accuracy: 0.9703 - f1: 0.9704 - val_loss: 0.3738 - val_accuracy: 0.9008 - val_f1: 0.9028
# Epoch 555/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.1420 - accuracy: 0.9654 - f1: 0.9658 - val_loss: 0.4002 - val_accuracy: 0.8958 - val_f1: 0.8975
# Epoch 556/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1362 - accuracy: 0.9680 - f1: 0.9682 - val_loss: 0.4151 - val_accuracy: 0.8841 - val_f1: 0.8860
# Epoch 557/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1337 - accuracy: 0.9700 - f1: 0.9702 - val_loss: 0.4225 - val_accuracy: 0.8863 - val_f1: 0.8880
# Epoch 558/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1378 - accuracy: 0.9675 - f1: 0.9668 - val_loss: 0.5151 - val_accuracy: 0.8867 - val_f1: 0.8880
# Epoch 559/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1486 - accuracy: 0.9644 - f1: 0.9643 - val_loss: 0.5458 - val_accuracy: 0.8775 - val_f1: 0.8776
# Epoch 560/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1508 - accuracy: 0.9646 - f1: 0.9638 - val_loss: 0.4796 - val_accuracy: 0.8701 - val_f1: 0.8716
# Epoch 561/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1501 - accuracy: 0.9646 - f1: 0.9646 - val_loss: 0.4830 - val_accuracy: 0.8793 - val_f1: 0.8809
# Epoch 562/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1446 - accuracy: 0.9671 - f1: 0.9674 - val_loss: 0.3923 - val_accuracy: 0.9070 - val_f1: 0.9082
# Epoch 563/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1353 - accuracy: 0.9699 - f1: 0.9698 - val_loss: 0.4011 - val_accuracy: 0.8966 - val_f1: 0.8976
# Epoch 564/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1344 - accuracy: 0.9699 - f1: 0.9695 - val_loss: 0.4095 - val_accuracy: 0.8938 - val_f1: 0.8955
# Epoch 565/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1599 - accuracy: 0.9612 - f1: 0.9613 - val_loss: 0.4380 - val_accuracy: 0.8928 - val_f1: 0.8923
# Epoch 566/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1320 - accuracy: 0.9710 - f1: 0.9705 - val_loss: 0.3908 - val_accuracy: 0.9018 - val_f1: 0.9020
# Epoch 567/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.1407 - accuracy: 0.9677 - f1: 0.9675 - val_loss: 0.3961 - val_accuracy: 0.8998 - val_f1: 0.9010
# Epoch 568/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1389 - accuracy: 0.9690 - f1: 0.9692 - val_loss: 0.4205 - val_accuracy: 0.8982 - val_f1: 0.8984
# Epoch 569/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1327 - accuracy: 0.9698 - f1: 0.9703 - val_loss: 0.4654 - val_accuracy: 0.8837 - val_f1: 0.8835
# Epoch 570/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1288 - accuracy: 0.9707 - f1: 0.9705 - val_loss: 0.3806 - val_accuracy: 0.9050 - val_f1: 0.9073
# Epoch 571/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.1390 - accuracy: 0.9668 - f1: 0.9671 - val_loss: 0.3872 - val_accuracy: 0.9048 - val_f1: 0.9057
# Epoch 572/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1342 - accuracy: 0.9696 - f1: 0.9700 - val_loss: 0.3836 - val_accuracy: 0.9082 - val_f1: 0.9104
# Epoch 573/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1351 - accuracy: 0.9693 - f1: 0.9696 - val_loss: 0.3729 - val_accuracy: 0.9046 - val_f1: 0.9052
# Epoch 574/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1385 - accuracy: 0.9686 - f1: 0.9677 - val_loss: 0.4201 - val_accuracy: 0.9016 - val_f1: 0.9009
# Epoch 575/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1652 - accuracy: 0.9600 - f1: 0.9603 - val_loss: 0.4680 - val_accuracy: 0.8873 - val_f1: 0.8881
# Epoch 576/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1409 - accuracy: 0.9684 - f1: 0.9684 - val_loss: 0.4219 - val_accuracy: 0.8958 - val_f1: 0.8954
# Epoch 577/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1349 - accuracy: 0.9696 - f1: 0.9692 - val_loss: 0.4850 - val_accuracy: 0.8616 - val_f1: 0.8624
# Epoch 578/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1444 - accuracy: 0.9668 - f1: 0.9670 - val_loss: 0.4180 - val_accuracy: 0.8869 - val_f1: 0.8896
# Epoch 579/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1339 - accuracy: 0.9714 - f1: 0.9716 - val_loss: 0.4119 - val_accuracy: 0.8990 - val_f1: 0.8998
# Epoch 580/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1196 - accuracy: 0.9749 - f1: 0.9748 - val_loss: 0.4568 - val_accuracy: 0.8859 - val_f1: 0.8860
# Epoch 581/600
# 176/176 [==============================] - 3s 20ms/step - loss: 0.1342 - accuracy: 0.9691 - f1: 0.9689 - val_loss: 0.3905 - val_accuracy: 0.8950 - val_f1: 0.8962
# Epoch 582/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1436 - accuracy: 0.9672 - f1: 0.9673 - val_loss: 0.4444 - val_accuracy: 0.8924 - val_f1: 0.8941
# Epoch 583/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1372 - accuracy: 0.9683 - f1: 0.9683 - val_loss: 0.4176 - val_accuracy: 0.8938 - val_f1: 0.8941
# Epoch 584/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1492 - accuracy: 0.9654 - f1: 0.9648 - val_loss: 0.3841 - val_accuracy: 0.9014 - val_f1: 0.9023
# Epoch 585/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1577 - accuracy: 0.9626 - f1: 0.9626 - val_loss: 0.3888 - val_accuracy: 0.8952 - val_f1: 0.8982
# Epoch 586/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1348 - accuracy: 0.9707 - f1: 0.9707 - val_loss: 0.4310 - val_accuracy: 0.8998 - val_f1: 0.9007
# Epoch 587/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1386 - accuracy: 0.9683 - f1: 0.9682 - val_loss: 0.4079 - val_accuracy: 0.8888 - val_f1: 0.8904
# Epoch 588/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1394 - accuracy: 0.9683 - f1: 0.9685 - val_loss: 0.4147 - val_accuracy: 0.8932 - val_f1: 0.8940
# Epoch 589/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1303 - accuracy: 0.9700 - f1: 0.9698 - val_loss: 0.4446 - val_accuracy: 0.8980 - val_f1: 0.8996
# Epoch 590/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1429 - accuracy: 0.9664 - f1: 0.9658 - val_loss: 0.4054 - val_accuracy: 0.9004 - val_f1: 0.9010
# Epoch 591/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1617 - accuracy: 0.9612 - f1: 0.9613 - val_loss: 0.5089 - val_accuracy: 0.8817 - val_f1: 0.8830
# Epoch 592/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1456 - accuracy: 0.9669 - f1: 0.9657 - val_loss: 0.4746 - val_accuracy: 0.8751 - val_f1: 0.8762
# Epoch 593/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1731 - accuracy: 0.9580 - f1: 0.9577 - val_loss: 0.4439 - val_accuracy: 0.8936 - val_f1: 0.8949
# Epoch 594/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1471 - accuracy: 0.9675 - f1: 0.9671 - val_loss: 0.3726 - val_accuracy: 0.9050 - val_f1: 0.9054
# Epoch 595/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1352 - accuracy: 0.9707 - f1: 0.9708 - val_loss: 0.3704 - val_accuracy: 0.9010 - val_f1: 0.9022
# Epoch 596/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1231 - accuracy: 0.9736 - f1: 0.9740 - val_loss: 0.3962 - val_accuracy: 0.8996 - val_f1: 0.9005
# Epoch 597/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1154 - accuracy: 0.9767 - f1: 0.9767 - val_loss: 0.3806 - val_accuracy: 0.9024 - val_f1: 0.9034
# Epoch 598/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1239 - accuracy: 0.9724 - f1: 0.9725 - val_loss: 0.3975 - val_accuracy: 0.8982 - val_f1: 0.8995
# Epoch 599/600
# 176/176 [==============================] - 3s 19ms/step - loss: 0.1242 - accuracy: 0.9724 - f1: 0.9722 - val_loss: 0.5336 - val_accuracy: 0.8765 - val_f1: 0.8781
# Epoch 600/600
# 176/176 [==============================] - 3s 18ms/step - loss: 0.1282 - accuracy: 0.9716 - f1: 0.9716 - val_loss: 0.3731 - val_accuracy: 0.9014 - val_f1: 0.9020

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/cnn_fp8.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=256)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 49/49 [==============================] - 1s 9ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.84      0.89      0.87      2810
#          REM       0.91      0.89      0.90      1809
#        LIGHT       0.92      0.91      0.91      6233
#         DEEP       0.93      0.88      0.90      1598
#
#     accuracy                           0.90     12450
#    macro avg       0.90      0.90      0.90     12450
# weighted avg       0.90      0.90      0.90     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=False,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "batch_normalization": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 [
#                     null,
#                     3840,
#                     1
#                 ]
#             ]
#         }
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 10,
#                 1,
#                 5
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 5
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1916,
#                 5
#             ]
#         },
#         "operation_count": 95800
#     },
#     "q_activation": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 1916,
#                 5
#             ]
#         },
#         "operation_count": 9580
#     },
#     "max_pooling1d": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 958,
#                 5
#             ]
#         },
#         "operation_count": 9580
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 10,
#                 5,
#                 45
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 45
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 22,
#             "int_bits": 9,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 22,
#             "int_bits": 9,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 949,
#                 45
#             ]
#         },
#         "operation_count": 2135250
#     },
#     "max_pooling1d_1": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 22,
#                 "int_bits": 9,
#                 "is_signed": 1
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 22,
#             "int_bits": 9,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 474,
#                 45
#             ]
#         },
#         "operation_count": 42705
#     },
#     "q_activation_1": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 22,
#                 "int_bits": 9,
#                 "is_signed": 1
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 474,
#                 45
#             ]
#         },
#         "operation_count": 21330
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 30,
#                 45,
#                 25
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 25
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 27,
#             "int_bits": 14,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 27,
#             "int_bits": 14,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 445,
#                 25
#             ]
#         },
#         "operation_count": 15018750
#     },
#     "max_pooling1d_2": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 27,
#                 "int_bits": 14,
#                 "is_signed": 1
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 27,
#             "int_bits": 14,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 111,
#                 25
#             ]
#         },
#         "operation_count": 11125
#     },
#     "q_activation_2": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 27,
#                 "int_bits": 14,
#                 "is_signed": 1
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 111,
#                 25
#             ]
#         },
#         "operation_count": 2775
#     },
#     "batch_normalization_1": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 111,
#                 25
#             ]
#         }
#     },
#     "flatten": {
#         "layer_type": "Flatten",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 2775
#             ]
#         },
#         "operation_count": 2775
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 2775,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 11100
#     }
# }
# {'batch_normalization': {'energy': {'inputs': 7303.28,
#                                     'op_cost': 28416.0,
#                                     'outputs': 3.8,
#                                     'parameters': 15.22},
#                          'total': 15.22},
#  'batch_normalization_1': {'energy': {'inputs': 1319.92,
#                                       'op_cost': 20535.0,
#                                       'outputs': 5279.66,
#                                       'parameters': 197.8},
#                            'total': 197.8},
#  'flatten': {'energy': {'inputs': 5279.66,
#                         'op_cost': 0.0,
#                         'outputs': 5279.66,
#                         'parameters': 0.0},
#              'total': 5279.66},
#  'max_pooling1d': {'energy': {'inputs': 4556.94,
#                               'op_cost': 0.0,
#                               'outputs': 2278.47,
#                               'parameters': 0.0},
#                    'total': 4556.94},
#  'max_pooling1d_1': {'energy': {'inputs': 55839.63,
#                                 'op_cost': 0.0,
#                                 'outputs': 27893.19,
#                                 'parameters': 0.0},
#                      'total': 55839.63},
#  'max_pooling1d_2': {'energy': {'inputs': 17854.99,
#                                 'op_cost': 0.0,
#                                 'outputs': 4454.24,
#                                 'parameters': 0.0},
#                      'total': 17854.99},
#  'q_activation': {'energy': {'inputs': 18220.15,
#                              'op_cost': 0.0,
#                              'outputs': 4556.94,
#                              'parameters': 0.0},
#                   'total': 4556.94},
#  'q_activation_1': {'energy': {'inputs': 27893.19,
#                                'op_cost': 0.0,
#                                'outputs': 10144.71,
#                                'parameters': 0.0},
#                     'total': 10144.71},
#  'q_activation_2': {'energy': {'inputs': 4454.24,
#                                'op_cost': 0.0,
#                                'outputs': 1319.92,
#                                'parameters': 0.0},
#                     'total': 1319.92},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 440680.0,
#                          'outputs': 18220.15,
#                          'parameters': 30.43},
#               'total': 448013.71},
#  'q_conv1d_1': {'energy': {'inputs': 2278.47,
#                            'op_cost': 573848.44,
#                            'outputs': 55839.63,
#                            'parameters': 1095.49},
#                 'total': 577222.3999999999},
#  'q_conv1d_2': {'energy': {'inputs': 10144.71,
#                            'op_cost': 4270957.03,
#                            'outputs': 17854.99,
#                            'parameters': 16063.4},
#                 'total': 4297165.140000001},
#  'q_dense': {'energy': {'inputs': 5279.66,
#                         'op_cost': 51060.0,
#                         'outputs': 7.61,
#                         'parameters': 5283.46},
#              'total': 61623.119999999995}}
#
# Total energy: 5.48 uJ

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=True,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "batch_normalization": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 [
#                     null,
#                     3840,
#                     1
#                 ]
#             ]
#         }
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 10,
#                 1,
#                 5
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 5
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1916,
#                 5
#             ]
#         },
#         "operation_count": 95800
#     },
#     "q_activation": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1916,
#                 5
#             ]
#         },
#         "operation_count": 9580
#     },
#     "max_pooling1d": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 958,
#                 5
#             ]
#         },
#         "operation_count": 9580
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 10,
#                 5,
#                 45
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 45
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 949,
#                 45
#             ]
#         },
#         "operation_count": 2135250
#     },
#     "max_pooling1d_1": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 474,
#                 45
#             ]
#         },
#         "operation_count": 42705
#     },
#     "q_activation_1": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 474,
#                 45
#             ]
#         },
#         "operation_count": 21330
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 30,
#                 45,
#                 25
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 25
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 445,
#                 25
#             ]
#         },
#         "operation_count": 15018750
#     },
#     "max_pooling1d_2": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 111,
#                 25
#             ]
#         },
#         "operation_count": 11125
#     },
#     "q_activation_2": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 111,
#                 25
#             ]
#         },
#         "operation_count": 2775
#     },
#     "batch_normalization_1": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 111,
#                 25
#             ]
#         }
#     },
#     "flatten": {
#         "layer_type": "Flatten",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 2775
#             ]
#         },
#         "operation_count": 2775
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 2775,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 11100
#     }
# }
# {'batch_normalization': {'energy': {'inputs': 7303.28,
#                                     'op_cost': 28416.0,
#                                     'outputs': 3.8,
#                                     'parameters': 15.22},
#                          'total': 15.22},
#  'batch_normalization_1': {'energy': {'inputs': 5279.66,
#                                       'op_cost': 20535.0,
#                                       'outputs': 5279.66,
#                                       'parameters': 197.8},
#                            'total': 197.8},
#  'flatten': {'energy': {'inputs': 5279.66,
#                         'op_cost': 0.0,
#                         'outputs': 5279.66,
#                         'parameters': 0.0},
#              'total': 5279.66},
#  'max_pooling1d': {'energy': {'inputs': 18220.15,
#                               'op_cost': 0.0,
#                               'outputs': 9110.08,
#                               'parameters': 0.0},
#                    'total': 18220.15},
#  'max_pooling1d_1': {'energy': {'inputs': 81222.32,
#                                 'op_cost': 0.0,
#                                 'outputs': 40567.42,
#                                 'parameters': 0.0},
#                      'total': 81222.32},
#  'max_pooling1d_2': {'energy': {'inputs': 21160.48,
#                                 'op_cost': 0.0,
#                                 'outputs': 5279.66,
#                                 'parameters': 0.0},
#                      'total': 21160.48},
#  'q_activation': {'energy': {'inputs': 18220.15,
#                              'op_cost': 0.0,
#                              'outputs': 18220.15,
#                              'parameters': 0.0},
#                   'total': 18220.15},
#  'q_activation_1': {'energy': {'inputs': 40567.42,
#                                'op_cost': 0.0,
#                                'outputs': 40567.42,
#                                'parameters': 0.0},
#                     'total': 40567.42},
#  'q_activation_2': {'energy': {'inputs': 5279.66,
#                                'op_cost': 0.0,
#                                'outputs': 5279.66,
#                                'parameters': 0.0},
#                     'total': 5279.66},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 440680.0,
#                          'outputs': 18220.15,
#                          'parameters': 106.51},
#               'total': 448089.79},
#  'q_conv1d_1': {'energy': {'inputs': 9110.08,
#                            'op_cost': 9822150.0,
#                            'outputs': 81222.32,
#                            'parameters': 4366.75},
#                 'total': 9835626.83},
#  'q_conv1d_2': {'energy': {'inputs': 40567.42,
#                            'op_cost': 69086250.0,
#                            'outputs': 21160.48,
#                            'parameters': 64238.4},
#                 'total': 69191055.82},
#  'q_dense': {'energy': {'inputs': 5279.66,
#                         'op_cost': 51060.0,
#                         'outputs': 7.61,
#                         'parameters': 21118.64},
#              'total': 77458.3}}
#
# Total energy: 79.74 uJ
