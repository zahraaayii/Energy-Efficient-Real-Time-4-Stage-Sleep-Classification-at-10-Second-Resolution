# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, DepthwiseConv1D, GlobalAveragePooling1D, Reshape, Dropout
from tensorflow.keras.models import Model
from keras.layers import Conv1D, SeparableConv1D,GlobalAveragePooling1D,Add,concatenate, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\zazaz\AppData\Local\Temp\ipykernel_21452\912390324.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install QKeras
from qkeras import *
import pprint
from qkeras.autoqkeras import *
from qkeras import *
from qkeras.qtools import run_qtools
from qkeras.qtools import settings as qtools_settings

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))

        recall = TP / (Positives+K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

        precision = TP / (Pred_Positives+K.epsilon())
        return precision
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
def build_efficientnet_b2(input_shape, num_classes):
    model = Sequential()
    model.add(BatchNormalization(input_shape=input_shape))
    # Initial Stem
    model.add(QConv1D(filters=32, kernel_size=3, strides=2, padding='same', input_shape=input_shape,kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
    model.add(BatchNormalization())
    model.add(Activation('swish'))  # Swish activation function

    # Depthwise Separable Convolution Blocks
    block_settings = [
        {'repeats': 1, 'filters_in': 32, 'filters_out': 16, 'kernel_size': 3, 'strides': 1},
        {'repeats': 2, 'filters_in': 16, 'filters_out': 24, 'kernel_size': 3, 'strides': 2},
        {'repeats': 2, 'filters_in': 24, 'filters_out': 40, 'kernel_size': 3, 'strides': 2},
    ]

    for settings in block_settings:
        for _ in range(settings['repeats']):
            model.add(DepthwiseConv1D(kernel_size=settings['kernel_size'], strides=settings['strides'], padding='same'))
            model.add(BatchNormalization())
            model.add(Activation('swish'))  # Swish activation function
            model.add(QConv1D(filters=settings['filters_out'], kernel_size=1, padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
            model.add(BatchNormalization())
            model.add(Activation('swish'))  # Swish activation function

    # Global Average Pooling and Classifier
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(0.2))  # Dropout for regularization
    model.add(QDense(512, activation='relu',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
    model.add(QDense(256, activation='relu',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
    model.add(QDense(num_classes,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='softmax',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))

    return model

input_shape = (3840,1)
num_classes = 4 
model = build_efficientnet_b2(input_shape, num_classes)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 3840, 1)          4
#  ormalization)
#
#  q_conv1d (QConv1D)          (None, 1920, 32)          128
#
#  batch_normalization_1 (Batc  (None, 1920, 32)         128
#  hNormalization)
#
#  activation (Activation)     (None, 1920, 32)          0
#
#  depthwise_conv1d (Depthwise  (None, 1920, 32)         128
#  Conv1D)
#
#  batch_normalization_2 (Batc  (None, 1920, 32)         128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1920, 32)          0
#
#  q_conv1d_1 (QConv1D)        (None, 1920, 16)          528
#
#  batch_normalization_3 (Batc  (None, 1920, 16)         64
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1920, 16)          0
#
#  depthwise_conv1d_1 (Depthwi  (None, 960, 16)          64
#  seConv1D)
#
#  batch_normalization_4 (Batc  (None, 960, 16)          64
#  hNormalization)
#
#  activation_3 (Activation)   (None, 960, 16)           0
#
#  q_conv1d_2 (QConv1D)        (None, 960, 24)           408
#
#  batch_normalization_5 (Batc  (None, 960, 24)          96
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 3840, 1)          4
#  ormalization)
#
#  q_conv1d (QConv1D)          (None, 1920, 32)          128
#
#  batch_normalization_1 (Batc  (None, 1920, 32)         128
#  hNormalization)
#
#  activation (Activation)     (None, 1920, 32)          0
#
#  depthwise_conv1d (Depthwise  (None, 1920, 32)         128
#  Conv1D)
#
#  batch_normalization_2 (Batc  (None, 1920, 32)         128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1920, 32)          0
#
#  q_conv1d_1 (QConv1D)        (None, 1920, 16)          528
#
#  batch_normalization_3 (Batc  (None, 1920, 16)         64
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1920, 16)          0
#
#  depthwise_conv1d_1 (Depthwi  (None, 960, 16)          64
#  seConv1D)
#
#  batch_normalization_4 (Batc  (None, 960, 16)          64
#  hNormalization)
#
#  activation_3 (Activation)   (None, 960, 16)           0
#
#  q_conv1d_2 (QConv1D)        (None, 960, 24)           408
#
#  batch_normalization_5 (Batc  (None, 960, 24)          96
#  hNormalization)
#
#  activation_4 (Activation)   (None, 960, 24)           0
#
#  depthwise_conv1d_2 (Depthwi  (None, 480, 24)          96
#  seConv1D)
#
#  batch_normalization_6 (Batc  (None, 480, 24)          96
#  hNormalization)
#
#  activation_5 (Activation)   (None, 480, 24)           0
#
#  q_conv1d_3 (QConv1D)        (None, 480, 24)           600
#
#  batch_normalization_7 (Batc  (None, 480, 24)          96
#  hNormalization)
#
#  activation_6 (Activation)   (None, 480, 24)           0
#
#  depthwise_conv1d_3 (Depthwi  (None, 240, 24)          96
#  seConv1D)
#
#  batch_normalization_8 (Batc  (None, 240, 24)          96
#  hNormalization)
#
#  activation_7 (Activation)   (None, 240, 24)           0
#
#  q_conv1d_4 (QConv1D)        (None, 240, 40)           1000
#
#  batch_normalization_9 (Batc  (None, 240, 40)          160
#  hNormalization)
#
#  activation_8 (Activation)   (None, 240, 40)           0
#
#  depthwise_conv1d_4 (Depthwi  (None, 120, 40)          160
#  seConv1D)
#
#  batch_normalization_10 (Bat  (None, 120, 40)          160
#  chNormalization)
#
#  activation_9 (Activation)   (None, 120, 40)           0
#
#  q_conv1d_5 (QConv1D)        (None, 120, 40)           1640
#
#  batch_normalization_11 (Bat  (None, 120, 40)          160
#  chNormalization)
#
#  activation_10 (Activation)  (None, 120, 40)           0
#
#  global_average_pooling1d (G  (None, 40)               0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           (None, 40)                0
#
#  q_dense (QDense)            (None, 512)               20992
#
#  q_dense_1 (QDense)          (None, 256)               131328
#
#  q_dense_2 (QDense)          (None, 4)                 1028
#
# =================================================================
# Total params: 159,448
# Trainable params: 158,822
# Non-trainable params: 626
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/efficientnet_fp8.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=256,epochs=250,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/250
# 176/176 [==============================] - 15s 71ms/step - loss: 1.1914 - accuracy: 0.5235 - f1: 0.3938 - val_loss: 1.3601 - val_accuracy: 0.2241 - val_f1: 0.0000e+00
# Epoch 2/250
# 176/176 [==============================] - 12s 70ms/step - loss: 1.0926 - accuracy: 0.5457 - f1: 0.4579 - val_loss: 2.4415 - val_accuracy: 0.2241 - val_f1: 0.2243
# Epoch 3/250
# 176/176 [==============================] - 12s 67ms/step - loss: 1.0452 - accuracy: 0.5579 - f1: 0.4796 - val_loss: 1.7208 - val_accuracy: 0.2819 - val_f1: 0.1895
# Epoch 4/250
# 176/176 [==============================] - 12s 66ms/step - loss: 1.0045 - accuracy: 0.5760 - f1: 0.5105 - val_loss: 1.1915 - val_accuracy: 0.4805 - val_f1: 0.3700
# Epoch 5/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.9752 - accuracy: 0.5921 - f1: 0.5334 - val_loss: 1.2609 - val_accuracy: 0.4508 - val_f1: 0.3838
# Epoch 6/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.9544 - accuracy: 0.6033 - f1: 0.5527 - val_loss: 1.6818 - val_accuracy: 0.4122 - val_f1: 0.3793
# Epoch 7/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.9312 - accuracy: 0.6126 - f1: 0.5693 - val_loss: 1.2399 - val_accuracy: 0.4904 - val_f1: 0.4245
# Epoch 8/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.9105 - accuracy: 0.6273 - f1: 0.5896 - val_loss: 1.1288 - val_accuracy: 0.5498 - val_f1: 0.5088
# Epoch 9/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8940 - accuracy: 0.6348 - f1: 0.5999 - val_loss: 2.3615 - val_accuracy: 0.3269 - val_f1: 0.3195
# Epoch 10/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8769 - accuracy: 0.6445 - f1: 0.6146 - val_loss: 1.1065 - val_accuracy: 0.5697 - val_f1: 0.5646
# Epoch 11/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8569 - accuracy: 0.6526 - f1: 0.6272 - val_loss: 1.3561 - val_accuracy: 0.4498 - val_f1: 0.4184
# Epoch 12/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8524 - accuracy: 0.6548 - f1: 0.6298 - val_loss: 0.9026 - val_accuracy: 0.6263 - val_f1: 0.6153
# Epoch 13/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.8395 - accuracy: 0.6608 - f1: 0.6362 - val_loss: 0.9786 - val_accuracy: 0.6177 - val_f1: 0.6036
# Epoch 14/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8282 - accuracy: 0.6659 - f1: 0.6442 - val_loss: 1.6154 - val_accuracy: 0.4558 - val_f1: 0.4294
# Epoch 15/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8156 - accuracy: 0.6714 - f1: 0.6536 - val_loss: 1.3627 - val_accuracy: 0.5596 - val_f1: 0.5491
# Epoch 16/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8085 - accuracy: 0.6764 - f1: 0.6582 - val_loss: 1.3012 - val_accuracy: 0.5127 - val_f1: 0.4821
# Epoch 17/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.8033 - accuracy: 0.6780 - f1: 0.6589 - val_loss: 0.9011 - val_accuracy: 0.6251 - val_f1: 0.6062
# Epoch 18/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7917 - accuracy: 0.6815 - f1: 0.6652 - val_loss: 0.9105 - val_accuracy: 0.6351 - val_f1: 0.6272
# Epoch 19/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7810 - accuracy: 0.6859 - f1: 0.6702 - val_loss: 0.9340 - val_accuracy: 0.6163 - val_f1: 0.6102
# Epoch 20/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7831 - accuracy: 0.6859 - f1: 0.6688 - val_loss: 0.8491 - val_accuracy: 0.6522 - val_f1: 0.6301
# Epoch 21/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7730 - accuracy: 0.6913 - f1: 0.6759 - val_loss: 1.1254 - val_accuracy: 0.5723 - val_f1: 0.5579
# Epoch 22/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.7685 - accuracy: 0.6919 - f1: 0.6778 - val_loss: 1.2665 - val_accuracy: 0.5490 - val_f1: 0.5306
# Epoch 23/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.7605 - accuracy: 0.6990 - f1: 0.6848 - val_loss: 1.1969 - val_accuracy: 0.5390 - val_f1: 0.5073
# Epoch 24/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.7524 - accuracy: 0.6998 - f1: 0.6886 - val_loss: 0.9106 - val_accuracy: 0.6251 - val_f1: 0.6149
# Epoch 25/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.7461 - accuracy: 0.7020 - f1: 0.6895 - val_loss: 0.9328 - val_accuracy: 0.6281 - val_f1: 0.6131
# Epoch 26/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7423 - accuracy: 0.7021 - f1: 0.6885 - val_loss: 1.0902 - val_accuracy: 0.5904 - val_f1: 0.5848
# Epoch 27/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7366 - accuracy: 0.7076 - f1: 0.6956 - val_loss: 0.8940 - val_accuracy: 0.6351 - val_f1: 0.6219
# Epoch 28/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7329 - accuracy: 0.7077 - f1: 0.6955 - val_loss: 0.8114 - val_accuracy: 0.6691 - val_f1: 0.6486
# Epoch 29/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7271 - accuracy: 0.7111 - f1: 0.6983 - val_loss: 0.8384 - val_accuracy: 0.6681 - val_f1: 0.6558
# Epoch 30/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7214 - accuracy: 0.7165 - f1: 0.7051 - val_loss: 1.0980 - val_accuracy: 0.5936 - val_f1: 0.5824
# Epoch 31/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7155 - accuracy: 0.7191 - f1: 0.7071 - val_loss: 1.1313 - val_accuracy: 0.5502 - val_f1: 0.5280
# Epoch 32/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7132 - accuracy: 0.7190 - f1: 0.7088 - val_loss: 0.8436 - val_accuracy: 0.6683 - val_f1: 0.6621
# Epoch 33/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.7130 - accuracy: 0.7181 - f1: 0.7060 - val_loss: 1.5726 - val_accuracy: 0.5287 - val_f1: 0.5095
# Epoch 34/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.7098 - accuracy: 0.7189 - f1: 0.7085 - val_loss: 1.3363 - val_accuracy: 0.5518 - val_f1: 0.5373
# Epoch 35/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7012 - accuracy: 0.7226 - f1: 0.7118 - val_loss: 0.9638 - val_accuracy: 0.6384 - val_f1: 0.6320
# Epoch 36/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7001 - accuracy: 0.7221 - f1: 0.7111 - val_loss: 0.9362 - val_accuracy: 0.6211 - val_f1: 0.6026
# Epoch 37/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.6904 - accuracy: 0.7287 - f1: 0.7158 - val_loss: 0.7667 - val_accuracy: 0.6867 - val_f1: 0.6664
# Epoch 38/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6906 - accuracy: 0.7264 - f1: 0.7180 - val_loss: 0.8155 - val_accuracy: 0.6689 - val_f1: 0.6533
# Epoch 39/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.6844 - accuracy: 0.7285 - f1: 0.7197 - val_loss: 1.1606 - val_accuracy: 0.5803 - val_f1: 0.5659
# Epoch 40/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6852 - accuracy: 0.7296 - f1: 0.7211 - val_loss: 0.9111 - val_accuracy: 0.6307 - val_f1: 0.6285
# Epoch 41/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6778 - accuracy: 0.7321 - f1: 0.7232 - val_loss: 0.9190 - val_accuracy: 0.6325 - val_f1: 0.6170
# Epoch 42/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.6755 - accuracy: 0.7334 - f1: 0.7241 - val_loss: 1.2862 - val_accuracy: 0.5759 - val_f1: 0.5701
# Epoch 43/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.6691 - accuracy: 0.7363 - f1: 0.7283 - val_loss: 1.1209 - val_accuracy: 0.5797 - val_f1: 0.5713
# Epoch 44/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6732 - accuracy: 0.7361 - f1: 0.7263 - val_loss: 0.7017 - val_accuracy: 0.7217 - val_f1: 0.7106
# Epoch 45/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6668 - accuracy: 0.7369 - f1: 0.7271 - val_loss: 0.7490 - val_accuracy: 0.7056 - val_f1: 0.6947
# Epoch 46/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6632 - accuracy: 0.7413 - f1: 0.7315 - val_loss: 0.9941 - val_accuracy: 0.5928 - val_f1: 0.5661
# Epoch 47/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.6572 - accuracy: 0.7416 - f1: 0.7344 - val_loss: 2.4166 - val_accuracy: 0.4470 - val_f1: 0.4416
# Epoch 48/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.6592 - accuracy: 0.7404 - f1: 0.7324 - val_loss: 0.9135 - val_accuracy: 0.6410 - val_f1: 0.6246
# Epoch 49/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.6539 - accuracy: 0.7433 - f1: 0.7348 - val_loss: 0.8350 - val_accuracy: 0.6853 - val_f1: 0.6694
# Epoch 50/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6546 - accuracy: 0.7404 - f1: 0.7331 - val_loss: 1.6237 - val_accuracy: 0.5020 - val_f1: 0.4897
# Epoch 51/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.6455 - accuracy: 0.7441 - f1: 0.7366 - val_loss: 0.8849 - val_accuracy: 0.6476 - val_f1: 0.6346
# Epoch 52/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.6475 - accuracy: 0.7443 - f1: 0.7364 - val_loss: 0.7741 - val_accuracy: 0.6884 - val_f1: 0.6793
# Epoch 53/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6444 - accuracy: 0.7465 - f1: 0.7398 - val_loss: 0.8279 - val_accuracy: 0.6811 - val_f1: 0.6760
# Epoch 54/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6414 - accuracy: 0.7482 - f1: 0.7410 - val_loss: 0.9391 - val_accuracy: 0.6203 - val_f1: 0.6094
# Epoch 55/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6350 - accuracy: 0.7496 - f1: 0.7424 - val_loss: 0.8351 - val_accuracy: 0.6582 - val_f1: 0.6509
# Epoch 56/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.6379 - accuracy: 0.7491 - f1: 0.7424 - val_loss: 0.8893 - val_accuracy: 0.6522 - val_f1: 0.6427
# Epoch 57/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.6355 - accuracy: 0.7490 - f1: 0.7414 - val_loss: 0.7772 - val_accuracy: 0.6825 - val_f1: 0.6720
# Epoch 58/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.6331 - accuracy: 0.7493 - f1: 0.7413 - val_loss: 0.7509 - val_accuracy: 0.6986 - val_f1: 0.6896
# Epoch 59/250
# 176/176 [==============================] - 11s 63ms/step - loss: 0.6324 - accuracy: 0.7538 - f1: 0.7457 - val_loss: 1.2558 - val_accuracy: 0.5606 - val_f1: 0.5524
# Epoch 60/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6271 - accuracy: 0.7522 - f1: 0.7448 - val_loss: 1.0927 - val_accuracy: 0.5924 - val_f1: 0.5771
# Epoch 61/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.6300 - accuracy: 0.7534 - f1: 0.7457 - val_loss: 0.8450 - val_accuracy: 0.6641 - val_f1: 0.6535
# Epoch 62/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6212 - accuracy: 0.7553 - f1: 0.7498 - val_loss: 0.8515 - val_accuracy: 0.6721 - val_f1: 0.6636
# Epoch 63/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6173 - accuracy: 0.7576 - f1: 0.7509 - val_loss: 0.7434 - val_accuracy: 0.7072 - val_f1: 0.7029
# Epoch 64/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6182 - accuracy: 0.7586 - f1: 0.7515 - val_loss: 0.7268 - val_accuracy: 0.7157 - val_f1: 0.7049
# Epoch 65/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6167 - accuracy: 0.7575 - f1: 0.7511 - val_loss: 0.6953 - val_accuracy: 0.7303 - val_f1: 0.7248
# Epoch 66/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6119 - accuracy: 0.7607 - f1: 0.7544 - val_loss: 0.8855 - val_accuracy: 0.6693 - val_f1: 0.6605
# Epoch 67/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6125 - accuracy: 0.7585 - f1: 0.7526 - val_loss: 0.8455 - val_accuracy: 0.6653 - val_f1: 0.6600
# Epoch 68/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.6113 - accuracy: 0.7601 - f1: 0.7538 - val_loss: 0.7475 - val_accuracy: 0.7028 - val_f1: 0.6996
# Epoch 69/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.6092 - accuracy: 0.7606 - f1: 0.7542 - val_loss: 1.2288 - val_accuracy: 0.5823 - val_f1: 0.5738
# Epoch 70/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.6094 - accuracy: 0.7610 - f1: 0.7546 - val_loss: 0.8817 - val_accuracy: 0.6496 - val_f1: 0.6312
# Epoch 71/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.6060 - accuracy: 0.7625 - f1: 0.7545 - val_loss: 1.0890 - val_accuracy: 0.6058 - val_f1: 0.5968
# Epoch 72/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6067 - accuracy: 0.7632 - f1: 0.7554 - val_loss: 1.0042 - val_accuracy: 0.6155 - val_f1: 0.6049
# Epoch 73/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6022 - accuracy: 0.7638 - f1: 0.7552 - val_loss: 0.9348 - val_accuracy: 0.6343 - val_f1: 0.6080
# Epoch 74/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.6063 - accuracy: 0.7623 - f1: 0.7561 - val_loss: 0.9171 - val_accuracy: 0.6199 - val_f1: 0.6047
# Epoch 75/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5963 - accuracy: 0.7669 - f1: 0.7599 - val_loss: 1.2736 - val_accuracy: 0.5484 - val_f1: 0.5434
# Epoch 76/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5941 - accuracy: 0.7673 - f1: 0.7609 - val_loss: 0.7512 - val_accuracy: 0.6990 - val_f1: 0.6937
# Epoch 77/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5988 - accuracy: 0.7626 - f1: 0.7578 - val_loss: 1.2211 - val_accuracy: 0.5600 - val_f1: 0.5493
# Epoch 78/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5932 - accuracy: 0.7693 - f1: 0.7631 - val_loss: 0.7651 - val_accuracy: 0.7068 - val_f1: 0.7049
# Epoch 79/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5897 - accuracy: 0.7700 - f1: 0.7628 - val_loss: 0.7415 - val_accuracy: 0.7040 - val_f1: 0.6936
# Epoch 80/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5927 - accuracy: 0.7698 - f1: 0.7637 - val_loss: 0.9868 - val_accuracy: 0.6500 - val_f1: 0.6438
# Epoch 81/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5872 - accuracy: 0.7702 - f1: 0.7640 - val_loss: 0.8088 - val_accuracy: 0.6799 - val_f1: 0.6768
# Epoch 82/250
# 176/176 [==============================] - 11s 64ms/step - loss: 0.5902 - accuracy: 0.7694 - f1: 0.7633 - val_loss: 2.0184 - val_accuracy: 0.4681 - val_f1: 0.4583
# Epoch 83/250
# 176/176 [==============================] - 11s 61ms/step - loss: 0.5869 - accuracy: 0.7690 - f1: 0.7637 - val_loss: 2.3737 - val_accuracy: 0.4078 - val_f1: 0.3967
# Epoch 84/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5875 - accuracy: 0.7678 - f1: 0.7617 - val_loss: 1.2561 - val_accuracy: 0.5787 - val_f1: 0.5753
# Epoch 85/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5869 - accuracy: 0.7702 - f1: 0.7665 - val_loss: 0.9295 - val_accuracy: 0.6693 - val_f1: 0.6622
# Epoch 86/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5781 - accuracy: 0.7734 - f1: 0.7666 - val_loss: 1.2174 - val_accuracy: 0.5510 - val_f1: 0.5379
# Epoch 87/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5826 - accuracy: 0.7725 - f1: 0.7652 - val_loss: 1.4523 - val_accuracy: 0.5002 - val_f1: 0.4885
# Epoch 88/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5805 - accuracy: 0.7734 - f1: 0.7679 - val_loss: 0.9677 - val_accuracy: 0.6448 - val_f1: 0.6307
# Epoch 89/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5770 - accuracy: 0.7759 - f1: 0.7705 - val_loss: 0.7179 - val_accuracy: 0.7199 - val_f1: 0.7118
# Epoch 90/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5817 - accuracy: 0.7722 - f1: 0.7659 - val_loss: 1.0294 - val_accuracy: 0.6297 - val_f1: 0.6198
# Epoch 91/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5768 - accuracy: 0.7757 - f1: 0.7689 - val_loss: 0.7325 - val_accuracy: 0.7120 - val_f1: 0.7088
# Epoch 92/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5794 - accuracy: 0.7738 - f1: 0.7681 - val_loss: 0.7525 - val_accuracy: 0.7012 - val_f1: 0.6894
# Epoch 93/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5782 - accuracy: 0.7736 - f1: 0.7686 - val_loss: 0.8470 - val_accuracy: 0.6741 - val_f1: 0.6628
# Epoch 94/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5722 - accuracy: 0.7751 - f1: 0.7697 - val_loss: 0.6928 - val_accuracy: 0.7311 - val_f1: 0.7283
# Epoch 95/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5748 - accuracy: 0.7750 - f1: 0.7681 - val_loss: 0.9162 - val_accuracy: 0.6554 - val_f1: 0.6509
# Epoch 96/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5687 - accuracy: 0.7779 - f1: 0.7730 - val_loss: 0.9068 - val_accuracy: 0.6388 - val_f1: 0.6300
# Epoch 97/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5758 - accuracy: 0.7762 - f1: 0.7722 - val_loss: 0.7394 - val_accuracy: 0.7100 - val_f1: 0.7031
# Epoch 98/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5686 - accuracy: 0.7791 - f1: 0.7722 - val_loss: 0.8187 - val_accuracy: 0.6861 - val_f1: 0.6798
# Epoch 99/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5689 - accuracy: 0.7778 - f1: 0.7735 - val_loss: 0.8025 - val_accuracy: 0.6886 - val_f1: 0.6808
# Epoch 100/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5617 - accuracy: 0.7803 - f1: 0.7765 - val_loss: 1.4355 - val_accuracy: 0.5725 - val_f1: 0.5634
# Epoch 101/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5579 - accuracy: 0.7831 - f1: 0.7789 - val_loss: 0.8627 - val_accuracy: 0.6759 - val_f1: 0.6717
# Epoch 102/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5613 - accuracy: 0.7802 - f1: 0.7757 - val_loss: 0.7718 - val_accuracy: 0.6922 - val_f1: 0.6838
# Epoch 103/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5622 - accuracy: 0.7799 - f1: 0.7746 - val_loss: 0.7577 - val_accuracy: 0.6932 - val_f1: 0.6892
# Epoch 104/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5629 - accuracy: 0.7802 - f1: 0.7739 - val_loss: 1.0553 - val_accuracy: 0.6394 - val_f1: 0.6373
# Epoch 105/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5603 - accuracy: 0.7825 - f1: 0.7769 - val_loss: 0.7702 - val_accuracy: 0.6954 - val_f1: 0.6901
# Epoch 106/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5582 - accuracy: 0.7816 - f1: 0.7775 - val_loss: 0.6317 - val_accuracy: 0.7584 - val_f1: 0.7523
# Epoch 107/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5538 - accuracy: 0.7847 - f1: 0.7799 - val_loss: 0.9922 - val_accuracy: 0.6466 - val_f1: 0.6405
# Epoch 108/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5563 - accuracy: 0.7838 - f1: 0.7776 - val_loss: 1.1810 - val_accuracy: 0.5635 - val_f1: 0.5550
# Epoch 109/250
# 176/176 [==============================] - 11s 61ms/step - loss: 0.5537 - accuracy: 0.7851 - f1: 0.7804 - val_loss: 1.5068 - val_accuracy: 0.5629 - val_f1: 0.5576
# Epoch 110/250
# 176/176 [==============================] - 11s 61ms/step - loss: 0.5517 - accuracy: 0.7871 - f1: 0.7824 - val_loss: 0.7061 - val_accuracy: 0.7319 - val_f1: 0.7243
# Epoch 111/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5513 - accuracy: 0.7840 - f1: 0.7790 - val_loss: 0.7932 - val_accuracy: 0.6857 - val_f1: 0.6773
# Epoch 112/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5512 - accuracy: 0.7848 - f1: 0.7781 - val_loss: 0.6860 - val_accuracy: 0.7299 - val_f1: 0.7259
# Epoch 113/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5487 - accuracy: 0.7863 - f1: 0.7816 - val_loss: 0.7529 - val_accuracy: 0.7056 - val_f1: 0.6995
# Epoch 114/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5517 - accuracy: 0.7838 - f1: 0.7784 - val_loss: 0.7250 - val_accuracy: 0.7139 - val_f1: 0.7077
# Epoch 115/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5513 - accuracy: 0.7858 - f1: 0.7793 - val_loss: 0.9020 - val_accuracy: 0.6470 - val_f1: 0.6423
# Epoch 116/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5474 - accuracy: 0.7872 - f1: 0.7814 - val_loss: 0.5821 - val_accuracy: 0.7683 - val_f1: 0.7645
# Epoch 117/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5523 - accuracy: 0.7839 - f1: 0.7797 - val_loss: 1.1436 - val_accuracy: 0.6034 - val_f1: 0.5997
# Epoch 118/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5492 - accuracy: 0.7853 - f1: 0.7814 - val_loss: 0.8528 - val_accuracy: 0.6544 - val_f1: 0.6389
# Epoch 119/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5399 - accuracy: 0.7902 - f1: 0.7851 - val_loss: 0.7782 - val_accuracy: 0.7020 - val_f1: 0.6982
# Epoch 120/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5419 - accuracy: 0.7909 - f1: 0.7856 - val_loss: 0.8254 - val_accuracy: 0.6606 - val_f1: 0.6513
# Epoch 121/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5397 - accuracy: 0.7900 - f1: 0.7863 - val_loss: 0.8885 - val_accuracy: 0.6733 - val_f1: 0.6643
# Epoch 122/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5397 - accuracy: 0.7897 - f1: 0.7844 - val_loss: 0.6511 - val_accuracy: 0.7474 - val_f1: 0.7413
# Epoch 123/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5352 - accuracy: 0.7920 - f1: 0.7881 - val_loss: 0.6667 - val_accuracy: 0.7422 - val_f1: 0.7320
# Epoch 124/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5408 - accuracy: 0.7874 - f1: 0.7849 - val_loss: 0.7717 - val_accuracy: 0.6992 - val_f1: 0.6919
# Epoch 125/250
# 176/176 [==============================] - 13s 72ms/step - loss: 0.5327 - accuracy: 0.7943 - f1: 0.7885 - val_loss: 0.6726 - val_accuracy: 0.7384 - val_f1: 0.7335
# Epoch 126/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5330 - accuracy: 0.7934 - f1: 0.7878 - val_loss: 1.1709 - val_accuracy: 0.5871 - val_f1: 0.5791
# Epoch 127/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5376 - accuracy: 0.7910 - f1: 0.7860 - val_loss: 0.7145 - val_accuracy: 0.7239 - val_f1: 0.7209
# Epoch 128/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.5305 - accuracy: 0.7943 - f1: 0.7900 - val_loss: 0.9215 - val_accuracy: 0.6492 - val_f1: 0.6411
# Epoch 129/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5296 - accuracy: 0.7938 - f1: 0.7899 - val_loss: 0.6615 - val_accuracy: 0.7448 - val_f1: 0.7439
# Epoch 130/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5334 - accuracy: 0.7932 - f1: 0.7888 - val_loss: 1.1938 - val_accuracy: 0.5592 - val_f1: 0.5406
# Epoch 131/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5340 - accuracy: 0.7905 - f1: 0.7868 - val_loss: 1.2609 - val_accuracy: 0.5815 - val_f1: 0.5718
# Epoch 132/250
# 176/176 [==============================] - 13s 71ms/step - loss: 0.5297 - accuracy: 0.7930 - f1: 0.7894 - val_loss: 0.6258 - val_accuracy: 0.7574 - val_f1: 0.7541
# Epoch 133/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5287 - accuracy: 0.7944 - f1: 0.7901 - val_loss: 0.7049 - val_accuracy: 0.7141 - val_f1: 0.7061
# Epoch 134/250
# 176/176 [==============================] - 12s 71ms/step - loss: 0.5319 - accuracy: 0.7931 - f1: 0.7897 - val_loss: 0.9359 - val_accuracy: 0.6193 - val_f1: 0.6047
# Epoch 135/250
# 176/176 [==============================] - 13s 71ms/step - loss: 0.5205 - accuracy: 0.7971 - f1: 0.7932 - val_loss: 1.0746 - val_accuracy: 0.5847 - val_f1: 0.5700
# Epoch 136/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5268 - accuracy: 0.7965 - f1: 0.7910 - val_loss: 0.7591 - val_accuracy: 0.7064 - val_f1: 0.6984
# Epoch 137/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5279 - accuracy: 0.7938 - f1: 0.7909 - val_loss: 0.6114 - val_accuracy: 0.7554 - val_f1: 0.7524
# Epoch 138/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5261 - accuracy: 0.7952 - f1: 0.7911 - val_loss: 0.6450 - val_accuracy: 0.7510 - val_f1: 0.7473
# Epoch 139/250
# 176/176 [==============================] - 12s 71ms/step - loss: 0.5229 - accuracy: 0.7953 - f1: 0.7920 - val_loss: 0.7199 - val_accuracy: 0.7199 - val_f1: 0.7139
# Epoch 140/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.5213 - accuracy: 0.7975 - f1: 0.7933 - val_loss: 0.6073 - val_accuracy: 0.7643 - val_f1: 0.7583
# Epoch 141/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5283 - accuracy: 0.7953 - f1: 0.7922 - val_loss: 1.1657 - val_accuracy: 0.5458 - val_f1: 0.5361
# Epoch 142/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5244 - accuracy: 0.7960 - f1: 0.7925 - val_loss: 0.6664 - val_accuracy: 0.7319 - val_f1: 0.7298
# Epoch 143/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5207 - accuracy: 0.7986 - f1: 0.7949 - val_loss: 0.6767 - val_accuracy: 0.7339 - val_f1: 0.7326
# Epoch 144/250
# 176/176 [==============================] - 12s 71ms/step - loss: 0.5140 - accuracy: 0.7994 - f1: 0.7967 - val_loss: 0.6850 - val_accuracy: 0.7299 - val_f1: 0.7240
# Epoch 145/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5225 - accuracy: 0.7980 - f1: 0.7947 - val_loss: 0.8206 - val_accuracy: 0.6837 - val_f1: 0.6726
# Epoch 146/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5148 - accuracy: 0.8007 - f1: 0.7970 - val_loss: 0.7786 - val_accuracy: 0.6926 - val_f1: 0.6819
# Epoch 147/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5192 - accuracy: 0.7993 - f1: 0.7953 - val_loss: 0.7706 - val_accuracy: 0.6946 - val_f1: 0.6887
# Epoch 148/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5146 - accuracy: 0.8010 - f1: 0.7968 - val_loss: 0.7333 - val_accuracy: 0.7157 - val_f1: 0.7108
# Epoch 149/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5150 - accuracy: 0.8007 - f1: 0.7965 - val_loss: 0.8817 - val_accuracy: 0.6582 - val_f1: 0.6506
# Epoch 150/250
# 176/176 [==============================] - 13s 71ms/step - loss: 0.5189 - accuracy: 0.7976 - f1: 0.7943 - val_loss: 0.6442 - val_accuracy: 0.7478 - val_f1: 0.7477
# Epoch 151/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5156 - accuracy: 0.7993 - f1: 0.7963 - val_loss: 0.8623 - val_accuracy: 0.6697 - val_f1: 0.6648
# Epoch 152/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5135 - accuracy: 0.8020 - f1: 0.7979 - val_loss: 0.6746 - val_accuracy: 0.7333 - val_f1: 0.7288
# Epoch 153/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5121 - accuracy: 0.8011 - f1: 0.7963 - val_loss: 0.7132 - val_accuracy: 0.7143 - val_f1: 0.7041
# Epoch 154/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5130 - accuracy: 0.8008 - f1: 0.7969 - val_loss: 0.8129 - val_accuracy: 0.7024 - val_f1: 0.6935
# Epoch 155/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5077 - accuracy: 0.8037 - f1: 0.8005 - val_loss: 1.2579 - val_accuracy: 0.5325 - val_f1: 0.5179
# Epoch 156/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5108 - accuracy: 0.8030 - f1: 0.7992 - val_loss: 0.6710 - val_accuracy: 0.7420 - val_f1: 0.7385
# Epoch 157/250
# 176/176 [==============================] - 12s 71ms/step - loss: 0.5107 - accuracy: 0.8004 - f1: 0.7975 - val_loss: 1.9647 - val_accuracy: 0.5004 - val_f1: 0.4921
# Epoch 158/250
# 176/176 [==============================] - 13s 72ms/step - loss: 0.5094 - accuracy: 0.8032 - f1: 0.8011 - val_loss: 1.4287 - val_accuracy: 0.5618 - val_f1: 0.5583
# Epoch 159/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5082 - accuracy: 0.8024 - f1: 0.7982 - val_loss: 0.7042 - val_accuracy: 0.7245 - val_f1: 0.7173
# Epoch 160/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5104 - accuracy: 0.8027 - f1: 0.7984 - val_loss: 0.7336 - val_accuracy: 0.7175 - val_f1: 0.7148
# Epoch 161/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5103 - accuracy: 0.8019 - f1: 0.7987 - val_loss: 0.8922 - val_accuracy: 0.6703 - val_f1: 0.6694
# Epoch 162/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5090 - accuracy: 0.8038 - f1: 0.8007 - val_loss: 0.7132 - val_accuracy: 0.7283 - val_f1: 0.7237
# Epoch 163/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5064 - accuracy: 0.8026 - f1: 0.7992 - val_loss: 1.0416 - val_accuracy: 0.6012 - val_f1: 0.5914
# Epoch 164/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5097 - accuracy: 0.8036 - f1: 0.8000 - val_loss: 0.6588 - val_accuracy: 0.7438 - val_f1: 0.7377
# Epoch 165/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5040 - accuracy: 0.8034 - f1: 0.7991 - val_loss: 0.8302 - val_accuracy: 0.6966 - val_f1: 0.6936
# Epoch 166/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5051 - accuracy: 0.8030 - f1: 0.8001 - val_loss: 0.6497 - val_accuracy: 0.7494 - val_f1: 0.7441
# Epoch 167/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5030 - accuracy: 0.8040 - f1: 0.8011 - val_loss: 0.8283 - val_accuracy: 0.6954 - val_f1: 0.6919
# Epoch 168/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5013 - accuracy: 0.8055 - f1: 0.8018 - val_loss: 0.7664 - val_accuracy: 0.7098 - val_f1: 0.7072
# Epoch 169/250
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4991 - accuracy: 0.8062 - f1: 0.8028 - val_loss: 0.8264 - val_accuracy: 0.6894 - val_f1: 0.6872
# Epoch 170/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.5020 - accuracy: 0.8044 - f1: 0.8003 - val_loss: 0.7301 - val_accuracy: 0.7153 - val_f1: 0.7167
# Epoch 171/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5031 - accuracy: 0.8060 - f1: 0.8015 - val_loss: 0.6131 - val_accuracy: 0.7620 - val_f1: 0.7608
# Epoch 172/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.5036 - accuracy: 0.8047 - f1: 0.8021 - val_loss: 1.1346 - val_accuracy: 0.6098 - val_f1: 0.6023
# Epoch 173/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4979 - accuracy: 0.8050 - f1: 0.8007 - val_loss: 0.9540 - val_accuracy: 0.6452 - val_f1: 0.6363
# Epoch 174/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5021 - accuracy: 0.8065 - f1: 0.8032 - val_loss: 0.8579 - val_accuracy: 0.6741 - val_f1: 0.6650
# Epoch 175/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.5043 - accuracy: 0.8041 - f1: 0.8002 - val_loss: 0.6878 - val_accuracy: 0.7193 - val_f1: 0.7112
# Epoch 176/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4978 - accuracy: 0.8077 - f1: 0.8043 - val_loss: 1.0877 - val_accuracy: 0.6454 - val_f1: 0.6418
# Epoch 177/250
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4970 - accuracy: 0.8069 - f1: 0.8038 - val_loss: 0.8548 - val_accuracy: 0.6671 - val_f1: 0.6605
# Epoch 178/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4945 - accuracy: 0.8090 - f1: 0.8065 - val_loss: 0.6922 - val_accuracy: 0.7396 - val_f1: 0.7365
# Epoch 179/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4945 - accuracy: 0.8069 - f1: 0.8038 - val_loss: 0.6104 - val_accuracy: 0.7586 - val_f1: 0.7522
# Epoch 180/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4918 - accuracy: 0.8094 - f1: 0.8072 - val_loss: 0.7161 - val_accuracy: 0.7223 - val_f1: 0.7191
# Epoch 181/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4938 - accuracy: 0.8094 - f1: 0.8062 - val_loss: 0.6685 - val_accuracy: 0.7466 - val_f1: 0.7436
# Epoch 182/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4928 - accuracy: 0.8100 - f1: 0.8059 - val_loss: 0.7969 - val_accuracy: 0.6849 - val_f1: 0.6784
# Epoch 183/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4956 - accuracy: 0.8090 - f1: 0.8041 - val_loss: 0.7448 - val_accuracy: 0.7151 - val_f1: 0.7093
# Epoch 184/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4947 - accuracy: 0.8093 - f1: 0.8067 - val_loss: 0.8208 - val_accuracy: 0.6867 - val_f1: 0.6838
# Epoch 185/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.4927 - accuracy: 0.8101 - f1: 0.8063 - val_loss: 0.8976 - val_accuracy: 0.6791 - val_f1: 0.6768
# Epoch 186/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4902 - accuracy: 0.8108 - f1: 0.8074 - val_loss: 1.6135 - val_accuracy: 0.5484 - val_f1: 0.5449
# Epoch 187/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4854 - accuracy: 0.8126 - f1: 0.8084 - val_loss: 0.8841 - val_accuracy: 0.6725 - val_f1: 0.6658
# Epoch 188/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4893 - accuracy: 0.8127 - f1: 0.8098 - val_loss: 0.6068 - val_accuracy: 0.7667 - val_f1: 0.7657
# Epoch 189/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4907 - accuracy: 0.8098 - f1: 0.8075 - val_loss: 0.7731 - val_accuracy: 0.7038 - val_f1: 0.6996
# Epoch 190/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.4855 - accuracy: 0.8134 - f1: 0.8107 - val_loss: 0.6162 - val_accuracy: 0.7677 - val_f1: 0.7639
# Epoch 191/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4942 - accuracy: 0.8094 - f1: 0.8055 - val_loss: 0.9056 - val_accuracy: 0.6647 - val_f1: 0.6613
# Epoch 192/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4890 - accuracy: 0.8105 - f1: 0.8094 - val_loss: 0.7139 - val_accuracy: 0.7195 - val_f1: 0.7140
# Epoch 193/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4854 - accuracy: 0.8125 - f1: 0.8095 - val_loss: 0.8041 - val_accuracy: 0.6934 - val_f1: 0.6896
# Epoch 194/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.4847 - accuracy: 0.8132 - f1: 0.8090 - val_loss: 0.8202 - val_accuracy: 0.6767 - val_f1: 0.6710
# Epoch 195/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4900 - accuracy: 0.8101 - f1: 0.8073 - val_loss: 0.7520 - val_accuracy: 0.7183 - val_f1: 0.7099
# Epoch 196/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4875 - accuracy: 0.8113 - f1: 0.8076 - val_loss: 0.6704 - val_accuracy: 0.7357 - val_f1: 0.7333
# Epoch 197/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4853 - accuracy: 0.8139 - f1: 0.8092 - val_loss: 0.7567 - val_accuracy: 0.7108 - val_f1: 0.7073
# Epoch 198/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4896 - accuracy: 0.8099 - f1: 0.8067 - val_loss: 0.8501 - val_accuracy: 0.6871 - val_f1: 0.6817
# Epoch 199/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4839 - accuracy: 0.8119 - f1: 0.8089 - val_loss: 0.6664 - val_accuracy: 0.7376 - val_f1: 0.7306
# Epoch 200/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4796 - accuracy: 0.8161 - f1: 0.8140 - val_loss: 0.6851 - val_accuracy: 0.7412 - val_f1: 0.7411
# Epoch 201/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4788 - accuracy: 0.8150 - f1: 0.8103 - val_loss: 0.7356 - val_accuracy: 0.7237 - val_f1: 0.7202
# Epoch 202/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4842 - accuracy: 0.8130 - f1: 0.8102 - val_loss: 1.1479 - val_accuracy: 0.6468 - val_f1: 0.6457
# Epoch 203/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4790 - accuracy: 0.8149 - f1: 0.8111 - val_loss: 0.6645 - val_accuracy: 0.7406 - val_f1: 0.7371
# Epoch 204/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4849 - accuracy: 0.8130 - f1: 0.8104 - val_loss: 0.8775 - val_accuracy: 0.6653 - val_f1: 0.6613
# Epoch 205/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4807 - accuracy: 0.8156 - f1: 0.8127 - val_loss: 1.7176 - val_accuracy: 0.4745 - val_f1: 0.4610
# Epoch 206/250
# 176/176 [==============================] - 13s 71ms/step - loss: 0.4806 - accuracy: 0.8151 - f1: 0.8114 - val_loss: 0.6616 - val_accuracy: 0.7396 - val_f1: 0.7388
# Epoch 207/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.4744 - accuracy: 0.8163 - f1: 0.8139 - val_loss: 0.6636 - val_accuracy: 0.7392 - val_f1: 0.7368
# Epoch 208/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4800 - accuracy: 0.8156 - f1: 0.8124 - val_loss: 0.8446 - val_accuracy: 0.6839 - val_f1: 0.6817
# Epoch 209/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4736 - accuracy: 0.8190 - f1: 0.8154 - val_loss: 0.7377 - val_accuracy: 0.7106 - val_f1: 0.7030
# Epoch 210/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4816 - accuracy: 0.8151 - f1: 0.8119 - val_loss: 0.5466 - val_accuracy: 0.7825 - val_f1: 0.7838
# Epoch 211/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4716 - accuracy: 0.8191 - f1: 0.8160 - val_loss: 0.7439 - val_accuracy: 0.7189 - val_f1: 0.7131
# Epoch 212/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4718 - accuracy: 0.8188 - f1: 0.8146 - val_loss: 0.7156 - val_accuracy: 0.7267 - val_f1: 0.7274
# Epoch 213/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4747 - accuracy: 0.8173 - f1: 0.8131 - val_loss: 0.5876 - val_accuracy: 0.7753 - val_f1: 0.7709
# Epoch 214/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4744 - accuracy: 0.8148 - f1: 0.8137 - val_loss: 0.9266 - val_accuracy: 0.6490 - val_f1: 0.6438
# Epoch 215/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4734 - accuracy: 0.8168 - f1: 0.8141 - val_loss: 0.8283 - val_accuracy: 0.6934 - val_f1: 0.6889
# Epoch 216/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4728 - accuracy: 0.8179 - f1: 0.8155 - val_loss: 0.6409 - val_accuracy: 0.7512 - val_f1: 0.7492
# Epoch 217/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4715 - accuracy: 0.8190 - f1: 0.8154 - val_loss: 0.8626 - val_accuracy: 0.6843 - val_f1: 0.6837
# Epoch 218/250
# 176/176 [==============================] - 12s 71ms/step - loss: 0.4726 - accuracy: 0.8190 - f1: 0.8157 - val_loss: 0.6961 - val_accuracy: 0.7275 - val_f1: 0.7232
# Epoch 219/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4674 - accuracy: 0.8211 - f1: 0.8175 - val_loss: 0.8074 - val_accuracy: 0.6878 - val_f1: 0.6821
# Epoch 220/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4766 - accuracy: 0.8161 - f1: 0.8130 - val_loss: 0.7030 - val_accuracy: 0.7299 - val_f1: 0.7271
# Epoch 221/250
# 176/176 [==============================] - 13s 71ms/step - loss: 0.4688 - accuracy: 0.8169 - f1: 0.8149 - val_loss: 0.6603 - val_accuracy: 0.7430 - val_f1: 0.7392
# Epoch 222/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4691 - accuracy: 0.8208 - f1: 0.8181 - val_loss: 0.7002 - val_accuracy: 0.7335 - val_f1: 0.7269
# Epoch 223/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4712 - accuracy: 0.8179 - f1: 0.8156 - val_loss: 0.7726 - val_accuracy: 0.7022 - val_f1: 0.6982
# Epoch 224/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4647 - accuracy: 0.8196 - f1: 0.8167 - val_loss: 0.6567 - val_accuracy: 0.7448 - val_f1: 0.7416
# Epoch 225/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4693 - accuracy: 0.8176 - f1: 0.8145 - val_loss: 0.5932 - val_accuracy: 0.7723 - val_f1: 0.7688
# Epoch 226/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4708 - accuracy: 0.8183 - f1: 0.8146 - val_loss: 0.6718 - val_accuracy: 0.7345 - val_f1: 0.7275
# Epoch 227/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4700 - accuracy: 0.8196 - f1: 0.8156 - val_loss: 0.6867 - val_accuracy: 0.7277 - val_f1: 0.7241
# Epoch 228/250
# 176/176 [==============================] - 12s 66ms/step - loss: 0.4654 - accuracy: 0.8215 - f1: 0.8194 - val_loss: 0.7529 - val_accuracy: 0.7137 - val_f1: 0.7109
# Epoch 229/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4607 - accuracy: 0.8231 - f1: 0.8194 - val_loss: 0.6164 - val_accuracy: 0.7512 - val_f1: 0.7479
# Epoch 230/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4608 - accuracy: 0.8229 - f1: 0.8209 - val_loss: 0.8017 - val_accuracy: 0.6992 - val_f1: 0.6943
# Epoch 231/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4725 - accuracy: 0.8202 - f1: 0.8179 - val_loss: 0.6096 - val_accuracy: 0.7705 - val_f1: 0.7671
# Epoch 232/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4615 - accuracy: 0.8216 - f1: 0.8198 - val_loss: 0.7951 - val_accuracy: 0.6795 - val_f1: 0.6759
# Epoch 233/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4643 - accuracy: 0.8210 - f1: 0.8172 - val_loss: 0.7733 - val_accuracy: 0.7042 - val_f1: 0.7049
# Epoch 234/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4655 - accuracy: 0.8210 - f1: 0.8181 - val_loss: 1.0381 - val_accuracy: 0.6351 - val_f1: 0.6336
# Epoch 235/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4668 - accuracy: 0.8207 - f1: 0.8171 - val_loss: 0.8295 - val_accuracy: 0.6952 - val_f1: 0.6925
# Epoch 236/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4674 - accuracy: 0.8203 - f1: 0.8180 - val_loss: 0.5919 - val_accuracy: 0.7598 - val_f1: 0.7575
# Epoch 237/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4612 - accuracy: 0.8236 - f1: 0.8208 - val_loss: 0.5943 - val_accuracy: 0.7667 - val_f1: 0.7644
# Epoch 238/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4589 - accuracy: 0.8241 - f1: 0.8216 - val_loss: 1.9029 - val_accuracy: 0.4554 - val_f1: 0.4472
# Epoch 239/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4578 - accuracy: 0.8230 - f1: 0.8206 - val_loss: 1.2102 - val_accuracy: 0.5705 - val_f1: 0.5634
# Epoch 240/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4592 - accuracy: 0.8231 - f1: 0.8214 - val_loss: 0.9497 - val_accuracy: 0.6653 - val_f1: 0.6616
# Epoch 241/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4593 - accuracy: 0.8231 - f1: 0.8205 - val_loss: 0.7424 - val_accuracy: 0.7155 - val_f1: 0.7131
# Epoch 242/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4649 - accuracy: 0.8214 - f1: 0.8183 - val_loss: 1.1297 - val_accuracy: 0.6325 - val_f1: 0.6300
# Epoch 243/250
# 176/176 [==============================] - 12s 67ms/step - loss: 0.4691 - accuracy: 0.8215 - f1: 0.8187 - val_loss: 0.5902 - val_accuracy: 0.7639 - val_f1: 0.7611
# Epoch 244/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4574 - accuracy: 0.8237 - f1: 0.8214 - val_loss: 1.0181 - val_accuracy: 0.6323 - val_f1: 0.6291
# Epoch 245/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4612 - accuracy: 0.8216 - f1: 0.8197 - val_loss: 0.5537 - val_accuracy: 0.7791 - val_f1: 0.7780
# Epoch 246/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4524 - accuracy: 0.8247 - f1: 0.8240 - val_loss: 0.7770 - val_accuracy: 0.7118 - val_f1: 0.7094
# Epoch 247/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.4514 - accuracy: 0.8281 - f1: 0.8256 - val_loss: 0.8895 - val_accuracy: 0.6904 - val_f1: 0.6888
# Epoch 248/250
# 176/176 [==============================] - 12s 69ms/step - loss: 0.4589 - accuracy: 0.8224 - f1: 0.8198 - val_loss: 1.0143 - val_accuracy: 0.6363 - val_f1: 0.6290
# Epoch 249/250
# 176/176 [==============================] - 12s 68ms/step - loss: 0.4580 - accuracy: 0.8235 - f1: 0.8216 - val_loss: 0.6532 - val_accuracy: 0.7468 - val_f1: 0.7434
# Epoch 250/250
# 176/176 [==============================] - 12s 70ms/step - loss: 0.4583 - accuracy: 0.8240 - f1: 0.8211 - val_loss: 0.6590 - val_accuracy: 0.7470 - val_f1: 0.7464

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/efficientnet_fp8.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=256)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 49/49 [==============================] - 2s 18ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.79      0.73      0.76      2810
#          REM       0.82      0.50      0.62      1809
#        LIGHT       0.72      0.87      0.79      6233
#         DEEP       0.74      0.60      0.66      1598
#
#     accuracy                           0.75     12450
#    macro avg       0.77      0.67      0.71     12450
# weighted avg       0.75      0.75      0.74     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=False,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081A775F40> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000020812923A90> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081A6EA9A0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081272BC70> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081A770A00> is defaulted to 0
# operation count for <keras.layers.pooling.global_average_pooling1d.GlobalAveragePooling1D object at 0x000002081260A160> is defaulted to 0
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "batch_normalization": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 [
#                     null,
#                     3840,
#                     1
#                 ]
#             ]
#         }
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 1,
#                 32
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 32
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 184320
#     },
#     "batch_normalization_1": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "activation": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "depthwise_conv1d": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_2": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "activation_1": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 32,
#                 16
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 16
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 16
#             ]
#         },
#         "operation_count": 983040
#     },
#     "batch_normalization_3": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 16
#             ]
#         }
#     },
#     "activation_2": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 16
#             ]
#         },
#         "operation_count": 30720
#     },
#     "depthwise_conv1d_1": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 16
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_4": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 16
#             ]
#         }
#     },
#     "activation_3": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 16
#             ]
#         },
#         "operation_count": 15360
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 16,
#                 24
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 24
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 24
#             ]
#         },
#         "operation_count": 368640
#     },
#     "batch_normalization_5": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 24
#             ]
#         }
#     },
#     "activation_4": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 24
#             ]
#         },
#         "operation_count": 23040
#     },
#     "depthwise_conv1d_2": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_6": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         }
#     },
#     "activation_5": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 11520
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 24,
#                 24
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 24
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 276480
#     },
#     "batch_normalization_7": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         }
#     },
#     "activation_6": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 11520
#     },
#     "depthwise_conv1d_3": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 24
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_8": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 24
#             ]
#         }
#     },
#     "activation_7": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 24
#             ]
#         },
#         "operation_count": 5760
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 24,
#                 40
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 40
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 40
#             ]
#         },
#         "operation_count": 230400
#     },
#     "batch_normalization_9": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 40
#             ]
#         }
#     },
#     "activation_8": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 40
#             ]
#         },
#         "operation_count": 9600
#     },
#     "depthwise_conv1d_4": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_10": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         }
#     },
#     "activation_9": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 4800
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 40,
#                 40
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 40
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 192000
#     },
#     "batch_normalization_11": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         }
#     },
#     "activation_10": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 4800
#     },
#     "global_average_pooling1d": {
#         "layer_type": "GlobalAveragePooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 40
#             ]
#         },
#         "operation_count": 0
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 40,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 512
#             ]
#         },
#         "operation_count": 20480
#     },
#     "q_dense_1": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 512,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 256
#             ]
#         },
#         "operation_count": 131072
#     },
#     "q_dense_2": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 256,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 1024
#     }
# }
# {'activation': {'energy': {'inputs': 116852.42,
#                            'op_cost': 0.0,
#                            'outputs': 116852.42,
#                            'parameters': 0.0},
#                 'total': 116852.42},
#  'activation_1': {'energy': {'inputs': 116852.42,
#                              'op_cost': 0.0,
#                              'outputs': 116852.42,
#                              'parameters': 0.0},
#                   'total': 116852.42},
#  'activation_10': {'energy': {'inputs': 9129.1,
#                               'op_cost': 0.0,
#                               'outputs': 9129.1,
#                               'parameters': 0.0},
#                    'total': 9129.1},
#  'activation_2': {'energy': {'inputs': 58426.21,
#                              'op_cost': 0.0,
#                              'outputs': 58426.21,
#                              'parameters': 0.0},
#                   'total': 58426.21},
#  'activation_3': {'energy': {'inputs': 29213.11,
#                              'op_cost': 0.0,
#                              'outputs': 29213.11,
#                              'parameters': 0.0},
#                   'total': 29213.11},
#  'activation_4': {'energy': {'inputs': 43819.66,
#                              'op_cost': 0.0,
#                              'outputs': 43819.66,
#                              'parameters': 0.0},
#                   'total': 43819.66},
#  'activation_5': {'energy': {'inputs': 21909.83,
#                              'op_cost': 0.0,
#                              'outputs': 21909.83,
#                              'parameters': 0.0},
#                   'total': 21909.83},
#  'activation_6': {'energy': {'inputs': 21909.83,
#                              'op_cost': 0.0,
#                              'outputs': 21909.83,
#                              'parameters': 0.0},
#                   'total': 21909.83},
#  'activation_7': {'energy': {'inputs': 10954.91,
#                              'op_cost': 0.0,
#                              'outputs': 10954.91,
#                              'parameters': 0.0},
#                   'total': 10954.91},
#  'activation_8': {'energy': {'inputs': 18258.19,
#                              'op_cost': 0.0,
#                              'outputs': 18258.19,
#                              'parameters': 0.0},
#                   'total': 18258.19},
#  'activation_9': {'energy': {'inputs': 9129.1,
#                              'op_cost': 0.0,
#                              'outputs': 9129.1,
#                              'parameters': 0.0},
#                   'total': 9129.1},
#  'batch_normalization': {'energy': {'inputs': 7303.28,
#                                     'op_cost': 28416.0,
#                                     'outputs': 3.8,
#                                     'parameters': 15.22},
#                          'total': 15.22},
#  'batch_normalization_1': {'energy': {'inputs': 116852.42,
#                                       'op_cost': 454656.0,
#                                       'outputs': 116852.42,
#                                       'parameters': 243.44},
#                            'total': 243.44},
#  'batch_normalization_10': {'energy': {'inputs': 9129.1,
#                                        'op_cost': 35520.0,
#                                        'outputs': 9129.1,
#                                        'parameters': 304.3},
#                             'total': 304.3},
#  'batch_normalization_11': {'energy': {'inputs': 9129.1,
#                                        'op_cost': 35520.0,
#                                        'outputs': 9129.1,
#                                        'parameters': 304.3},
#                             'total': 304.3},
#  'batch_normalization_2': {'energy': {'inputs': 116852.42,
#                                       'op_cost': 454656.0,
#                                       'outputs': 116852.42,
#                                       'parameters': 243.44},
#                            'total': 243.44},
#  'batch_normalization_3': {'energy': {'inputs': 58426.21,
#                                       'op_cost': 227328.0,
#                                       'outputs': 58426.21,
#                                       'parameters': 121.72},
#                            'total': 121.72},
#  'batch_normalization_4': {'energy': {'inputs': 29213.11,
#                                       'op_cost': 113664.0,
#                                       'outputs': 29213.11,
#                                       'parameters': 121.72},
#                            'total': 121.72},
#  'batch_normalization_5': {'energy': {'inputs': 43819.66,
#                                       'op_cost': 170496.0,
#                                       'outputs': 43819.66,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_6': {'energy': {'inputs': 21909.83,
#                                       'op_cost': 85248.0,
#                                       'outputs': 21909.83,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_7': {'energy': {'inputs': 21909.83,
#                                       'op_cost': 85248.0,
#                                       'outputs': 21909.83,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_8': {'energy': {'inputs': 10954.91,
#                                       'op_cost': 42624.0,
#                                       'outputs': 10954.91,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_9': {'energy': {'inputs': 18258.19,
#                                       'op_cost': 71040.0,
#                                       'outputs': 18258.19,
#                                       'parameters': 304.3},
#                            'total': 304.3},
#  'depthwise_conv1d': {'energy': {'inputs': 116852.42,
#                                  'op_cost': 0.0,
#                                  'outputs': 116852.42,
#                                  'parameters': 0.0},
#                       'total': 116852.42},
#  'depthwise_conv1d_1': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 29213.11,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'depthwise_conv1d_2': {'energy': {'inputs': 43819.66,
#                                    'op_cost': 0.0,
#                                    'outputs': 21909.83,
#                                    'parameters': 0.0},
#                         'total': 43819.66},
#  'depthwise_conv1d_3': {'energy': {'inputs': 21909.83,
#                                    'op_cost': 0.0,
#                                    'outputs': 10954.91,
#                                    'parameters': 0.0},
#                         'total': 21909.83},
#  'depthwise_conv1d_4': {'energy': {'inputs': 18258.19,
#                                    'op_cost': 0.0,
#                                    'outputs': 9129.1,
#                                    'parameters': 0.0},
#                         'total': 18258.19},
#  'global_average_pooling1d': {'energy': {'inputs': 9129.1,
#                                          'op_cost': 0.0,
#                                          'outputs': 76.08,
#                                          'parameters': 0.0},
#                               'total': 9129.1},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 847872.0,
#                          'outputs': 116852.42,
#                          'parameters': 60.86},
#               'total': 855236.14},
#  'q_conv1d_1': {'energy': {'inputs': 116852.42,
#                            'op_cost': 4521984.0,
#                            'outputs': 58426.21,
#                            'parameters': 251.05},
#                 'total': 4639087.47},
#  'q_conv1d_2': {'energy': {'inputs': 29213.11,
#                            'op_cost': 1695744.0,
#                            'outputs': 43819.66,
#                            'parameters': 193.99},
#                 'total': 1725151.1},
#  'q_conv1d_3': {'energy': {'inputs': 21909.83,
#                            'op_cost': 1271808.0,
#                            'outputs': 21909.83,
#                            'parameters': 285.28},
#                 'total': 1294003.11},
#  'q_conv1d_4': {'energy': {'inputs': 10954.91,
#                            'op_cost': 1059840.0,
#                            'outputs': 18258.19,
#                            'parameters': 475.47},
#                 'total': 1071270.38},
#  'q_conv1d_5': {'energy': {'inputs': 9129.1,
#                            'op_cost': 883200.0,
#                            'outputs': 9129.1,
#                            'parameters': 779.78},
#                 'total': 893108.88},
#  'q_dense': {'energy': {'inputs': 76.08,
#                         'op_cost': 94208.0,
#                         'outputs': 973.77,
#                         'parameters': 9981.14},
#              'total': 104265.22},
#  'q_dense_1': {'energy': {'inputs': 973.77,
#                           'op_cost': 602931.2,
#                           'outputs': 486.89,
#                           'parameters': 62443.01},
#                'total': 666347.98},
#  'q_dense_2': {'energy': {'inputs': 486.89,
#                           'op_cost': 4710.4,
#                           'outputs': 7.61,
#                           'parameters': 490.69},
#                'total': 5687.98}}
#
# Total energy: 11.98 uJ

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=True,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081A775F40> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000020812923A90> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081A6EA9A0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081272BC70> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x000002081A770A00> is defaulted to 0
# operation count for <keras.layers.pooling.global_average_pooling1d.GlobalAveragePooling1D object at 0x000002081260A160> is defaulted to 0
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "batch_normalization": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 [
#                     null,
#                     3840,
#                     1
#                 ]
#             ]
#         }
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 1,
#                 32
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 32
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 184320
#     },
#     "batch_normalization_1": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "activation": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "depthwise_conv1d": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_2": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "activation_1": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 32,
#                 16
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 16
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 16
#             ]
#         },
#         "operation_count": 983040
#     },
#     "batch_normalization_3": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 16
#             ]
#         }
#     },
#     "activation_2": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 16
#             ]
#         },
#         "operation_count": 30720
#     },
#     "depthwise_conv1d_1": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 16
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_4": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 16
#             ]
#         }
#     },
#     "activation_3": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 16
#             ]
#         },
#         "operation_count": 15360
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 16,
#                 24
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 24
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 24
#             ]
#         },
#         "operation_count": 368640
#     },
#     "batch_normalization_5": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 24
#             ]
#         }
#     },
#     "activation_4": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 24
#             ]
#         },
#         "operation_count": 23040
#     },
#     "depthwise_conv1d_2": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_6": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         }
#     },
#     "activation_5": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 11520
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 24,
#                 24
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 24
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 276480
#     },
#     "batch_normalization_7": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         }
#     },
#     "activation_6": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 24
#             ]
#         },
#         "operation_count": 11520
#     },
#     "depthwise_conv1d_3": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 24
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_8": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 24
#             ]
#         }
#     },
#     "activation_7": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 24
#             ]
#         },
#         "operation_count": 5760
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 24,
#                 40
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 40
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 40
#             ]
#         },
#         "operation_count": 230400
#     },
#     "batch_normalization_9": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 40
#             ]
#         }
#     },
#     "activation_8": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 40
#             ]
#         },
#         "operation_count": 9600
#     },
#     "depthwise_conv1d_4": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 0
#     },
#     "batch_normalization_10": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         }
#     },
#     "activation_9": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 4800
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 40,
#                 40
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 40
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 192000
#     },
#     "batch_normalization_11": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         }
#     },
#     "activation_10": {
#         "layer_type": "Activation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 40
#             ]
#         },
#         "operation_count": 4800
#     },
#     "global_average_pooling1d": {
#         "layer_type": "GlobalAveragePooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 40
#             ]
#         },
#         "operation_count": 0
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 40,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 512
#             ]
#         },
#         "operation_count": 20480
#     },
#     "q_dense_1": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 512,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 256
#             ]
#         },
#         "operation_count": 131072
#     },
#     "q_dense_2": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 256,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 1024
#     }
# }
# {'activation': {'energy': {'inputs': 116852.42,
#                            'op_cost': 0.0,
#                            'outputs': 116852.42,
#                            'parameters': 0.0},
#                 'total': 116852.42},
#  'activation_1': {'energy': {'inputs': 116852.42,
#                              'op_cost': 0.0,
#                              'outputs': 116852.42,
#                              'parameters': 0.0},
#                   'total': 116852.42},
#  'activation_10': {'energy': {'inputs': 9129.1,
#                               'op_cost': 0.0,
#                               'outputs': 9129.1,
#                               'parameters': 0.0},
#                    'total': 9129.1},
#  'activation_2': {'energy': {'inputs': 58426.21,
#                              'op_cost': 0.0,
#                              'outputs': 58426.21,
#                              'parameters': 0.0},
#                   'total': 58426.21},
#  'activation_3': {'energy': {'inputs': 29213.11,
#                              'op_cost': 0.0,
#                              'outputs': 29213.11,
#                              'parameters': 0.0},
#                   'total': 29213.11},
#  'activation_4': {'energy': {'inputs': 43819.66,
#                              'op_cost': 0.0,
#                              'outputs': 43819.66,
#                              'parameters': 0.0},
#                   'total': 43819.66},
#  'activation_5': {'energy': {'inputs': 21909.83,
#                              'op_cost': 0.0,
#                              'outputs': 21909.83,
#                              'parameters': 0.0},
#                   'total': 21909.83},
#  'activation_6': {'energy': {'inputs': 21909.83,
#                              'op_cost': 0.0,
#                              'outputs': 21909.83,
#                              'parameters': 0.0},
#                   'total': 21909.83},
#  'activation_7': {'energy': {'inputs': 10954.91,
#                              'op_cost': 0.0,
#                              'outputs': 10954.91,
#                              'parameters': 0.0},
#                   'total': 10954.91},
#  'activation_8': {'energy': {'inputs': 18258.19,
#                              'op_cost': 0.0,
#                              'outputs': 18258.19,
#                              'parameters': 0.0},
#                   'total': 18258.19},
#  'activation_9': {'energy': {'inputs': 9129.1,
#                              'op_cost': 0.0,
#                              'outputs': 9129.1,
#                              'parameters': 0.0},
#                   'total': 9129.1},
#  'batch_normalization': {'energy': {'inputs': 7303.28,
#                                     'op_cost': 28416.0,
#                                     'outputs': 3.8,
#                                     'parameters': 15.22},
#                          'total': 15.22},
#  'batch_normalization_1': {'energy': {'inputs': 116852.42,
#                                       'op_cost': 454656.0,
#                                       'outputs': 116852.42,
#                                       'parameters': 243.44},
#                            'total': 243.44},
#  'batch_normalization_10': {'energy': {'inputs': 9129.1,
#                                        'op_cost': 35520.0,
#                                        'outputs': 9129.1,
#                                        'parameters': 304.3},
#                             'total': 304.3},
#  'batch_normalization_11': {'energy': {'inputs': 9129.1,
#                                        'op_cost': 35520.0,
#                                        'outputs': 9129.1,
#                                        'parameters': 304.3},
#                             'total': 304.3},
#  'batch_normalization_2': {'energy': {'inputs': 116852.42,
#                                       'op_cost': 454656.0,
#                                       'outputs': 116852.42,
#                                       'parameters': 243.44},
#                            'total': 243.44},
#  'batch_normalization_3': {'energy': {'inputs': 58426.21,
#                                       'op_cost': 227328.0,
#                                       'outputs': 58426.21,
#                                       'parameters': 121.72},
#                            'total': 121.72},
#  'batch_normalization_4': {'energy': {'inputs': 29213.11,
#                                       'op_cost': 113664.0,
#                                       'outputs': 29213.11,
#                                       'parameters': 121.72},
#                            'total': 121.72},
#  'batch_normalization_5': {'energy': {'inputs': 43819.66,
#                                       'op_cost': 170496.0,
#                                       'outputs': 43819.66,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_6': {'energy': {'inputs': 21909.83,
#                                       'op_cost': 85248.0,
#                                       'outputs': 21909.83,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_7': {'energy': {'inputs': 21909.83,
#                                       'op_cost': 85248.0,
#                                       'outputs': 21909.83,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_8': {'energy': {'inputs': 10954.91,
#                                       'op_cost': 42624.0,
#                                       'outputs': 10954.91,
#                                       'parameters': 182.58},
#                            'total': 182.58},
#  'batch_normalization_9': {'energy': {'inputs': 18258.19,
#                                       'op_cost': 71040.0,
#                                       'outputs': 18258.19,
#                                       'parameters': 304.3},
#                            'total': 304.3},
#  'depthwise_conv1d': {'energy': {'inputs': 116852.42,
#                                  'op_cost': 0.0,
#                                  'outputs': 116852.42,
#                                  'parameters': 0.0},
#                       'total': 116852.42},
#  'depthwise_conv1d_1': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 29213.11,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'depthwise_conv1d_2': {'energy': {'inputs': 43819.66,
#                                    'op_cost': 0.0,
#                                    'outputs': 21909.83,
#                                    'parameters': 0.0},
#                         'total': 43819.66},
#  'depthwise_conv1d_3': {'energy': {'inputs': 21909.83,
#                                    'op_cost': 0.0,
#                                    'outputs': 10954.91,
#                                    'parameters': 0.0},
#                         'total': 21909.83},
#  'depthwise_conv1d_4': {'energy': {'inputs': 18258.19,
#                                    'op_cost': 0.0,
#                                    'outputs': 9129.1,
#                                    'parameters': 0.0},
#                         'total': 18258.19},
#  'global_average_pooling1d': {'energy': {'inputs': 9129.1,
#                                          'op_cost': 0.0,
#                                          'outputs': 76.08,
#                                          'parameters': 0.0},
#                               'total': 9129.1},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 847872.0,
#                          'outputs': 116852.42,
#                          'parameters': 243.44},
#               'total': 855418.72},
#  'q_conv1d_1': {'energy': {'inputs': 116852.42,
#                            'op_cost': 4521984.0,
#                            'outputs': 58426.21,
#                            'parameters': 1004.2},
#                 'total': 4639840.62},
#  'q_conv1d_2': {'energy': {'inputs': 29213.11,
#                            'op_cost': 1695744.0,
#                            'outputs': 43819.66,
#                            'parameters': 775.97},
#                 'total': 1725733.08},
#  'q_conv1d_3': {'energy': {'inputs': 21909.83,
#                            'op_cost': 1271808.0,
#                            'outputs': 21909.83,
#                            'parameters': 1141.14},
#                 'total': 1294858.97},
#  'q_conv1d_4': {'energy': {'inputs': 10954.91,
#                            'op_cost': 1059840.0,
#                            'outputs': 18258.19,
#                            'parameters': 1901.89},
#                 'total': 1072696.8},
#  'q_conv1d_5': {'energy': {'inputs': 9129.1,
#                            'op_cost': 883200.0,
#                            'outputs': 9129.1,
#                            'parameters': 3119.11},
#                 'total': 895448.21},
#  'q_dense': {'energy': {'inputs': 76.08,
#                         'op_cost': 94208.0,
#                         'outputs': 973.77,
#                         'parameters': 39924.58},
#              'total': 134208.66},
#  'q_dense_1': {'energy': {'inputs': 973.77,
#                           'op_cost': 602931.2,
#                           'outputs': 486.89,
#                           'parameters': 249772.05},
#                'total': 853677.0199999999},
#  'q_dense_2': {'energy': {'inputs': 486.89,
#                           'op_cost': 4710.4,
#                           'outputs': 7.61,
#                           'parameters': 1955.15},
#                'total': 7152.44}}
#
# Total energy: 12.21 uJ
