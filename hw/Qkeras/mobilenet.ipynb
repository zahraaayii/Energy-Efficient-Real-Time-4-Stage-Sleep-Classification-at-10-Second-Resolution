# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, DepthwiseConv1D, BatchNormalization, ReLU, GlobalAveragePooling1D, Dense
from keras.layers import Conv1D, SeparableConv1D,GlobalAveragePooling1D,Add,concatenate, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\zazaz\AppData\Local\Temp\ipykernel_2476\265848756.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install QKeras
from qkeras import *
import pprint
from qkeras.autoqkeras import *
from qkeras import *
from qkeras.qtools import run_qtools
from qkeras.qtools import settings as qtools_settings

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))

        recall = TP / (Positives+K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

        precision = TP / (Pred_Positives+K.epsilon())
        return precision
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
def depthwise_separable_conv_block(inputs, pointwise_conv_filters, alpha=1, depth_multiplier=1, strides=1, block_id=1):
    """Depthwise separable conv block.
    """
    pointwise_conv_filters = int(pointwise_conv_filters * alpha)

    x = DepthwiseConv1D((3,), padding='same', depth_multiplier=depth_multiplier, strides=strides)(inputs)
    x = BatchNormalization(name='conv_dw_%d_bn' % block_id)(x)
    x = QActivation("quantized_relu(8,1)")(x)

    x = QConv1D(pointwise_conv_filters, (1,), padding='same', use_bias=False, strides=(1,),kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(x)
    x = BatchNormalization(name='conv_pw_%d_bn' % block_id)(x)
    x = QActivation("quantized_relu(8,1)")(x)

    return x

def MobileNet1D(input_shape, alpha=1, depth_multiplier=1, classes=10):
    """Instantiates the MobileNet architecture.
    """
    inputs = Input(shape=input_shape)

    x = depthwise_separable_conv_block(inputs, 32, alpha, depth_multiplier, strides=2, block_id=1)
    x = depthwise_separable_conv_block(x, 64, alpha, depth_multiplier, strides=1, block_id=2)
    x = depthwise_separable_conv_block(x, 128, alpha, depth_multiplier, strides=2, block_id=3)
    x = depthwise_separable_conv_block(x, 128, alpha, depth_multiplier, strides=1, block_id=4)
    x = depthwise_separable_conv_block(x, 256, alpha, depth_multiplier, strides=2, block_id=5)
    x = depthwise_separable_conv_block(x, 256, alpha, depth_multiplier, strides=1, block_id=6)
    x = depthwise_separable_conv_block(x, 512, alpha, depth_multiplier, strides=2, block_id=7)

    # Add more depthwise separable blocks if needed

    x = GlobalAveragePooling1D()(x)
    x = QDense(256,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(x)
    x = QDense(classes,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='softmax',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(x)

    model = Model(inputs, x)

    return model


input_shape = (3840,1)
alpha = 1.0
depth_multiplier = 1
classes = 4  # Number of output classes

model = MobileNet1D(input_shape, alpha, depth_multiplier, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3840, 1)]         0
#
#  depthwise_conv1d (Depthwise  (None, 1920, 1)          4
#  Conv1D)
#
#  conv_dw_1_bn (BatchNormaliz  (None, 1920, 1)          4
#  ation)
#
#  q_activation (QActivation)  (None, 1920, 1)           0
#
#  q_conv1d (QConv1D)          (None, 1920, 32)          32
#
#  conv_pw_1_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  q_activation_1 (QActivation  (None, 1920, 32)         0
#  )
#
#  depthwise_conv1d_1 (Depthwi  (None, 1920, 32)         128
#  seConv1D)
#
#  conv_dw_2_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  q_activation_2 (QActivation  (None, 1920, 32)         0
#  )
#
#  q_conv1d_1 (QConv1D)        (None, 1920, 64)          2048
#
#  conv_pw_2_bn (BatchNormaliz  (None, 1920, 64)         256
#  ation)
#
#  q_activation_3 (QActivation  (None, 1920, 64)         0
#  )
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3840, 1)]         0
#
#  depthwise_conv1d (Depthwise  (None, 1920, 1)          4
#  Conv1D)
#
#  conv_dw_1_bn (BatchNormaliz  (None, 1920, 1)          4
#  ation)
#
#  q_activation (QActivation)  (None, 1920, 1)           0
#
#  q_conv1d (QConv1D)          (None, 1920, 32)          32
#
#  conv_pw_1_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  q_activation_1 (QActivation  (None, 1920, 32)         0
#  )
#
#  depthwise_conv1d_1 (Depthwi  (None, 1920, 32)         128
#  seConv1D)
#
#  conv_dw_2_bn (BatchNormaliz  (None, 1920, 32)         128
#  ation)
#
#  q_activation_2 (QActivation  (None, 1920, 32)         0
#  )
#
#  q_conv1d_1 (QConv1D)        (None, 1920, 64)          2048
#
#  conv_pw_2_bn (BatchNormaliz  (None, 1920, 64)         256
#  ation)
#
#  q_activation_3 (QActivation  (None, 1920, 64)         0
#  )
#
#  depthwise_conv1d_2 (Depthwi  (None, 960, 64)          256
#  seConv1D)
#
#  conv_dw_3_bn (BatchNormaliz  (None, 960, 64)          256
#  ation)
#
#  q_activation_4 (QActivation  (None, 960, 64)          0
#  )
#
#  q_conv1d_2 (QConv1D)        (None, 960, 128)          8192
#
#  conv_pw_3_bn (BatchNormaliz  (None, 960, 128)         512
#  ation)
#
#  q_activation_5 (QActivation  (None, 960, 128)         0
#  )
#
#  depthwise_conv1d_3 (Depthwi  (None, 960, 128)         512
#  seConv1D)
#
#  conv_dw_4_bn (BatchNormaliz  (None, 960, 128)         512
#  ation)
#
#  q_activation_6 (QActivation  (None, 960, 128)         0
#  )
#
#  q_conv1d_3 (QConv1D)        (None, 960, 128)          16384
#
#  conv_pw_4_bn (BatchNormaliz  (None, 960, 128)         512
#  ation)
#
#  q_activation_7 (QActivation  (None, 960, 128)         0
#  )
#
#  depthwise_conv1d_4 (Depthwi  (None, 480, 128)         512
#  seConv1D)
#
#  conv_dw_5_bn (BatchNormaliz  (None, 480, 128)         512
#  ation)
#
#  q_activation_8 (QActivation  (None, 480, 128)         0
#  )
#
#  q_conv1d_4 (QConv1D)        (None, 480, 256)          32768
#
#  conv_pw_5_bn (BatchNormaliz  (None, 480, 256)         1024
#  ation)
#
#  q_activation_9 (QActivation  (None, 480, 256)         0
#  )
#
#  depthwise_conv1d_5 (Depthwi  (None, 480, 256)         1024
#  seConv1D)
#
#  conv_dw_6_bn (BatchNormaliz  (None, 480, 256)         1024
#  ation)
#
#  q_activation_10 (QActivatio  (None, 480, 256)         0
#  n)
#
#  q_conv1d_5 (QConv1D)        (None, 480, 256)          65536
#
#  conv_pw_6_bn (BatchNormaliz  (None, 480, 256)         1024
#  ation)
#
#  q_activation_11 (QActivatio  (None, 480, 256)         0
#  n)
#
#  depthwise_conv1d_6 (Depthwi  (None, 240, 256)         1024
#  seConv1D)
#
#  conv_dw_7_bn (BatchNormaliz  (None, 240, 256)         1024
#  ation)
#
#  q_activation_12 (QActivatio  (None, 240, 256)         0
#  n)
#
#  q_conv1d_6 (QConv1D)        (None, 240, 512)          131072
#
#  conv_pw_7_bn (BatchNormaliz  (None, 240, 512)         2048
#  ation)
#
#  q_activation_13 (QActivatio  (None, 240, 512)         0
#  n)
#
#  global_average_pooling1d (G  (None, 512)              0
#  lobalAveragePooling1D)
#
#  q_dense (QDense)            (None, 256)               131328
#
#  q_dense_1 (QDense)          (None, 4)                 1028
#
# =================================================================
# Total params: 400,812
# Trainable params: 396,330
# Non-trainable params: 4,482
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/mobilenet_fp8.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=256,epochs=200,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/200
# 176/176 [==============================] - 84s 454ms/step - loss: 2.7414 - accuracy: 0.5681 - f1: 0.4978 - val_loss: 1.8134 - val_accuracy: 0.1319 - val_f1: 0.0000e+00
# 176/176 [==============================] - 79s 448ms/step - loss: 0.1776 - accuracy: 0.9837 - f1: 0.9818 - val_loss: 1.2503 - val_accuracy: 0.6755 - val_f1: 0.6739
# Epoch 198/200
# 176/176 [==============================] - 79s 448ms/step - loss: 0.2236 - accuracy: 0.9694 - f1: 0.9678 - val_loss: 0.4238 - val_accuracy: 0.8880 - val_f1: 0.8876
# Epoch 199/200
# 176/176 [==============================] - 79s 448ms/step - loss: 0.2173 - accuracy: 0.9769 - f1: 0.9755 - val_loss: 0.4853 - val_accuracy: 0.8649 - val_f1: 0.8651
# Epoch 200/200
# 176/176 [==============================] - 79s 448ms/step - loss: 0.1685 - accuracy: 0.9898 - f1: 0.9895 - val_loss: 0.4136 - val_accuracy: 0.8954 - val_f1: 0.8958

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/mobilenet_fp8.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=256)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 49/49 [==============================] - 11s 215ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.95      0.76      0.85      2810
#          REM       0.96      0.82      0.88      1809
#        LIGHT       0.85      0.97      0.91      6233
#         DEEP       0.88      0.86      0.87      1598
#
#     accuracy                           0.89     12450
#    macro avg       0.91      0.85      0.88     12450
# weighted avg       0.89      0.89      0.89     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=False,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# CRITICAL:absl:unsupported kernel shape, it is neither a dense kernel of length 2, nor a convolution kernel of length 4
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C5E0860A0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C5E08A760> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D035F70> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D0E9FA0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D0E6CD0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D0A7FA0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D131A60> is defaulted to 0
# operation count for <keras.layers.pooling.global_average_pooling1d.GlobalAveragePooling1D object at 0x0000018C6D15EE80> is defaulted to 0
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "depthwise_conv1d": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 1
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_1_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 1
#             ]
#         }
#     },
#     "q_activation": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 1920,
#                 1
#             ]
#         },
#         "operation_count": 1920
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 1,
#                 32
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 17,
#             "int_bits": 4,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 17,
#             "int_bits": 4,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "conv_pw_1_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 17,
#                 "int_bits": 4,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "q_activation_1": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "depthwise_conv1d_1": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_2_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "q_activation_2": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 32,
#                 64
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 22,
#             "int_bits": 9,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 22,
#             "int_bits": 9,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         },
#         "operation_count": 3932160
#     },
#     "conv_pw_2_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 22,
#                 "int_bits": 9,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         }
#     },
#     "q_activation_3": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_2": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 960,
#                 64
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_3_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 64
#             ]
#         }
#     },
#     "q_activation_4": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 960,
#                 64
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 64,
#                 128
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 23,
#             "int_bits": 10,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 23,
#             "int_bits": 10,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 7864320
#     },
#     "conv_pw_3_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 23,
#                 "int_bits": 10,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         }
#     },
#     "q_activation_5": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_3": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_4_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         }
#     },
#     "q_activation_6": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 122880
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 128,
#                 128
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 24,
#             "int_bits": 11,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 24,
#             "int_bits": 11,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 15728640
#     },
#     "conv_pw_4_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 24,
#                 "int_bits": 11,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         }
#     },
#     "q_activation_7": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_4": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 480,
#                 128
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_5_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 128
#             ]
#         }
#     },
#     "q_activation_8": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 480,
#                 128
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 128,
#                 256
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 24,
#             "int_bits": 11,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 24,
#             "int_bits": 11,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 15728640
#     },
#     "conv_pw_5_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 24,
#                 "int_bits": 11,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         }
#     },
#     "q_activation_9": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_5": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_6_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         }
#     },
#     "q_activation_10": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 122880
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 256,
#                 256
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 25,
#             "int_bits": 12,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 25,
#             "int_bits": 12,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 31457280
#     },
#     "conv_pw_6_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 25,
#                 "int_bits": 12,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         }
#     },
#     "q_activation_11": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_6": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 240,
#                 256
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_7_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 256
#             ]
#         }
#     },
#     "q_activation_12": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 240,
#                 256
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_6": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 256,
#                 512
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 25,
#             "int_bits": 12,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 25,
#             "int_bits": 12,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 31457280
#     },
#     "conv_pw_7_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 25,
#                 "int_bits": 12,
#                 "is_signed": 1
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         }
#     },
#     "q_activation_13": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 122880
#     },
#     "global_average_pooling1d": {
#         "layer_type": "GlobalAveragePooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "quantized_relu",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": 0,
#             "shape": [
#                 -1,
#                 512
#             ]
#         },
#         "operation_count": 0
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_relu",
#                 "bits": 8,
#                 "int_bits": 1,
#                 "is_signed": 0
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 512,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 16,
#             "int_bits": 3,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 26,
#             "int_bits": 13,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 26,
#             "int_bits": 13,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 256
#             ]
#         },
#         "operation_count": 131072
#     },
#     "q_dense_1": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "quantized_bits",
#                 "bits": 26,
#                 "int_bits": 13,
#                 "is_signed": 1
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 256,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "quantized_bits",
#             "bits": 34,
#             "int_bits": 14,
#             "is_signed": 1,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "quantized_bits",
#             "bits": 43,
#             "int_bits": 23,
#             "is_signed": 1,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 43,
#             "int_bits": 23,
#             "is_signed": 1,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 1024
#     }
# }
# {'conv_dw_1_bn': {'energy': {'inputs': 3651.64,
#                              'op_cost': 14208.0,
#                              'outputs': 3651.64,
#                              'parameters': 15.22},
#                   'total': 15.22},
#  'conv_dw_2_bn': {'energy': {'inputs': 29213.11,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 243.44},
#                   'total': 243.44},
#  'conv_dw_3_bn': {'energy': {'inputs': 29213.11,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 486.89},
#                   'total': 486.89},
#  'conv_dw_4_bn': {'energy': {'inputs': 58426.21,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_dw_5_bn': {'energy': {'inputs': 29213.11,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_dw_6_bn': {'energy': {'inputs': 58426.21,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_dw_7_bn': {'energy': {'inputs': 29213.11,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_pw_1_bn': {'energy': {'inputs': 62077.85,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 243.44},
#                   'total': 243.44},
#  'conv_pw_2_bn': {'energy': {'inputs': 160672.08,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 486.89},
#                   'total': 486.89},
#  'conv_pw_3_bn': {'energy': {'inputs': 167975.36,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_pw_4_bn': {'energy': {'inputs': 175278.63,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_pw_5_bn': {'energy': {'inputs': 175278.63,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_pw_6_bn': {'energy': {'inputs': 182581.91,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_pw_7_bn': {'energy': {'inputs': 182581.91,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 3895.08},
#                   'total': 3895.08},
#  'depthwise_conv1d': {'energy': {'inputs': 7303.28,
#                                  'op_cost': 0.0,
#                                  'outputs': 3651.64,
#                                  'parameters': 0.0},
#                       'total': 7303.28},
#  'depthwise_conv1d_1': {'energy': {'inputs': 29213.11,
#                                    'op_cost': 0.0,
#                                    'outputs': 29213.11,
#                                    'parameters': 0.0},
#                         'total': 29213.11},
#  'depthwise_conv1d_2': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 29213.11,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'depthwise_conv1d_3': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 58426.21,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'depthwise_conv1d_4': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 29213.11,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'depthwise_conv1d_5': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 58426.21,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'depthwise_conv1d_6': {'energy': {'inputs': 58426.21,
#                                    'op_cost': 0.0,
#                                    'outputs': 29213.11,
#                                    'parameters': 0.0},
#                         'total': 58426.21},
#  'global_average_pooling1d': {'energy': {'inputs': 58426.21,
#                                          'op_cost': 0.0,
#                                          'outputs': 243.44,
#                                          'parameters': 0.0},
#                               'total': 58426.21},
#  'q_activation': {'energy': {'inputs': 3651.64,
#                              'op_cost': 0.0,
#                              'outputs': 912.91,
#                              'parameters': 0.0},
#                   'total': 912.91},
#  'q_activation_1': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 29213.11,
#                                'parameters': 0.0},
#                     'total': 29213.11},
#  'q_activation_10': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 58426.21,
#                                 'parameters': 0.0},
#                      'total': 58426.21},
#  'q_activation_11': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 58426.21,
#                                 'parameters': 0.0},
#                      'total': 58426.21},
#  'q_activation_12': {'energy': {'inputs': 116852.42,
#                                 'op_cost': 0.0,
#                                 'outputs': 29213.11,
#                                 'parameters': 0.0},
#                      'total': 29213.11},
#  'q_activation_13': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 58426.21,
#                                 'parameters': 0.0},
#                      'total': 58426.21},
#  'q_activation_2': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 29213.11,
#                                'parameters': 0.0},
#                     'total': 29213.11},
#  'q_activation_3': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 58426.21,
#                                'parameters': 0.0},
#                     'total': 58426.21},
#  'q_activation_4': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 29213.11,
#                                'parameters': 0.0},
#                     'total': 29213.11},
#  'q_activation_5': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 58426.21,
#                                'parameters': 0.0},
#                     'total': 58426.21},
#  'q_activation_6': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 58426.21,
#                                'parameters': 0.0},
#                     'total': 58426.21},
#  'q_activation_7': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 58426.21,
#                                'parameters': 0.0},
#                     'total': 58426.21},
#  'q_activation_8': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 29213.11,
#                                'parameters': 0.0},
#                     'total': 29213.11},
#  'q_activation_9': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 58426.21,
#                                'parameters': 0.0},
#                     'total': 58426.21},
#  'q_conv1d': {'energy': {'inputs': 912.91,
#                          'op_cost': 15552.0,
#                          'outputs': 62077.85,
#                          'parameters': 15.22},
#               'total': 16480.13},
#  'q_conv1d_1': {'energy': {'inputs': 29213.11,
#                            'op_cost': 1056768.0,
#                            'outputs': 160672.08,
#                            'parameters': 973.77},
#                 'total': 1086954.88},
#  'q_conv1d_2': {'energy': {'inputs': 29213.11,
#                            'op_cost': 2138112.0,
#                            'outputs': 167975.36,
#                            'parameters': 3895.08},
#                 'total': 2171220.19},
#  'q_conv1d_3': {'energy': {'inputs': 58426.21,
#                            'op_cost': 4325376.0,
#                            'outputs': 175278.63,
#                            'parameters': 7790.16},
#                 'total': 4391592.37},
#  'q_conv1d_4': {'energy': {'inputs': 29213.11,
#                            'op_cost': 4325376.0,
#                            'outputs': 175278.63,
#                            'parameters': 15580.32},
#                 'total': 4370169.43},
#  'q_conv1d_5': {'energy': {'inputs': 58426.21,
#                            'op_cost': 8749056.0,
#                            'outputs': 182581.91,
#                            'parameters': 31160.65},
#                 'total': 8838642.86},
#  'q_conv1d_6': {'energy': {'inputs': 29213.11,
#                            'op_cost': 8749056.0,
#                            'outputs': 182581.91,
#                            'parameters': 62321.29},
#                 'total': 8840590.4},
#  'q_dense': {'energy': {'inputs': 243.44,
#                         'op_cost': 36864.0,
#                         'outputs': 395.59,
#                         'parameters': 62443.01},
#              'total': 99550.45000000001},
#  'q_dense_1': {'energy': {'inputs': 395.59,
#                           'op_cost': 790.85,
#                           'outputs': 11.41,
#                           'parameters': 490.69},
#                'total': 1677.13}}
#
# Total energy: 30.84 uJ

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=True,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C5E0860A0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C5E08A760> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D035F70> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D0E9FA0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D0E6CD0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D0A7FA0> is defaulted to 0
# operation count for <keras.layers.convolutional.depthwise_conv1d.DepthwiseConv1D object at 0x0000018C6D131A60> is defaulted to 0
# operation count for <keras.layers.pooling.global_average_pooling1d.GlobalAveragePooling1D object at 0x0000018C6D15EE80> is defaulted to 0
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "depthwise_conv1d": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 1
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_1_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 1
#             ]
#         }
#     },
#     "q_activation": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 1
#             ]
#         },
#         "operation_count": 1920
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 1,
#                 32
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "conv_pw_1_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "q_activation_1": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "depthwise_conv1d_1": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_2_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         }
#     },
#     "q_activation_2": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 32
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 32,
#                 64
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         },
#         "operation_count": 3932160
#     },
#     "conv_pw_2_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         }
#     },
#     "q_activation_3": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_2": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 64
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_3_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 64
#             ]
#         }
#     },
#     "q_activation_4": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 64
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 64,
#                 128
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 7864320
#     },
#     "conv_pw_3_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         }
#     },
#     "q_activation_5": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_3": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_4_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         }
#     },
#     "q_activation_6": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 122880
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 128,
#                 128
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 15728640
#     },
#     "conv_pw_4_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         }
#     },
#     "q_activation_7": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_4": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 128
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_5_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 128
#             ]
#         }
#     },
#     "q_activation_8": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 128
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 128,
#                 256
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 15728640
#     },
#     "conv_pw_5_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         }
#     },
#     "q_activation_9": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_5": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_6_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         }
#     },
#     "q_activation_10": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 122880
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 256,
#                 256
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 31457280
#     },
#     "conv_pw_6_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         }
#     },
#     "q_activation_11": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 122880
#     },
#     "depthwise_conv1d_6": {
#         "layer_type": "DepthwiseConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 256
#             ]
#         },
#         "operation_count": 0
#     },
#     "conv_dw_7_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 256
#             ]
#         }
#     },
#     "q_activation_12": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 256
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_conv1d_6": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 256,
#                 512
#             ]
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 31457280
#     },
#     "conv_pw_7_bn": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         }
#     },
#     "q_activation_13": {
#         "layer_type": "QActivation",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 122880
#     },
#     "global_average_pooling1d": {
#         "layer_type": "GlobalAveragePooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 512
#             ]
#         },
#         "operation_count": 0
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 512,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 256
#             ]
#         },
#         "operation_count": 131072
#     },
#     "q_dense_1": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 256,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 1024
#     }
# }
# {'conv_dw_1_bn': {'energy': {'inputs': 3651.64,
#                              'op_cost': 14208.0,
#                              'outputs': 3651.64,
#                              'parameters': 15.22},
#                   'total': 15.22},
#  'conv_dw_2_bn': {'energy': {'inputs': 116852.42,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 243.44},
#                   'total': 243.44},
#  'conv_dw_3_bn': {'energy': {'inputs': 116852.42,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 486.89},
#                   'total': 486.89},
#  'conv_dw_4_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_dw_5_bn': {'energy': {'inputs': 116852.42,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_dw_6_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_dw_7_bn': {'energy': {'inputs': 116852.42,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_pw_1_bn': {'energy': {'inputs': 116852.42,
#                              'op_cost': 454656.0,
#                              'outputs': 116852.42,
#                              'parameters': 243.44},
#                   'total': 243.44},
#  'conv_pw_2_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 486.89},
#                   'total': 486.89},
#  'conv_pw_3_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_pw_4_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 973.77},
#                   'total': 973.77},
#  'conv_pw_5_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_pw_6_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 1947.54},
#                   'total': 1947.54},
#  'conv_pw_7_bn': {'energy': {'inputs': 233704.85,
#                              'op_cost': 909312.0,
#                              'outputs': 233704.85,
#                              'parameters': 3895.08},
#                   'total': 3895.08},
#  'depthwise_conv1d': {'energy': {'inputs': 7303.28,
#                                  'op_cost': 0.0,
#                                  'outputs': 3651.64,
#                                  'parameters': 0.0},
#                       'total': 7303.28},
#  'depthwise_conv1d_1': {'energy': {'inputs': 116852.42,
#                                    'op_cost': 0.0,
#                                    'outputs': 116852.42,
#                                    'parameters': 0.0},
#                         'total': 116852.42},
#  'depthwise_conv1d_2': {'energy': {'inputs': 233704.85,
#                                    'op_cost': 0.0,
#                                    'outputs': 116852.42,
#                                    'parameters': 0.0},
#                         'total': 233704.85},
#  'depthwise_conv1d_3': {'energy': {'inputs': 233704.85,
#                                    'op_cost': 0.0,
#                                    'outputs': 233704.85,
#                                    'parameters': 0.0},
#                         'total': 233704.85},
#  'depthwise_conv1d_4': {'energy': {'inputs': 233704.85,
#                                    'op_cost': 0.0,
#                                    'outputs': 116852.42,
#                                    'parameters': 0.0},
#                         'total': 233704.85},
#  'depthwise_conv1d_5': {'energy': {'inputs': 233704.85,
#                                    'op_cost': 0.0,
#                                    'outputs': 233704.85,
#                                    'parameters': 0.0},
#                         'total': 233704.85},
#  'depthwise_conv1d_6': {'energy': {'inputs': 233704.85,
#                                    'op_cost': 0.0,
#                                    'outputs': 116852.42,
#                                    'parameters': 0.0},
#                         'total': 233704.85},
#  'global_average_pooling1d': {'energy': {'inputs': 233704.85,
#                                          'op_cost': 0.0,
#                                          'outputs': 973.77,
#                                          'parameters': 0.0},
#                               'total': 233704.85},
#  'q_activation': {'energy': {'inputs': 3651.64,
#                              'op_cost': 0.0,
#                              'outputs': 3651.64,
#                              'parameters': 0.0},
#                   'total': 3651.64},
#  'q_activation_1': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 116852.42,
#                                'parameters': 0.0},
#                     'total': 116852.42},
#  'q_activation_10': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 233704.85},
#  'q_activation_11': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 233704.85},
#  'q_activation_12': {'energy': {'inputs': 116852.42,
#                                 'op_cost': 0.0,
#                                 'outputs': 116852.42,
#                                 'parameters': 0.0},
#                      'total': 116852.42},
#  'q_activation_13': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 233704.85},
#  'q_activation_2': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 116852.42,
#                                'parameters': 0.0},
#                     'total': 116852.42},
#  'q_activation_3': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 233704.85,
#                                'parameters': 0.0},
#                     'total': 233704.85},
#  'q_activation_4': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 116852.42,
#                                'parameters': 0.0},
#                     'total': 116852.42},
#  'q_activation_5': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 233704.85,
#                                'parameters': 0.0},
#                     'total': 233704.85},
#  'q_activation_6': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 233704.85,
#                                'parameters': 0.0},
#                     'total': 233704.85},
#  'q_activation_7': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 233704.85,
#                                'parameters': 0.0},
#                     'total': 233704.85},
#  'q_activation_8': {'energy': {'inputs': 116852.42,
#                                'op_cost': 0.0,
#                                'outputs': 116852.42,
#                                'parameters': 0.0},
#                     'total': 116852.42},
#  'q_activation_9': {'energy': {'inputs': 233704.85,
#                                'op_cost': 0.0,
#                                'outputs': 233704.85,
#                                'parameters': 0.0},
#                     'total': 233704.85},
#  'q_conv1d': {'energy': {'inputs': 3651.64,
#                          'op_cost': 282624.0,
#                          'outputs': 116852.42,
#                          'parameters': 60.86},
#               'total': 286336.5},
#  'q_conv1d_1': {'energy': {'inputs': 116852.42,
#                            'op_cost': 18087936.0,
#                            'outputs': 233704.85,
#                            'parameters': 3895.08},
#                 'total': 18208683.5},
#  'q_conv1d_2': {'energy': {'inputs': 116852.42,
#                            'op_cost': 36175872.0,
#                            'outputs': 233704.85,
#                            'parameters': 15580.32},
#                 'total': 36308304.74},
#  'q_conv1d_3': {'energy': {'inputs': 233704.85,
#                            'op_cost': 72351744.0,
#                            'outputs': 233704.85,
#                            'parameters': 31160.65},
#                 'total': 72616609.5},
#  'q_conv1d_4': {'energy': {'inputs': 116852.42,
#                            'op_cost': 72351744.0,
#                            'outputs': 233704.85,
#                            'parameters': 62321.29},
#                 'total': 72530917.71},
#  'q_conv1d_5': {'energy': {'inputs': 233704.85,
#                            'op_cost': 144703488.0,
#                            'outputs': 233704.85,
#                            'parameters': 124642.58},
#                 'total': 145061835.43},
#  'q_conv1d_6': {'energy': {'inputs': 116852.42,
#                            'op_cost': 144703488.0,
#                            'outputs': 233704.85,
#                            'parameters': 249285.17},
#                 'total': 145069625.59},
#  'q_dense': {'energy': {'inputs': 973.77,
#                         'op_cost': 602931.2,
#                         'outputs': 486.89,
#                         'parameters': 249772.05},
#              'total': 853677.0199999999},
#  'q_dense_1': {'energy': {'inputs': 486.89,
#                           'op_cost': 4710.4,
#                           'outputs': 7.61,
#                           'parameters': 1955.15},
#                'total': 7152.44}}
#
# Total energy: 494.94 uJ
