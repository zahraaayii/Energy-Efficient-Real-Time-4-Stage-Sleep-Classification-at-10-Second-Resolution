# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from tensorflow.keras.models import Model
from keras.layers import Conv1D, SeparableConv1D,GlobalAveragePooling1D,Add,concatenate, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\zazaz\AppData\Local\Temp\ipykernel_10444\3697400870.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install QKeras
from qkeras import *
import pprint
from qkeras.autoqkeras import *
from qkeras import *
from qkeras.qtools import run_qtools
from qkeras.qtools import settings as qtools_settings

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))

        recall = TP / (Positives+K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

        precision = TP / (Pred_Positives+K.epsilon())
        return precision
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, concatenate, Activation

def fire_module(x, squeeze_filters, expand_filters):
    squeeze = QConv1D(squeeze_filters, 1, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(x)
    expand_1x1 = QConv1D(expand_filters, 1, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(squeeze)
    expand_3x3 = QConv1D(expand_filters, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(squeeze)
    merged = concatenate([expand_1x1, expand_3x3], axis=-1)
    return merged

def SqueezeNet(input_shape, num_classes):
    input_layer = Input(shape=input_shape)
    x = QConv1D(64, 3, strides=2, padding='valid', activation='relu')(input_layer)
    x = MaxPooling1D(pool_size=3, strides=2)(x)
    
    x = fire_module(x, squeeze_filters=16, expand_filters=64)
    x = fire_module(x, squeeze_filters=16, expand_filters=64)
    x = MaxPooling1D(pool_size=3, strides=2)(x)
    
    x = fire_module(x, squeeze_filters=32, expand_filters=128)
    x = fire_module(x, squeeze_filters=32, expand_filters=128)
    x = MaxPooling1D(pool_size=3, strides=2)(x)
    
    x = fire_module(x, squeeze_filters=48, expand_filters=192)
    x = fire_module(x, squeeze_filters=48, expand_filters=192)
    x = fire_module(x, squeeze_filters=64, expand_filters=256)
    x = fire_module(x, squeeze_filters=64, expand_filters=256)
    
    x = Dropout(0.5)(x)

    x = GlobalAveragePooling1D()(x)
    output_layer =  QDense(num_classes,kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='softmax',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1))(x)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    return model
# Instantiate the model
input_shape = (3840,1)
num_classes = 4 
model = SqueezeNet(input_shape, num_classes)

# Print model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3840, 1)]    0           []
#
#  q_conv1d (QConv1D)             (None, 1919, 64)     256         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 959, 64)      0           ['q_conv1d[0][0]']
#
#  q_conv1d_1 (QConv1D)           (None, 959, 16)      1040        ['max_pooling1d[0][0]']
#
#  q_conv1d_2 (QConv1D)           (None, 959, 64)      1088        ['q_conv1d_1[0][0]']
#
#  q_conv1d_3 (QConv1D)           (None, 959, 64)      3136        ['q_conv1d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 959, 128)     0           ['q_conv1d_2[0][0]',
#                                                                   'q_conv1d_3[0][0]']
#
#  q_conv1d_4 (QConv1D)           (None, 959, 16)      2064        ['concatenate[0][0]']
#
#  q_conv1d_5 (QConv1D)           (None, 959, 64)      1088        ['q_conv1d_4[0][0]']
#
#  q_conv1d_6 (QConv1D)           (None, 959, 64)      3136        ['q_conv1d_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 959, 128)     0           ['q_conv1d_5[0][0]',
#                                                                   'q_conv1d_6[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 479, 128)    0           ['concatenate_1[0][0]']
#
#  q_conv1d_7 (QConv1D)           (None, 479, 32)      4128        ['max_pooling1d_1[0][0]']
#
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3840, 1)]    0           []
#
#  q_conv1d (QConv1D)             (None, 1919, 64)     256         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 959, 64)      0           ['q_conv1d[0][0]']
#
#  q_conv1d_1 (QConv1D)           (None, 959, 16)      1040        ['max_pooling1d[0][0]']
#
#  q_conv1d_2 (QConv1D)           (None, 959, 64)      1088        ['q_conv1d_1[0][0]']
#
#  q_conv1d_3 (QConv1D)           (None, 959, 64)      3136        ['q_conv1d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 959, 128)     0           ['q_conv1d_2[0][0]',
#                                                                   'q_conv1d_3[0][0]']
#
#  q_conv1d_4 (QConv1D)           (None, 959, 16)      2064        ['concatenate[0][0]']
#
#  q_conv1d_5 (QConv1D)           (None, 959, 64)      1088        ['q_conv1d_4[0][0]']
#
#  q_conv1d_6 (QConv1D)           (None, 959, 64)      3136        ['q_conv1d_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 959, 128)     0           ['q_conv1d_5[0][0]',
#                                                                   'q_conv1d_6[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 479, 128)    0           ['concatenate_1[0][0]']
#
#  q_conv1d_7 (QConv1D)           (None, 479, 32)      4128        ['max_pooling1d_1[0][0]']
#
#  q_conv1d_8 (QConv1D)           (None, 479, 128)     4224        ['q_conv1d_7[0][0]']
#
#  q_conv1d_9 (QConv1D)           (None, 479, 128)     12416       ['q_conv1d_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 479, 256)     0           ['q_conv1d_8[0][0]',
#                                                                   'q_conv1d_9[0][0]']
#
#  q_conv1d_10 (QConv1D)          (None, 479, 32)      8224        ['concatenate_2[0][0]']
#
#  q_conv1d_11 (QConv1D)          (None, 479, 128)     4224        ['q_conv1d_10[0][0]']
#
#  q_conv1d_12 (QConv1D)          (None, 479, 128)     12416       ['q_conv1d_10[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 479, 256)     0           ['q_conv1d_11[0][0]',
#                                                                   'q_conv1d_12[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 239, 256)    0           ['concatenate_3[0][0]']
#
#  q_conv1d_13 (QConv1D)          (None, 239, 48)      12336       ['max_pooling1d_2[0][0]']
#
#  q_conv1d_14 (QConv1D)          (None, 239, 192)     9408        ['q_conv1d_13[0][0]']
#
#  q_conv1d_15 (QConv1D)          (None, 239, 192)     27840       ['q_conv1d_13[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 239, 384)     0           ['q_conv1d_14[0][0]',
#                                                                   'q_conv1d_15[0][0]']
#
#  q_conv1d_16 (QConv1D)          (None, 239, 48)      18480       ['concatenate_4[0][0]']
#
#  q_conv1d_17 (QConv1D)          (None, 239, 192)     9408        ['q_conv1d_16[0][0]']
#
#  q_conv1d_18 (QConv1D)          (None, 239, 192)     27840       ['q_conv1d_16[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 239, 384)     0           ['q_conv1d_17[0][0]',
#                                                                   'q_conv1d_18[0][0]']
#
#  q_conv1d_19 (QConv1D)          (None, 239, 64)      24640       ['concatenate_5[0][0]']
#
#  q_conv1d_20 (QConv1D)          (None, 239, 256)     16640       ['q_conv1d_19[0][0]']
#
#  q_conv1d_21 (QConv1D)          (None, 239, 256)     49408       ['q_conv1d_19[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 239, 512)     0           ['q_conv1d_20[0][0]',
#                                                                   'q_conv1d_21[0][0]']
#
#  q_conv1d_22 (QConv1D)          (None, 239, 64)      32832       ['concatenate_6[0][0]']
#
#  q_conv1d_23 (QConv1D)          (None, 239, 256)     16640       ['q_conv1d_22[0][0]']
#
#  q_conv1d_24 (QConv1D)          (None, 239, 256)     49408       ['q_conv1d_22[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 239, 512)     0           ['q_conv1d_23[0][0]',
#                                                                   'q_conv1d_24[0][0]']
#
#  dropout (Dropout)              (None, 239, 512)     0           ['concatenate_7[0][0]']
#
#  global_average_pooling1d (Glob  (None, 512)         0           ['dropout[0][0]']
#  alAveragePooling1D)
#
#  q_dense (QDense)               (None, 4)            2052        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 354,372
# Trainable params: 354,372
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/SqueezeNet_fp8.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=128,epochs=100,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/100
# 351/351 [==============================] - 24s 61ms/step - loss: 1.3075 - accuracy: 0.5019 - f1: 0.3042 - val_loss: 1.2157 - val_accuracy: 0.5120 - val_f1: 0.4140
# Epoch 2/100
# 351/351 [==============================] - 23s 64ms/step - loss: 1.1862 - accuracy: 0.5185 - f1: 0.3865 - val_loss: 1.1493 - val_accuracy: 0.5317 - val_f1: 0.4857
# Epoch 3/100
# 351/351 [==============================] - 23s 65ms/step - loss: 1.1034 - accuracy: 0.5525 - f1: 0.4721 - val_loss: 1.1532 - val_accuracy: 0.4880 - val_f1: 0.3826
# Epoch 4/100
# 351/351 [==============================] - 23s 65ms/step - loss: 1.0088 - accuracy: 0.5934 - f1: 0.5369 - val_loss: 1.0173 - val_accuracy: 0.5793 - val_f1: 0.5029
# Epoch 5/100
# 351/351 [==============================] - 24s 68ms/step - loss: 0.9265 - accuracy: 0.6271 - f1: 0.5887 - val_loss: 0.9627 - val_accuracy: 0.6100 - val_f1: 0.5743
# Epoch 6/100
# 351/351 [==============================] - 24s 69ms/step - loss: 0.8682 - accuracy: 0.6551 - f1: 0.6240 - val_loss: 0.8692 - val_accuracy: 0.6558 - val_f1: 0.5720
# Epoch 7/100
# 351/351 [==============================] - 24s 70ms/step - loss: 0.8142 - accuracy: 0.6734 - f1: 0.6496 - val_loss: 0.8479 - val_accuracy: 0.6378 - val_f1: 0.6140
# Epoch 8/100
# 351/351 [==============================] - 22s 62ms/step - loss: 0.7667 - accuracy: 0.6947 - f1: 0.6763 - val_loss: 0.8054 - val_accuracy: 0.6705 - val_f1: 0.6660
# Epoch 9/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.7258 - accuracy: 0.7110 - f1: 0.6975 - val_loss: 0.7409 - val_accuracy: 0.7056 - val_f1: 0.6943
# Epoch 10/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.6921 - accuracy: 0.7249 - f1: 0.7150 - val_loss: 0.7611 - val_accuracy: 0.6920 - val_f1: 0.6865
# Epoch 11/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.6556 - accuracy: 0.7380 - f1: 0.7290 - val_loss: 0.6940 - val_accuracy: 0.7311 - val_f1: 0.7237
# Epoch 12/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.6330 - accuracy: 0.7489 - f1: 0.7410 - val_loss: 0.7072 - val_accuracy: 0.7197 - val_f1: 0.7157
# Epoch 13/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.6082 - accuracy: 0.7608 - f1: 0.7528 - val_loss: 0.6361 - val_accuracy: 0.7450 - val_f1: 0.7423
# Epoch 14/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.5862 - accuracy: 0.7689 - f1: 0.7625 - val_loss: 0.5698 - val_accuracy: 0.7695 - val_f1: 0.7660
# Epoch 15/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.5603 - accuracy: 0.7802 - f1: 0.7760 - val_loss: 0.5744 - val_accuracy: 0.7713 - val_f1: 0.7683
# Epoch 16/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.5387 - accuracy: 0.7876 - f1: 0.7837 - val_loss: 0.5652 - val_accuracy: 0.7757 - val_f1: 0.7732
# Epoch 17/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.5163 - accuracy: 0.7973 - f1: 0.7938 - val_loss: 0.5427 - val_accuracy: 0.7890 - val_f1: 0.7817
# Epoch 18/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4929 - accuracy: 0.8074 - f1: 0.8044 - val_loss: 0.5528 - val_accuracy: 0.7849 - val_f1: 0.7840
# Epoch 19/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4783 - accuracy: 0.8150 - f1: 0.8116 - val_loss: 0.5501 - val_accuracy: 0.7809 - val_f1: 0.7764
# Epoch 20/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4639 - accuracy: 0.8195 - f1: 0.8160 - val_loss: 0.5431 - val_accuracy: 0.7817 - val_f1: 0.7822
# Epoch 21/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4445 - accuracy: 0.8261 - f1: 0.8240 - val_loss: 0.5223 - val_accuracy: 0.7960 - val_f1: 0.7945
# Epoch 22/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4342 - accuracy: 0.8316 - f1: 0.8293 - val_loss: 0.5443 - val_accuracy: 0.7849 - val_f1: 0.7821
# Epoch 23/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4354 - accuracy: 0.8302 - f1: 0.8285 - val_loss: 0.5230 - val_accuracy: 0.7950 - val_f1: 0.7937
# Epoch 24/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.4022 - accuracy: 0.8447 - f1: 0.8433 - val_loss: 0.5380 - val_accuracy: 0.7928 - val_f1: 0.7931
# Epoch 25/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3881 - accuracy: 0.8518 - f1: 0.8504 - val_loss: 0.5070 - val_accuracy: 0.8000 - val_f1: 0.7970
# Epoch 26/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3686 - accuracy: 0.8577 - f1: 0.8565 - val_loss: 0.4570 - val_accuracy: 0.8221 - val_f1: 0.8210
# Epoch 27/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3569 - accuracy: 0.8626 - f1: 0.8623 - val_loss: 0.4644 - val_accuracy: 0.8221 - val_f1: 0.8196
# Epoch 28/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3436 - accuracy: 0.8687 - f1: 0.8669 - val_loss: 0.4648 - val_accuracy: 0.8159 - val_f1: 0.8153
# Epoch 29/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3360 - accuracy: 0.8717 - f1: 0.8712 - val_loss: 0.4576 - val_accuracy: 0.8263 - val_f1: 0.8259
# Epoch 30/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3188 - accuracy: 0.8791 - f1: 0.8787 - val_loss: 0.4776 - val_accuracy: 0.8223 - val_f1: 0.8225
# Epoch 31/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.3114 - accuracy: 0.8807 - f1: 0.8806 - val_loss: 0.3943 - val_accuracy: 0.8542 - val_f1: 0.8534
# Epoch 32/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2970 - accuracy: 0.8873 - f1: 0.8867 - val_loss: 0.4891 - val_accuracy: 0.8189 - val_f1: 0.8172
# Epoch 33/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2932 - accuracy: 0.8873 - f1: 0.8878 - val_loss: 0.5307 - val_accuracy: 0.8080 - val_f1: 0.8087
# Epoch 34/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2742 - accuracy: 0.8959 - f1: 0.8961 - val_loss: 0.4074 - val_accuracy: 0.8466 - val_f1: 0.8478
# Epoch 35/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2687 - accuracy: 0.8987 - f1: 0.8984 - val_loss: 0.4431 - val_accuracy: 0.8408 - val_f1: 0.8417
# Epoch 36/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2630 - accuracy: 0.9007 - f1: 0.9009 - val_loss: 0.4198 - val_accuracy: 0.8492 - val_f1: 0.8490
# Epoch 37/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2440 - accuracy: 0.9070 - f1: 0.9068 - val_loss: 0.4172 - val_accuracy: 0.8578 - val_f1: 0.8577
# Epoch 38/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2368 - accuracy: 0.9125 - f1: 0.9119 - val_loss: 0.4100 - val_accuracy: 0.8508 - val_f1: 0.8512
# Epoch 39/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2376 - accuracy: 0.9120 - f1: 0.9120 - val_loss: 0.3978 - val_accuracy: 0.8532 - val_f1: 0.8523
# Epoch 40/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2338 - accuracy: 0.9127 - f1: 0.9125 - val_loss: 0.3875 - val_accuracy: 0.8570 - val_f1: 0.8560
# Epoch 41/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2239 - accuracy: 0.9154 - f1: 0.9148 - val_loss: 0.4152 - val_accuracy: 0.8594 - val_f1: 0.8589
# Epoch 42/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2199 - accuracy: 0.9174 - f1: 0.9172 - val_loss: 0.4976 - val_accuracy: 0.8341 - val_f1: 0.8336
# Epoch 43/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2194 - accuracy: 0.9182 - f1: 0.9183 - val_loss: 0.4048 - val_accuracy: 0.8608 - val_f1: 0.8598
# Epoch 44/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1987 - accuracy: 0.9268 - f1: 0.9264 - val_loss: 0.3755 - val_accuracy: 0.8761 - val_f1: 0.8761
# Epoch 45/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.2100 - accuracy: 0.9235 - f1: 0.9233 - val_loss: 0.3782 - val_accuracy: 0.8753 - val_f1: 0.8756
# Epoch 46/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1975 - accuracy: 0.9277 - f1: 0.9279 - val_loss: 0.3539 - val_accuracy: 0.8839 - val_f1: 0.8849
# Epoch 47/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1844 - accuracy: 0.9326 - f1: 0.9324 - val_loss: 0.3896 - val_accuracy: 0.8655 - val_f1: 0.8649
# Epoch 48/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1999 - accuracy: 0.9271 - f1: 0.9270 - val_loss: 0.3742 - val_accuracy: 0.8717 - val_f1: 0.8726
# Epoch 49/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1763 - accuracy: 0.9375 - f1: 0.9378 - val_loss: 0.4090 - val_accuracy: 0.8576 - val_f1: 0.8552
# Epoch 50/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1675 - accuracy: 0.9385 - f1: 0.9384 - val_loss: 0.3910 - val_accuracy: 0.8737 - val_f1: 0.8742
# Epoch 51/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1813 - accuracy: 0.9345 - f1: 0.9342 - val_loss: 0.4152 - val_accuracy: 0.8671 - val_f1: 0.8682
# Epoch 52/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1727 - accuracy: 0.9372 - f1: 0.9368 - val_loss: 0.3999 - val_accuracy: 0.8745 - val_f1: 0.8752
# Epoch 53/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1678 - accuracy: 0.9404 - f1: 0.9405 - val_loss: 0.3781 - val_accuracy: 0.8813 - val_f1: 0.8814
# Epoch 54/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1594 - accuracy: 0.9424 - f1: 0.9423 - val_loss: 0.4015 - val_accuracy: 0.8683 - val_f1: 0.8681
# Epoch 55/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1676 - accuracy: 0.9392 - f1: 0.9394 - val_loss: 0.3778 - val_accuracy: 0.8799 - val_f1: 0.8797
# Epoch 56/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1565 - accuracy: 0.9427 - f1: 0.9429 - val_loss: 0.4841 - val_accuracy: 0.8627 - val_f1: 0.8623
# Epoch 57/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1542 - accuracy: 0.9449 - f1: 0.9450 - val_loss: 0.4153 - val_accuracy: 0.8793 - val_f1: 0.8789
# Epoch 58/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1604 - accuracy: 0.9421 - f1: 0.9422 - val_loss: 0.3626 - val_accuracy: 0.8831 - val_f1: 0.8839
# Epoch 59/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1475 - accuracy: 0.9482 - f1: 0.9481 - val_loss: 0.4442 - val_accuracy: 0.8614 - val_f1: 0.8617
# Epoch 60/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1524 - accuracy: 0.9454 - f1: 0.9455 - val_loss: 0.3659 - val_accuracy: 0.8894 - val_f1: 0.8898
# Epoch 61/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1543 - accuracy: 0.9440 - f1: 0.9442 - val_loss: 0.4057 - val_accuracy: 0.8809 - val_f1: 0.8817
# Epoch 62/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1519 - accuracy: 0.9455 - f1: 0.9455 - val_loss: 0.3956 - val_accuracy: 0.8827 - val_f1: 0.8836
# Epoch 63/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1436 - accuracy: 0.9491 - f1: 0.9491 - val_loss: 0.3855 - val_accuracy: 0.8801 - val_f1: 0.8802
# Epoch 64/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1453 - accuracy: 0.9490 - f1: 0.9489 - val_loss: 0.4069 - val_accuracy: 0.8821 - val_f1: 0.8834
# Epoch 65/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1487 - accuracy: 0.9468 - f1: 0.9470 - val_loss: 0.4181 - val_accuracy: 0.8773 - val_f1: 0.8779
# Epoch 66/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1288 - accuracy: 0.9534 - f1: 0.9534 - val_loss: 0.4241 - val_accuracy: 0.8729 - val_f1: 0.8737
# Epoch 67/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1390 - accuracy: 0.9510 - f1: 0.9514 - val_loss: 0.4218 - val_accuracy: 0.8823 - val_f1: 0.8828
# Epoch 68/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1263 - accuracy: 0.9555 - f1: 0.9556 - val_loss: 0.3953 - val_accuracy: 0.8876 - val_f1: 0.8874
# Epoch 69/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1252 - accuracy: 0.9566 - f1: 0.9566 - val_loss: 0.4208 - val_accuracy: 0.8865 - val_f1: 0.8870
# Epoch 70/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1391 - accuracy: 0.9500 - f1: 0.9502 - val_loss: 0.3566 - val_accuracy: 0.8960 - val_f1: 0.8967
# Epoch 71/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1337 - accuracy: 0.9528 - f1: 0.9528 - val_loss: 0.3606 - val_accuracy: 0.8934 - val_f1: 0.8931
# Epoch 72/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1279 - accuracy: 0.9549 - f1: 0.9551 - val_loss: 0.3679 - val_accuracy: 0.8932 - val_f1: 0.8927
# Epoch 73/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1323 - accuracy: 0.9531 - f1: 0.9531 - val_loss: 0.4001 - val_accuracy: 0.8898 - val_f1: 0.8897
# Epoch 74/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1270 - accuracy: 0.9565 - f1: 0.9566 - val_loss: 0.4274 - val_accuracy: 0.8787 - val_f1: 0.8786
# Epoch 75/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1303 - accuracy: 0.9554 - f1: 0.9549 - val_loss: 0.3407 - val_accuracy: 0.9000 - val_f1: 0.9002
# Epoch 76/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1217 - accuracy: 0.9571 - f1: 0.9572 - val_loss: 0.4048 - val_accuracy: 0.8859 - val_f1: 0.8861
# Epoch 77/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1282 - accuracy: 0.9544 - f1: 0.9547 - val_loss: 0.4082 - val_accuracy: 0.8787 - val_f1: 0.8788
# Epoch 78/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1268 - accuracy: 0.9559 - f1: 0.9561 - val_loss: 0.3990 - val_accuracy: 0.8867 - val_f1: 0.8861
# Epoch 79/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1181 - accuracy: 0.9588 - f1: 0.9590 - val_loss: 0.4179 - val_accuracy: 0.8793 - val_f1: 0.8801
# Epoch 80/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1370 - accuracy: 0.9520 - f1: 0.9516 - val_loss: 0.3964 - val_accuracy: 0.8928 - val_f1: 0.8932
# Epoch 81/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1308 - accuracy: 0.9552 - f1: 0.9552 - val_loss: 0.3961 - val_accuracy: 0.8906 - val_f1: 0.8906
# Epoch 82/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1154 - accuracy: 0.9597 - f1: 0.9600 - val_loss: 0.3886 - val_accuracy: 0.9004 - val_f1: 0.9012
# Epoch 83/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1080 - accuracy: 0.9617 - f1: 0.9617 - val_loss: 0.3462 - val_accuracy: 0.9078 - val_f1: 0.9080
# Epoch 84/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1258 - accuracy: 0.9555 - f1: 0.9557 - val_loss: 0.4285 - val_accuracy: 0.8761 - val_f1: 0.8761
# Epoch 85/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1148 - accuracy: 0.9595 - f1: 0.9593 - val_loss: 0.4334 - val_accuracy: 0.8735 - val_f1: 0.8736
# Epoch 86/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1298 - accuracy: 0.9539 - f1: 0.9539 - val_loss: 0.4237 - val_accuracy: 0.8876 - val_f1: 0.8869
# Epoch 87/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1098 - accuracy: 0.9615 - f1: 0.9616 - val_loss: 0.4592 - val_accuracy: 0.8719 - val_f1: 0.8727
# Epoch 88/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1036 - accuracy: 0.9635 - f1: 0.9640 - val_loss: 0.3935 - val_accuracy: 0.8859 - val_f1: 0.8865
# Epoch 89/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1180 - accuracy: 0.9586 - f1: 0.9587 - val_loss: 0.4306 - val_accuracy: 0.8683 - val_f1: 0.8695
# Epoch 90/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1115 - accuracy: 0.9614 - f1: 0.9615 - val_loss: 0.3202 - val_accuracy: 0.9020 - val_f1: 0.9023
# Epoch 91/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1092 - accuracy: 0.9616 - f1: 0.9615 - val_loss: 0.4149 - val_accuracy: 0.8809 - val_f1: 0.8813
# Epoch 92/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.0931 - accuracy: 0.9668 - f1: 0.9670 - val_loss: 0.3898 - val_accuracy: 0.9040 - val_f1: 0.9041
# Epoch 93/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1174 - accuracy: 0.9586 - f1: 0.9588 - val_loss: 0.4831 - val_accuracy: 0.8606 - val_f1: 0.8606
# Epoch 94/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1034 - accuracy: 0.9647 - f1: 0.9649 - val_loss: 0.4381 - val_accuracy: 0.8827 - val_f1: 0.8831
# Epoch 95/100
# 351/351 [==============================] - 21s 59ms/step - loss: 0.1098 - accuracy: 0.9617 - f1: 0.9618 - val_loss: 0.3376 - val_accuracy: 0.9072 - val_f1: 0.9078
# Epoch 96/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1115 - accuracy: 0.9614 - f1: 0.9615 - val_loss: 0.3946 - val_accuracy: 0.8960 - val_f1: 0.8959
# Epoch 97/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1078 - accuracy: 0.9623 - f1: 0.9625 - val_loss: 0.3857 - val_accuracy: 0.8972 - val_f1: 0.8976
# Epoch 98/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.0955 - accuracy: 0.9664 - f1: 0.9662 - val_loss: 0.4483 - val_accuracy: 0.8753 - val_f1: 0.8759
# Epoch 99/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1000 - accuracy: 0.9662 - f1: 0.9661 - val_loss: 0.4509 - val_accuracy: 0.8797 - val_f1: 0.8802
# Epoch 100/100
# 351/351 [==============================] - 21s 60ms/step - loss: 0.1217 - accuracy: 0.9573 - f1: 0.9571 - val_loss: 0.3971 - val_accuracy: 0.8960 - val_f1: 0.8964

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/SqueezeNet_fp8.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=128)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 98/98 [==============================] - 3s 22ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.96      0.75      0.84      2810
#          REM       0.93      0.87      0.90      1809
#        LIGHT       0.86      0.96      0.91      6233
#         DEEP       0.90      0.91      0.91      1598
#
#     accuracy                           0.89     12450
#    macro avg       0.91      0.87      0.89     12450
# weighted avg       0.90      0.89      0.89     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=False,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# operation count for <keras.layers.pooling.global_average_pooling1d.GlobalAveragePooling1D object at 0x000001967AB3F910> is defaulted to 0
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 1,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 1,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1919,
#                 64
#             ]
#         },
#         "operation_count": 368448
#     },
#     "max_pooling1d": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 122816
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 64,
#                 16
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 16
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 16
#             ]
#         },
#         "operation_count": 982016
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 982016
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 2946048
#     },
#     "concatenate": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 128
#             ]
#         },
#         "operation_count": 61376
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 128,
#                 16
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 16
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 16
#             ]
#         },
#         "operation_count": 1964032
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 982016
#     },
#     "q_conv1d_6": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 2946048
#     },
#     "concatenate_1": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 128
#             ]
#         },
#         "operation_count": 61376
#     },
#     "max_pooling1d_1": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 122752
#     },
#     "q_conv1d_7": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 128,
#                 32
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 32
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 32
#             ]
#         },
#         "operation_count": 1961984
#     },
#     "q_conv1d_8": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 1961984
#     },
#     "q_conv1d_9": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 5885952
#     },
#     "concatenate_2": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 256
#             ]
#         },
#         "operation_count": 61312
#     },
#     "q_conv1d_10": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 256,
#                 32
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 32
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 32
#             ]
#         },
#         "operation_count": 3923968
#     },
#     "q_conv1d_11": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 1961984
#     },
#     "q_conv1d_12": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 5885952
#     },
#     "concatenate_3": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 256
#             ]
#         },
#         "operation_count": 61312
#     },
#     "max_pooling1d_2": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 122624
#     },
#     "q_conv1d_13": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 256,
#                 48
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 48
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 48
#             ]
#         },
#         "operation_count": 2936832
#     },
#     "q_conv1d_14": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 2202624
#     },
#     "q_conv1d_15": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 6607872
#     },
#     "concatenate_4": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 384
#             ]
#         },
#         "operation_count": 45888
#     },
#     "q_conv1d_16": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 384,
#                 48
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 48
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 48
#             ]
#         },
#         "operation_count": 4405248
#     },
#     "q_conv1d_17": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 2202624
#     },
#     "q_conv1d_18": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 6607872
#     },
#     "concatenate_5": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 384
#             ]
#         },
#         "operation_count": 45888
#     },
#     "q_conv1d_19": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 384,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 64
#             ]
#         },
#         "operation_count": 5873664
#     },
#     "q_conv1d_20": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 3915776
#     },
#     "q_conv1d_21": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 11747328
#     },
#     "concatenate_6": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 512
#             ]
#         },
#         "operation_count": 61184
#     },
#     "q_conv1d_22": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 512,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 64
#             ]
#         },
#         "operation_count": 7831552
#     },
#     "q_conv1d_23": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 1,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 3915776
#     },
#     "q_conv1d_24": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 11747328
#     },
#     "concatenate_7": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 512
#             ]
#         },
#         "operation_count": 61184
#     },
#     "global_average_pooling1d": {
#         "layer_type": "GlobalAveragePooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 512
#             ]
#         },
#         "operation_count": 0
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 512,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 2048
#     }
# }
# {'concatenate': {'energy': {'inputs': 233461.4,
#                             'op_cost': 0.0,
#                             'outputs': 233461.4,
#                             'parameters': 0.0},
#                  'total': 233461.4},
#  'concatenate_1': {'energy': {'inputs': 233461.4,
#                               'op_cost': 0.0,
#                               'outputs': 233461.4,
#                               'parameters': 0.0},
#                    'total': 233461.4},
#  'concatenate_2': {'energy': {'inputs': 233217.96,
#                               'op_cost': 0.0,
#                               'outputs': 233217.96,
#                               'parameters': 0.0},
#                    'total': 233217.96},
#  'concatenate_3': {'energy': {'inputs': 233217.96,
#                               'op_cost': 0.0,
#                               'outputs': 233217.96,
#                               'parameters': 0.0},
#                    'total': 233217.96},
#  'concatenate_4': {'energy': {'inputs': 174548.31,
#                               'op_cost': 0.0,
#                               'outputs': 174548.31,
#                               'parameters': 0.0},
#                    'total': 174548.31},
#  'concatenate_5': {'energy': {'inputs': 174548.31,
#                               'op_cost': 0.0,
#                               'outputs': 174548.31,
#                               'parameters': 0.0},
#                    'total': 174548.31},
#  'concatenate_6': {'energy': {'inputs': 232731.08,
#                               'op_cost': 0.0,
#                               'outputs': 232731.08,
#                               'parameters': 0.0},
#                    'total': 232731.08},
#  'concatenate_7': {'energy': {'inputs': 232731.08,
#                               'op_cost': 0.0,
#                               'outputs': 232731.08,
#                               'parameters': 0.0},
#                    'total': 232731.08},
#  'global_average_pooling1d': {'energy': {'inputs': 232731.08,
#                                          'op_cost': 0.0,
#                                          'outputs': 973.77,
#                                          'parameters': 0.0},
#                               'total': 232731.08},
#  'max_pooling1d': {'energy': {'inputs': 233583.13,
#                               'op_cost': 0.0,
#                               'outputs': 116730.7,
#                               'parameters': 0.0},
#                    'total': 233583.13},
#  'max_pooling1d_1': {'energy': {'inputs': 233461.4,
#                                 'op_cost': 0.0,
#                                 'outputs': 116608.98,
#                                 'parameters': 0.0},
#                      'total': 233461.4},
#  'max_pooling1d_2': {'energy': {'inputs': 233217.96,
#                                 'op_cost': 0.0,
#                                 'outputs': 116365.54,
#                                 'parameters': 0.0},
#                      'total': 233217.96},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 1694860.8,
#                          'outputs': 233583.13,
#                          'parameters': 121.72},
#               'total': 1702285.8},
#  'q_conv1d_1': {'energy': {'inputs': 116730.7,
#                            'op_cost': 4517273.6,
#                            'outputs': 29182.68,
#                            'parameters': 494.49},
#                 'total': 4634498.79},
#  'q_conv1d_10': {'energy': {'inputs': 233217.96,
#                             'op_cost': 18050252.8,
#                             'outputs': 29152.25,
#                             'parameters': 3910.3},
#                  'total': 18287381.060000002},
#  'q_conv1d_11': {'energy': {'inputs': 29152.25,
#                             'op_cost': 9025126.4,
#                             'outputs': 116608.98,
#                             'parameters': 2008.4},
#                  'total': 9056287.05},
#  'q_conv1d_12': {'energy': {'inputs': 29152.25,
#                             'op_cost': 27075379.2,
#                             'outputs': 116608.98,
#                             'parameters': 5903.48},
#                  'total': 27110434.93},
#  'q_conv1d_13': {'energy': {'inputs': 116365.54,
#                             'op_cost': 13509427.2,
#                             'outputs': 21818.54,
#                             'parameters': 5865.44},
#                  'total': 13631658.18},
#  'q_conv1d_14': {'energy': {'inputs': 21818.54,
#                             'op_cost': 10132070.4,
#                             'outputs': 87274.15,
#                             'parameters': 4473.26},
#                  'total': 10158362.200000001},
#  'q_conv1d_15': {'energy': {'inputs': 21818.54,
#                             'op_cost': 30396211.2,
#                             'outputs': 87274.15,
#                             'parameters': 13237.19},
#                  'total': 30431266.93},
#  'q_conv1d_16': {'energy': {'inputs': 174548.31,
#                             'op_cost': 20264140.8,
#                             'outputs': 21818.54,
#                             'parameters': 8786.75},
#                  'total': 20447475.86},
#  'q_conv1d_17': {'energy': {'inputs': 21818.54,
#                             'op_cost': 10132070.4,
#                             'outputs': 87274.15,
#                             'parameters': 4473.26},
#                  'total': 10158362.200000001},
#  'q_conv1d_18': {'energy': {'inputs': 21818.54,
#                             'op_cost': 30396211.2,
#                             'outputs': 87274.15,
#                             'parameters': 13237.19},
#                  'total': 30431266.93},
#  'q_conv1d_19': {'energy': {'inputs': 174548.31,
#                             'op_cost': 27018854.4,
#                             'outputs': 29091.38,
#                             'parameters': 11715.67},
#                  'total': 27205118.38},
#  'q_conv1d_2': {'energy': {'inputs': 29182.68,
#                            'op_cost': 4517273.6,
#                            'outputs': 116730.7,
#                            'parameters': 517.32},
#                 'total': 4546973.6},
#  'q_conv1d_20': {'energy': {'inputs': 29091.38,
#                             'op_cost': 18012569.6,
#                             'outputs': 116365.54,
#                             'parameters': 7911.88},
#                  'total': 18049572.860000003},
#  'q_conv1d_21': {'energy': {'inputs': 29091.38,
#                             'op_cost': 54037708.8,
#                             'outputs': 116365.54,
#                             'parameters': 23492.21},
#                  'total': 54090292.39},
#  'q_conv1d_22': {'energy': {'inputs': 232731.08,
#                             'op_cost': 36025139.2,
#                             'outputs': 29091.38,
#                             'parameters': 15610.75},
#                  'total': 36273481.03},
#  'q_conv1d_23': {'energy': {'inputs': 29091.38,
#                             'op_cost': 18012569.6,
#                             'outputs': 116365.54,
#                             'parameters': 7911.88},
#                  'total': 18049572.860000003},
#  'q_conv1d_24': {'energy': {'inputs': 29091.38,
#                             'op_cost': 54037708.8,
#                             'outputs': 116365.54,
#                             'parameters': 23492.21},
#                  'total': 54090292.39},
#  'q_conv1d_3': {'energy': {'inputs': 29182.68,
#                            'op_cost': 13551820.8,
#                            'outputs': 116730.7,
#                            'parameters': 1491.09},
#                 'total': 13582494.57},
#  'q_conv1d_4': {'energy': {'inputs': 233461.4,
#                            'op_cost': 9034547.2,
#                            'outputs': 29182.68,
#                            'parameters': 981.38},
#                 'total': 9268989.979999999},
#  'q_conv1d_5': {'energy': {'inputs': 29182.68,
#                            'op_cost': 4517273.6,
#                            'outputs': 116730.7,
#                            'parameters': 517.32},
#                 'total': 4546973.6},
#  'q_conv1d_6': {'energy': {'inputs': 29182.68,
#                            'op_cost': 13551820.8,
#                            'outputs': 116730.7,
#                            'parameters': 1491.09},
#                 'total': 13582494.57},
#  'q_conv1d_7': {'energy': {'inputs': 116608.98,
#                            'op_cost': 9025126.4,
#                            'outputs': 29152.25,
#                            'parameters': 1962.76},
#                 'total': 9143698.14},
#  'q_conv1d_8': {'energy': {'inputs': 29152.25,
#                            'op_cost': 9025126.4,
#                            'outputs': 116608.98,
#                            'parameters': 2008.4},
#                 'total': 9056287.05},
#  'q_conv1d_9': {'energy': {'inputs': 29152.25,
#                            'op_cost': 27075379.2,
#                            'outputs': 116608.98,
#                            'parameters': 5903.48},
#                 'total': 27110434.93},
#  'q_dense': {'energy': {'inputs': 973.77,
#                         'op_cost': 9420.8,
#                         'outputs': 7.61,
#                         'parameters': 977.57},
#              'total': 11372.14}}
#
# Total energy: 477.34 uJ

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=True,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# operation count for <keras.layers.pooling.global_average_pooling1d.GlobalAveragePooling1D object at 0x000001967AB3F910> is defaulted to 0
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 1,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1919,
#                 64
#             ]
#         },
#         "operation_count": 368448
#     },
#     "max_pooling1d": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 122816
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 64,
#                 16
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 16
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 16
#             ]
#         },
#         "operation_count": 982016
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 982016
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 2946048
#     },
#     "concatenate": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 128
#             ]
#         },
#         "operation_count": 61376
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 128,
#                 16
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 16
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 16
#             ]
#         },
#         "operation_count": 1964032
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 982016
#     },
#     "q_conv1d_6": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 16,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 64
#             ]
#         },
#         "operation_count": 2946048
#     },
#     "concatenate_1": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 959,
#                 128
#             ]
#         },
#         "operation_count": 61376
#     },
#     "max_pooling1d_1": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 122752
#     },
#     "q_conv1d_7": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 128,
#                 32
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 32
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 32
#             ]
#         },
#         "operation_count": 1961984
#     },
#     "q_conv1d_8": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 1961984
#     },
#     "q_conv1d_9": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 5885952
#     },
#     "concatenate_2": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 256
#             ]
#         },
#         "operation_count": 61312
#     },
#     "q_conv1d_10": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 256,
#                 32
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 32
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 32
#             ]
#         },
#         "operation_count": 3923968
#     },
#     "q_conv1d_11": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 1961984
#     },
#     "q_conv1d_12": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 32,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 128
#             ]
#         },
#         "operation_count": 5885952
#     },
#     "concatenate_3": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 479,
#                 256
#             ]
#         },
#         "operation_count": 61312
#     },
#     "max_pooling1d_2": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 122624
#     },
#     "q_conv1d_13": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 256,
#                 48
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 48
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 48
#             ]
#         },
#         "operation_count": 2936832
#     },
#     "q_conv1d_14": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 2202624
#     },
#     "q_conv1d_15": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 6607872
#     },
#     "concatenate_4": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 384
#             ]
#         },
#         "operation_count": 45888
#     },
#     "q_conv1d_16": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 384,
#                 48
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 48
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 48
#             ]
#         },
#         "operation_count": 4405248
#     },
#     "q_conv1d_17": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 2202624
#     },
#     "q_conv1d_18": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 48,
#                 192
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 192
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 192
#             ]
#         },
#         "operation_count": 6607872
#     },
#     "concatenate_5": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 384
#             ]
#         },
#         "operation_count": 45888
#     },
#     "q_conv1d_19": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 384,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 64
#             ]
#         },
#         "operation_count": 5873664
#     },
#     "q_conv1d_20": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 3915776
#     },
#     "q_conv1d_21": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 11747328
#     },
#     "concatenate_6": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 512
#             ]
#         },
#         "operation_count": 61184
#     },
#     "q_conv1d_22": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 512,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 64
#             ]
#         },
#         "operation_count": 7831552
#     },
#     "q_conv1d_23": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 1,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 3915776
#     },
#     "q_conv1d_24": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 64,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 256
#             ]
#         },
#         "operation_count": 11747328
#     },
#     "concatenate_7": {
#         "layer_type": "Concatenate",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             },
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "Concatenate_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 239,
#                 512
#             ]
#         },
#         "operation_count": 61184
#     },
#     "global_average_pooling1d": {
#         "layer_type": "GlobalAveragePooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 512
#             ]
#         },
#         "operation_count": 0
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 512,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 2048
#     }
# }
# {'concatenate': {'energy': {'inputs': 233461.4,
#                             'op_cost': 0.0,
#                             'outputs': 233461.4,
#                             'parameters': 0.0},
#                  'total': 233461.4},
#  'concatenate_1': {'energy': {'inputs': 233461.4,
#                               'op_cost': 0.0,
#                               'outputs': 233461.4,
#                               'parameters': 0.0},
#                    'total': 233461.4},
#  'concatenate_2': {'energy': {'inputs': 233217.96,
#                               'op_cost': 0.0,
#                               'outputs': 233217.96,
#                               'parameters': 0.0},
#                    'total': 233217.96},
#  'concatenate_3': {'energy': {'inputs': 233217.96,
#                               'op_cost': 0.0,
#                               'outputs': 233217.96,
#                               'parameters': 0.0},
#                    'total': 233217.96},
#  'concatenate_4': {'energy': {'inputs': 174548.31,
#                               'op_cost': 0.0,
#                               'outputs': 174548.31,
#                               'parameters': 0.0},
#                    'total': 174548.31},
#  'concatenate_5': {'energy': {'inputs': 174548.31,
#                               'op_cost': 0.0,
#                               'outputs': 174548.31,
#                               'parameters': 0.0},
#                    'total': 174548.31},
#  'concatenate_6': {'energy': {'inputs': 232731.08,
#                               'op_cost': 0.0,
#                               'outputs': 232731.08,
#                               'parameters': 0.0},
#                    'total': 232731.08},
#  'concatenate_7': {'energy': {'inputs': 232731.08,
#                               'op_cost': 0.0,
#                               'outputs': 232731.08,
#                               'parameters': 0.0},
#                    'total': 232731.08},
#  'global_average_pooling1d': {'energy': {'inputs': 232731.08,
#                                          'op_cost': 0.0,
#                                          'outputs': 973.77,
#                                          'parameters': 0.0},
#                               'total': 232731.08},
#  'max_pooling1d': {'energy': {'inputs': 233583.13,
#                               'op_cost': 0.0,
#                               'outputs': 116730.7,
#                               'parameters': 0.0},
#                    'total': 233583.13},
#  'max_pooling1d_1': {'energy': {'inputs': 233461.4,
#                                 'op_cost': 0.0,
#                                 'outputs': 116608.98,
#                                 'parameters': 0.0},
#                      'total': 233461.4},
#  'max_pooling1d_2': {'energy': {'inputs': 233217.96,
#                                 'op_cost': 0.0,
#                                 'outputs': 116365.54,
#                                 'parameters': 0.0},
#                      'total': 233217.96},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 1694860.8,
#                          'outputs': 233583.13,
#                          'parameters': 486.89},
#               'total': 1702650.97},
#  'q_conv1d_1': {'energy': {'inputs': 116730.7,
#                            'op_cost': 4517273.6,
#                            'outputs': 29182.68,
#                            'parameters': 1977.97},
#                 'total': 4635982.27},
#  'q_conv1d_10': {'energy': {'inputs': 233217.96,
#                             'op_cost': 18050252.8,
#                             'outputs': 29152.25,
#                             'parameters': 15641.18},
#                  'total': 18299111.94},
#  'q_conv1d_11': {'energy': {'inputs': 29152.25,
#                             'op_cost': 9025126.4,
#                             'outputs': 116608.98,
#                             'parameters': 8033.6},
#                  'total': 9062312.25},
#  'q_conv1d_12': {'energy': {'inputs': 29152.25,
#                             'op_cost': 27075379.2,
#                             'outputs': 116608.98,
#                             'parameters': 23613.93},
#                  'total': 27128145.38},
#  'q_conv1d_13': {'energy': {'inputs': 116365.54,
#                             'op_cost': 13509427.2,
#                             'outputs': 21818.54,
#                             'parameters': 23461.78},
#                  'total': 13649254.52},
#  'q_conv1d_14': {'energy': {'inputs': 21818.54,
#                             'op_cost': 10132070.4,
#                             'outputs': 87274.15,
#                             'parameters': 17893.03},
#                  'total': 10171781.97},
#  'q_conv1d_15': {'energy': {'inputs': 21818.54,
#                             'op_cost': 30396211.2,
#                             'outputs': 87274.15,
#                             'parameters': 52948.75},
#                  'total': 30470978.49},
#  'q_conv1d_16': {'energy': {'inputs': 174548.31,
#                             'op_cost': 20264140.8,
#                             'outputs': 21818.54,
#                             'parameters': 35147.02},
#                  'total': 20473836.13},
#  'q_conv1d_17': {'energy': {'inputs': 21818.54,
#                             'op_cost': 10132070.4,
#                             'outputs': 87274.15,
#                             'parameters': 17893.03},
#                  'total': 10171781.97},
#  'q_conv1d_18': {'energy': {'inputs': 21818.54,
#                             'op_cost': 30396211.2,
#                             'outputs': 87274.15,
#                             'parameters': 52948.75},
#                  'total': 30470978.49},
#  'q_conv1d_19': {'energy': {'inputs': 174548.31,
#                             'op_cost': 27018854.4,
#                             'outputs': 29091.38,
#                             'parameters': 46862.69},
#                  'total': 27240265.4},
#  'q_conv1d_2': {'energy': {'inputs': 29182.68,
#                            'op_cost': 4517273.6,
#                            'outputs': 116730.7,
#                            'parameters': 2069.26},
#                 'total': 4548525.54},
#  'q_conv1d_20': {'energy': {'inputs': 29091.38,
#                             'op_cost': 18012569.6,
#                             'outputs': 116365.54,
#                             'parameters': 31647.53},
#                  'total': 18073308.51},
#  'q_conv1d_21': {'energy': {'inputs': 29091.38,
#                             'op_cost': 54037708.8,
#                             'outputs': 116365.54,
#                             'parameters': 93968.82},
#                  'total': 54160769.0},
#  'q_conv1d_22': {'energy': {'inputs': 232731.08,
#                             'op_cost': 36025139.2,
#                             'outputs': 29091.38,
#                             'parameters': 62443.01},
#                  'total': 36320313.29000001},
#  'q_conv1d_23': {'energy': {'inputs': 29091.38,
#                             'op_cost': 18012569.6,
#                             'outputs': 116365.54,
#                             'parameters': 31647.53},
#                  'total': 18073308.51},
#  'q_conv1d_24': {'energy': {'inputs': 29091.38,
#                             'op_cost': 54037708.8,
#                             'outputs': 116365.54,
#                             'parameters': 93968.82},
#                  'total': 54160769.0},
#  'q_conv1d_3': {'energy': {'inputs': 29182.68,
#                            'op_cost': 13551820.8,
#                            'outputs': 116730.7,
#                            'parameters': 5964.34},
#                 'total': 13586967.82},
#  'q_conv1d_4': {'energy': {'inputs': 233461.4,
#                            'op_cost': 9034547.2,
#                            'outputs': 29182.68,
#                            'parameters': 3925.51},
#                 'total': 9271934.11},
#  'q_conv1d_5': {'energy': {'inputs': 29182.68,
#                            'op_cost': 4517273.6,
#                            'outputs': 116730.7,
#                            'parameters': 2069.26},
#                 'total': 4548525.54},
#  'q_conv1d_6': {'energy': {'inputs': 29182.68,
#                            'op_cost': 13551820.8,
#                            'outputs': 116730.7,
#                            'parameters': 5964.34},
#                 'total': 13586967.82},
#  'q_conv1d_7': {'energy': {'inputs': 116608.98,
#                            'op_cost': 9025126.4,
#                            'outputs': 29152.25,
#                            'parameters': 7851.02},
#                 'total': 9149586.4},
#  'q_conv1d_8': {'energy': {'inputs': 29152.25,
#                            'op_cost': 9025126.4,
#                            'outputs': 116608.98,
#                            'parameters': 8033.6},
#                 'total': 9062312.25},
#  'q_conv1d_9': {'energy': {'inputs': 29152.25,
#                            'op_cost': 27075379.2,
#                            'outputs': 116608.98,
#                            'parameters': 23613.93},
#                 'total': 27128145.38},
#  'q_dense': {'energy': {'inputs': 973.77,
#                         'op_cost': 9420.8,
#                         'outputs': 7.61,
#                         'parameters': 3902.69},
#              'total': 14297.259999999998}}
#
# Total energy: 477.84 uJ
