# %%
# from google.colab import drive
# drive.mount('/content/drive')
# base_dir='/content/drive/MyDrive/ucd/'
base_dir='../../folders/'

# %%
import pandas as pd
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model,load_model
from keras.layers import Conv1D, Conv2D,MaxPooling1D,MaxPooling2D, Dropout,Dense,Flatten,Activation, Flatten, BatchNormalization,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import scipy.stats as stats
from keras.callbacks import ModelCheckpoint,EarlyStopping
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\zazaz\AppData\Local\Temp\ipykernel_22084\2070769173.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install QKeras
from qkeras import *
import pprint
from qkeras.autoqkeras import *
from qkeras import *
from qkeras.qtools import run_qtools
from qkeras.qtools import settings as qtools_settings

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Positives = K.sum(K.round(K.clip(y_true, 0, 1)))

        recall = TP / (Positives+K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        Pred_Positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

        precision = TP / (Pred_Positives+K.epsilon())
        return precision
    precision, recall = precision_m(y_true, y_pred), recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
with open(base_dir+f'all/train_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_train = res['x_train']
                y_train = res['y_train']
del res
x_train=np.reshape(x_train,(len(x_train),3840,1))
print(x_train.shape)
print(y_train.shape)
# Out:
# (49797, 3840, 1)
# (49797, 4)

# %%
with open(base_dir+f'all/test_all.pkl', 'rb') as f:
                res = pickle.load(f)
                x_test = res['x_test']
                y_test = res['y_test']
del res
x_test=np.reshape(x_test,(len(x_test),3840,1))
print(x_test.shape)
print(y_test.shape)
# Out:
# (12450, 3840, 1)
# (12450, 4)

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(3840,1)))
model.add(QConv1D(64, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(2))

model.add(QConv1D(128, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(2))

model.add(QConv1D(256, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(QConv1D(256, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(2))

model.add(QConv1D(512, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(QConv1D(512, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(2))

model.add(QConv1D(512, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(QConv1D(512, 3, activation='relu', padding='same',kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(MaxPooling1D(2))

model.add(Flatten())
# Fully connected layers
model.add(QDense(4096, activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(Dropout(0.25))
model.add(QDense(4096, activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))
model.add(Dropout(0.25))
model.add(QDense(4, activation='softmax',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01),kernel_quantizer=quantized_bits(8, 1,alpha=1), bias_quantizer=quantized_bits(8, 1,alpha=1)))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 3840, 1)          4
#  ormalization)
#
#  q_conv1d (QConv1D)          (None, 3840, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 1920, 64)         0
#  )
#
#  q_conv1d_1 (QConv1D)        (None, 1920, 128)         24704
#
#  max_pooling1d_1 (MaxPooling  (None, 960, 128)         0
#  1D)
#
#  q_conv1d_2 (QConv1D)        (None, 960, 256)          98560
#
#  q_conv1d_3 (QConv1D)        (None, 960, 256)          196864
#
#  max_pooling1d_2 (MaxPooling  (None, 480, 256)         0
#  1D)
#
#  q_conv1d_4 (QConv1D)        (None, 480, 512)          393728
#
#  q_conv1d_5 (QConv1D)        (None, 480, 512)          786944
#
#  max_pooling1d_3 (MaxPooling  (None, 240, 512)         0
#  1D)
#
#  q_conv1d_6 (QConv1D)        (None, 240, 512)          786944
#
#  q_conv1d_7 (QConv1D)        (None, 240, 512)          786944
#
#  max_pooling1d_4 (MaxPooling  (None, 120, 512)         0
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 3840, 1)          4
#  ormalization)
#
#  q_conv1d (QConv1D)          (None, 3840, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 1920, 64)         0
#  )
#
#  q_conv1d_1 (QConv1D)        (None, 1920, 128)         24704
#
#  max_pooling1d_1 (MaxPooling  (None, 960, 128)         0
#  1D)
#
#  q_conv1d_2 (QConv1D)        (None, 960, 256)          98560
#
#  q_conv1d_3 (QConv1D)        (None, 960, 256)          196864
#
#  max_pooling1d_2 (MaxPooling  (None, 480, 256)         0
#  1D)
#
#  q_conv1d_4 (QConv1D)        (None, 480, 512)          393728
#
#  q_conv1d_5 (QConv1D)        (None, 480, 512)          786944
#
#  max_pooling1d_3 (MaxPooling  (None, 240, 512)         0
#  1D)
#
#  q_conv1d_6 (QConv1D)        (None, 240, 512)          786944
#
#  q_conv1d_7 (QConv1D)        (None, 240, 512)          786944
#
#  max_pooling1d_4 (MaxPooling  (None, 120, 512)         0
#  1D)
#
#  flatten (Flatten)           (None, 61440)             0
#
#  q_dense (QDense)            (None, 4096)              251662336
#
#  dropout (Dropout)           (None, 4096)              0
#
#  q_dense_1 (QDense)          (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  q_dense_2 (QDense)          (None, 4)                 16388
#
# =================================================================
# Total params: 271,534,984
# Trainable params: 271,534,982
# Non-trainable params: 2
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(base_dir+"models/vgg11_fp8.keras")
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy',f1])
history=model.fit(x_train,y_train,batch_size=256,epochs=50,callbacks=[checkpoint], validation_split=0.10)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 94s 487ms/step - loss: 107.6003 - accuracy: 0.4907 - f1: 0.2780 - val_loss: 40.2809 - val_accuracy: 0.5058 - val_f1: 0.3594
# Epoch 2/50
# 176/176 [==============================] - 85s 481ms/step - loss: 29.7774 - accuracy: 0.5146 - f1: 0.3247 - val_loss: 22.3855 - val_accuracy: 0.5251 - val_f1: 0.3729
# Epoch 3/50
# 176/176 [==============================] - 85s 483ms/step - loss: 18.3945 - accuracy: 0.5324 - f1: 0.3910 - val_loss: 15.1724 - val_accuracy: 0.5317 - val_f1: 0.4602
# Epoch 4/50
# 176/176 [==============================] - 84s 478ms/step - loss: 13.0686 - accuracy: 0.5473 - f1: 0.4512 - val_loss: 11.2708 - val_accuracy: 0.5390 - val_f1: 0.5127
# Epoch 5/50
# 176/176 [==============================] - 86s 486ms/step - loss: 9.9382 - accuracy: 0.5632 - f1: 0.4852 - val_loss: 8.7477 - val_accuracy: 0.5731 - val_f1: 0.5692
# Epoch 6/50
# 176/176 [==============================] - 85s 481ms/step - loss: 7.8371 - accuracy: 0.5803 - f1: 0.5073 - val_loss: 7.1275 - val_accuracy: 0.4528 - val_f1: 0.3377
# Epoch 7/50
# 176/176 [==============================] - 85s 479ms/step - loss: 6.2947 - accuracy: 0.6135 - f1: 0.5584 - val_loss: 5.6197 - val_accuracy: 0.6380 - val_f1: 0.6203
# Epoch 8/50
# 176/176 [==============================] - 86s 485ms/step - loss: 5.0886 - accuracy: 0.6532 - f1: 0.6210 - val_loss: 4.7818 - val_accuracy: 0.5685 - val_f1: 0.5356
# Epoch 9/50
# 176/176 [==============================] - 85s 485ms/step - loss: 4.1730 - accuracy: 0.6684 - f1: 0.6420 - val_loss: 3.8137 - val_accuracy: 0.6562 - val_f1: 0.6394
# Epoch 10/50
# 176/176 [==============================] - 87s 491ms/step - loss: 3.4229 - accuracy: 0.6874 - f1: 0.6676 - val_loss: 3.0928 - val_accuracy: 0.7046 - val_f1: 0.6914
# Epoch 11/50
# 176/176 [==============================] - 85s 482ms/step - loss: 2.8258 - accuracy: 0.7037 - f1: 0.6872 - val_loss: 2.5333 - val_accuracy: 0.7241 - val_f1: 0.7110
# Epoch 12/50
# 176/176 [==============================] - 87s 491ms/step - loss: 2.3418 - accuracy: 0.7214 - f1: 0.7083 - val_loss: 2.1575 - val_accuracy: 0.7229 - val_f1: 0.7107
# Epoch 13/50
# 176/176 [==============================] - 87s 490ms/step - loss: 1.9569 - accuracy: 0.7349 - f1: 0.7259 - val_loss: 1.8585 - val_accuracy: 0.7076 - val_f1: 0.6965
# Epoch 14/50
# 176/176 [==============================] - 86s 489ms/step - loss: 1.6360 - accuracy: 0.7494 - f1: 0.7409 - val_loss: 1.6873 - val_accuracy: 0.6922 - val_f1: 0.6769
# Epoch 15/50
# 176/176 [==============================] - 86s 486ms/step - loss: 1.4179 - accuracy: 0.7485 - f1: 0.7395 - val_loss: 1.3003 - val_accuracy: 0.7528 - val_f1: 0.7508
# Epoch 16/50
# 176/176 [==============================] - 86s 488ms/step - loss: 1.1951 - accuracy: 0.7693 - f1: 0.7626 - val_loss: 1.1618 - val_accuracy: 0.7578 - val_f1: 0.7550
# Epoch 17/50
# 176/176 [==============================] - 86s 491ms/step - loss: 1.0490 - accuracy: 0.7753 - f1: 0.7695 - val_loss: 1.1058 - val_accuracy: 0.7438 - val_f1: 0.7448
# Epoch 18/50
# 176/176 [==============================] - 86s 490ms/step - loss: 0.9454 - accuracy: 0.7758 - f1: 0.7700 - val_loss: 0.9111 - val_accuracy: 0.7765 - val_f1: 0.7709
# Epoch 19/50
# 176/176 [==============================] - 86s 486ms/step - loss: 0.8315 - accuracy: 0.7922 - f1: 0.7860 - val_loss: 0.8057 - val_accuracy: 0.7867 - val_f1: 0.7846
# Epoch 20/50
# 176/176 [==============================] - 86s 487ms/step - loss: 0.7485 - accuracy: 0.8016 - f1: 0.7977 - val_loss: 0.8508 - val_accuracy: 0.7534 - val_f1: 0.7542
# Epoch 21/50
# 176/176 [==============================] - 84s 474ms/step - loss: 0.7011 - accuracy: 0.8056 - f1: 0.8016 - val_loss: 0.9445 - val_accuracy: 0.6900 - val_f1: 0.6832
# Epoch 22/50
# 176/176 [==============================] - 84s 474ms/step - loss: 0.6633 - accuracy: 0.8103 - f1: 0.8060 - val_loss: 0.7526 - val_accuracy: 0.7695 - val_f1: 0.7663
# Epoch 23/50
# 176/176 [==============================] - 83s 470ms/step - loss: 0.6341 - accuracy: 0.8144 - f1: 0.8121 - val_loss: 0.6959 - val_accuracy: 0.7876 - val_f1: 0.7884
# Epoch 24/50
# 176/176 [==============================] - 83s 470ms/step - loss: 0.5720 - accuracy: 0.8340 - f1: 0.8321 - val_loss: 0.7453 - val_accuracy: 0.7540 - val_f1: 0.7545
# Epoch 25/50
# 176/176 [==============================] - 83s 471ms/step - loss: 0.5598 - accuracy: 0.8353 - f1: 0.8329 - val_loss: 0.7273 - val_accuracy: 0.7725 - val_f1: 0.7715
# Epoch 26/50
# 176/176 [==============================] - 83s 472ms/step - loss: 0.5569 - accuracy: 0.8384 - f1: 0.8358 - val_loss: 0.6057 - val_accuracy: 0.8183 - val_f1: 0.8184
# Epoch 27/50
# 176/176 [==============================] - 83s 471ms/step - loss: 0.5227 - accuracy: 0.8485 - f1: 0.8463 - val_loss: 1.0507 - val_accuracy: 0.7070 - val_f1: 0.7071
# Epoch 28/50
# 176/176 [==============================] - 83s 470ms/step - loss: 0.5266 - accuracy: 0.8472 - f1: 0.8456 - val_loss: 0.6509 - val_accuracy: 0.8006 - val_f1: 0.7997
# Epoch 29/50
# 176/176 [==============================] - 83s 471ms/step - loss: 0.4905 - accuracy: 0.8621 - f1: 0.8615 - val_loss: 0.6218 - val_accuracy: 0.8243 - val_f1: 0.8251
# Epoch 30/50
# 176/176 [==============================] - 82s 469ms/step - loss: 0.4750 - accuracy: 0.8678 - f1: 0.8673 - val_loss: 0.6710 - val_accuracy: 0.8066 - val_f1: 0.8075
# Epoch 31/50
# 176/176 [==============================] - 82s 468ms/step - loss: 0.4580 - accuracy: 0.8775 - f1: 0.8768 - val_loss: 0.5969 - val_accuracy: 0.8243 - val_f1: 0.8265
# Epoch 32/50
# 176/176 [==============================] - 82s 465ms/step - loss: 0.4399 - accuracy: 0.8821 - f1: 0.8816 - val_loss: 0.5946 - val_accuracy: 0.8299 - val_f1: 0.8310
# Epoch 33/50
# 176/176 [==============================] - 82s 462ms/step - loss: 0.4298 - accuracy: 0.8900 - f1: 0.8894 - val_loss: 0.6213 - val_accuracy: 0.8185 - val_f1: 0.8207
# Epoch 34/50
# 176/176 [==============================] - 82s 462ms/step - loss: 0.4112 - accuracy: 0.8950 - f1: 0.8947 - val_loss: 0.5196 - val_accuracy: 0.8530 - val_f1: 0.8534
# Epoch 35/50
# 176/176 [==============================] - 82s 462ms/step - loss: 0.3758 - accuracy: 0.9051 - f1: 0.9055 - val_loss: 0.5245 - val_accuracy: 0.8530 - val_f1: 0.8524
# Epoch 36/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.3668 - accuracy: 0.9089 - f1: 0.9097 - val_loss: 0.5553 - val_accuracy: 0.8442 - val_f1: 0.8442
# Epoch 37/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.3592 - accuracy: 0.9147 - f1: 0.9151 - val_loss: 0.5598 - val_accuracy: 0.8502 - val_f1: 0.8498
# Epoch 38/50
# 176/176 [==============================] - 82s 462ms/step - loss: 0.3548 - accuracy: 0.9143 - f1: 0.9144 - val_loss: 0.6817 - val_accuracy: 0.8271 - val_f1: 0.8285
# Epoch 39/50
# 176/176 [==============================] - 82s 462ms/step - loss: 0.3717 - accuracy: 0.9129 - f1: 0.9125 - val_loss: 0.5835 - val_accuracy: 0.8472 - val_f1: 0.8475
# Epoch 40/50
# 176/176 [==============================] - 82s 462ms/step - loss: 0.3414 - accuracy: 0.9237 - f1: 0.9239 - val_loss: 0.5354 - val_accuracy: 0.8608 - val_f1: 0.8613
# Epoch 41/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.3214 - accuracy: 0.9251 - f1: 0.9250 - val_loss: 0.4956 - val_accuracy: 0.8701 - val_f1: 0.8714
# Epoch 42/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.3253 - accuracy: 0.9273 - f1: 0.9270 - val_loss: 0.5895 - val_accuracy: 0.8440 - val_f1: 0.8452
# Epoch 43/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.3387 - accuracy: 0.9210 - f1: 0.9209 - val_loss: 0.5339 - val_accuracy: 0.8576 - val_f1: 0.8576
# Epoch 44/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.2758 - accuracy: 0.9413 - f1: 0.9410 - val_loss: 0.4965 - val_accuracy: 0.8767 - val_f1: 0.8770
# Epoch 45/50
# 176/176 [==============================] - 81s 461ms/step - loss: 0.2616 - accuracy: 0.9459 - f1: 0.9460 - val_loss: 0.6688 - val_accuracy: 0.8307 - val_f1: 0.8323
# Epoch 46/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.2810 - accuracy: 0.9395 - f1: 0.9396 - val_loss: 0.5321 - val_accuracy: 0.8558 - val_f1: 0.8569
# Epoch 47/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.2646 - accuracy: 0.9443 - f1: 0.9444 - val_loss: 0.5765 - val_accuracy: 0.8600 - val_f1: 0.8590
# Epoch 48/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.2683 - accuracy: 0.9481 - f1: 0.9482 - val_loss: 0.5238 - val_accuracy: 0.8769 - val_f1: 0.8791
# Epoch 49/50
# 176/176 [==============================] - 81s 462ms/step - loss: 0.2393 - accuracy: 0.9540 - f1: 0.9535 - val_loss: 0.4739 - val_accuracy: 0.8837 - val_f1: 0.8836
# Epoch 50/50
# 176/176 [==============================] - 81s 461ms/step - loss: 0.2544 - accuracy: 0.9486 - f1: 0.9489 - val_loss: 0.5013 - val_accuracy: 0.8743 - val_f1: 0.8756

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# Plot F1
plt.subplot(1, 3, 3)
plt.plot(history.history['f1'], label='Training f1')
plt.plot(history.history['val_f1'], label='Validation f1')
plt.title('Training and Validation f1')
plt.xlabel('Epoch')
plt.ylabel('f1')
plt.legend()

plt.tight_layout()
plt.show()

# %%
del x_train
del y_train

# %%
# model=load_model(base_dir+"models/vgg11_fp8.keras",custom_objects={'f1':f1})
# model.summary()

# %%
y_pred=model.predict(x_test,batch_size=256)
y_pred = to_categorical(np.argmax(y_pred, axis=1), 4).astype(int)
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)
# Out:
# 49/49 [==============================] - 9s 183ms/step

# %%
print(classification_report(y_test,y_pred,target_names=['WAKE','REM','LIGHT','DEEP']))
# Out:
#               precision    recall  f1-score   support
#
#         WAKE       0.91      0.80      0.85      2810
#          REM       0.87      0.89      0.88      1809
#        LIGHT       0.89      0.88      0.88      6233
#         DEEP       0.76      0.94      0.84      1598
#
#     accuracy                           0.87     12450
#    macro avg       0.86      0.88      0.86     12450
# weighted avg       0.87      0.87      0.87     12450

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['WAKE','REM','LIGHT','DEEP'])
disp.plot()
plt.show()

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=False,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From c:\Users\zazaz\anaconda3\envs\tf\lib\site-packages\qkeras\qtools\qgraph.py:189: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "batch_normalization": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 [
#                     null,
#                     3840,
#                     1
#                 ]
#             ]
#         }
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 1,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 3840,
#                 64
#             ]
#         },
#         "operation_count": 737280
#     },
#     "max_pooling1d": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 64,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 128
#             ]
#         },
#         "operation_count": 47185920
#     },
#     "max_pooling1d_1": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 128,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 256
#             ]
#         },
#         "operation_count": 94371840
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 256,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 256
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "max_pooling1d_2": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 256,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 512
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 512,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 512
#             ]
#         },
#         "operation_count": 377487360
#     },
#     "max_pooling1d_3": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_6": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 512,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "q_conv1d_7": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 3,
#                 512,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "max_pooling1d_4": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 512
#             ]
#         },
#         "operation_count": 122880
#     },
#     "flatten": {
#         "layer_type": "Flatten",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 61440
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 61440,
#                 4096
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4096
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4096
#             ]
#         },
#         "operation_count": 251658240
#     },
#     "q_dense_1": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 4096,
#                 4096
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4096
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4096
#             ]
#         },
#         "operation_count": 16777216
#     },
#     "q_dense_2": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": [
#                 4096,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "quantized_bits",
#             "bits": 8,
#             "int_bits": 2,
#             "is_signed": true,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 16384
#     }
# }
# {'batch_normalization': {'energy': {'inputs': 7303.28,
#                                     'op_cost': 28416.0,
#                                     'outputs': 3.8,
#                                     'parameters': 15.22},
#                          'total': 15.22},
#  'flatten': {'energy': {'inputs': 116852.42,
#                         'op_cost': 0.0,
#                         'outputs': 116852.42,
#                         'parameters': 0.0},
#              'total': 116852.42},
#  'max_pooling1d': {'energy': {'inputs': 467409.69,
#                               'op_cost': 0.0,
#                               'outputs': 233704.85,
#                               'parameters': 0.0},
#                    'total': 467409.69},
#  'max_pooling1d_1': {'energy': {'inputs': 467409.69,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 467409.69},
#  'max_pooling1d_2': {'energy': {'inputs': 467409.69,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 467409.69},
#  'max_pooling1d_3': {'energy': {'inputs': 467409.69,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 467409.69},
#  'max_pooling1d_4': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 116852.42,
#                                 'parameters': 0.0},
#                      'total': 233704.85},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 3391488.0,
#                          'outputs': 467409.69,
#                          'parameters': 121.72},
#               'total': 3398913.0},
#  'q_conv1d_1': {'energy': {'inputs': 233704.85,
#                            'op_cost': 217055232.0,
#                            'outputs': 467409.69,
#                            'parameters': 11746.1},
#                 'total': 217300682.95},
#  'q_conv1d_2': {'energy': {'inputs': 233704.85,
#                            'op_cost': 434110464.0,
#                            'outputs': 467409.69,
#                            'parameters': 46862.69},
#                 'total': 434391031.54},
#  'q_conv1d_3': {'energy': {'inputs': 467409.69,
#                            'op_cost': 868220928.0,
#                            'outputs': 467409.69,
#                            'parameters': 93603.66},
#                 'total': 868781941.35},
#  'q_conv1d_4': {'energy': {'inputs': 233704.85,
#                            'op_cost': 868220928.0,
#                            'outputs': 467409.69,
#                            'parameters': 187207.32},
#                 'total': 868641840.17},
#  'q_conv1d_5': {'energy': {'inputs': 467409.69,
#                            'op_cost': 1736441856.0,
#                            'outputs': 467409.69,
#                            'parameters': 374171.2},
#                 'total': 1737283436.89},
#  'q_conv1d_6': {'energy': {'inputs': 233704.85,
#                            'op_cost': 868220928.0,
#                            'outputs': 233704.85,
#                            'parameters': 374171.2},
#                 'total': 868828804.05},
#  'q_conv1d_7': {'energy': {'inputs': 233704.85,
#                            'op_cost': 868220928.0,
#                            'outputs': 233704.85,
#                            'parameters': 374171.2},
#                 'total': 868828804.05},
#  'q_dense': {'energy': {'inputs': 116852.42,
#                         'op_cost': 1157627904.0,
#                         'outputs': 7790.16,
#                         'parameters': 233347606.58},
#              'total': 1391092363.0},
#  'q_dense_1': {'energy': {'inputs': 7790.16,
#                           'op_cost': 77175193.6,
#                           'outputs': 7790.16,
#                           'parameters': 7979072.97},
#                'total': 85162056.72999999},
#  'q_dense_2': {'energy': {'inputs': 7790.16,
#                           'op_cost': 75366.4,
#                           'outputs': 7.61,
#                           'parameters': 7793.97},
#                'total': 90950.53}}
#
# Total energy: 7346.02 uJ

# %%
q = run_qtools.QTools(
    model,
    # energy calculation using a given process
    # "horowitz" refers to 45nm process published at
    # M. Horowitz, "1.1 Computing's energy problem (and what we can do about
    # it), "2014 IEEE International Solid-State Circuits Conference Digest of
    # Technical Papers (ISSCC), San Francisco, CA, 2014, pp. 10-14, 
    # doi: 10.1109/ISSCC.2014.6757323.
    
    process="horowitz",
    # quantizers for model input
    source_quantizers=["fp32"],
    
    is_inference=True,
    # whether model has been trained already, which is
    # needed to compute tighter bounds for QBatchNormalization Power estimation.
    
    # weights_path=None,
    # absolute path (including filename) of the model weights
    
    
    keras_quantizer="fp32",
    # keras_quantizer to quantize weight/bias in un-quantized keras layers
    
    keras_accumulator="fp32",
    # keras_quantizer to quantize MAC in un-quantized keras layers
    
    for_reference=True,
    # whether calculate baseline energy
)
q.qtools_stats_print()

# caculate energy of the derived data type map.
energy_dict = q.pe(
    # whether to store parameters in dram, sram, or fixed
    weights_on_memory="sram",
    # store activations in dram or sram
    activations_on_memory="sram",
    # minimum sram size in number of bits
    min_sram_size=8*16*1024*1024,
    # whether load data from dram to sram (consider sram as a cache
    # for dram. If false, we will assume data will be already in SRAM
    rd_wr_on_io=False)

# get stats of energy distribution in each layer
energy_profile = q.extract_energy_profile(qtools_settings.cfg.include_energy, energy_dict)
# extract sum of energy of each layer according to the rule specified in
# qtools_settings.cfg.include_energy
total_energy = q.extract_energy_sum(qtools_settings.cfg.include_energy, energy_dict)

pprint.pprint(energy_profile)
print()

print("Total energy: {:.2f} uJ".format(total_energy / 1000000.0))
# Out:
# {
#     "source_quantizers": [
#         {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         }
#     ],
#     "batch_normalization": {
#         "layer_type": "BatchNormalization",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "gamma_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "beta_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "mean_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "variance_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32
#         },
#         "internal_divide_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "internal_accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 [
#                     null,
#                     3840,
#                     1
#                 ]
#             ]
#         }
#     },
#     "q_conv1d": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 1,
#                 64
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 64
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 3840,
#                 64
#             ]
#         },
#         "operation_count": 737280
#     },
#     "max_pooling1d": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 64
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_1": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 64,
#                 128
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 128
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 1920,
#                 128
#             ]
#         },
#         "operation_count": 47185920
#     },
#     "max_pooling1d_1": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 128
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_2": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 128,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 256
#             ]
#         },
#         "operation_count": 94371840
#     },
#     "q_conv1d_3": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 256,
#                 256
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 256
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 960,
#                 256
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "max_pooling1d_2": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 256
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_4": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 256,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 512
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "q_conv1d_5": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 512,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 480,
#                 512
#             ]
#         },
#         "operation_count": 377487360
#     },
#     "max_pooling1d_3": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 245760
#     },
#     "q_conv1d_6": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 512,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "q_conv1d_7": {
#         "layer_type": "QConv1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 3,
#                 512,
#                 512
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 512
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 240,
#                 512
#             ]
#         },
#         "operation_count": 188743680
#     },
#     "max_pooling1d_4": {
#         "layer_type": "MaxPooling1D",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 120,
#                 512
#             ]
#         },
#         "operation_count": 122880
#     },
#     "flatten": {
#         "layer_type": "Flatten",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 61440
#             ]
#         },
#         "operation_count": 61440
#     },
#     "q_dense": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 61440,
#                 4096
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4096
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4096
#             ]
#         },
#         "operation_count": 251658240
#     },
#     "q_dense_1": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 4096,
#                 4096
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4096
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4096
#             ]
#         },
#         "operation_count": 16777216
#     },
#     "q_dense_2": {
#         "layer_type": "QDense",
#         "input_quantizer_list": [
#             {
#                 "quantizer_type": "floating_point",
#                 "bits": 32
#             }
#         ],
#         "weight_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 4096,
#                 4
#             ]
#         },
#         "bias_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": 4
#         },
#         "multiplier": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "mul"
#         },
#         "accumulator": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "op_type": "add"
#         },
#         "output_quantizer": {
#             "quantizer_type": "floating_point",
#             "bits": 32,
#             "shape": [
#                 -1,
#                 4
#             ]
#         },
#         "operation_count": 16384
#     }
# }
# {'batch_normalization': {'energy': {'inputs': 7303.28,
#                                     'op_cost': 28416.0,
#                                     'outputs': 3.8,
#                                     'parameters': 15.22},
#                          'total': 15.22},
#  'flatten': {'energy': {'inputs': 116852.42,
#                         'op_cost': 0.0,
#                         'outputs': 116852.42,
#                         'parameters': 0.0},
#              'total': 116852.42},
#  'max_pooling1d': {'energy': {'inputs': 467409.69,
#                               'op_cost': 0.0,
#                               'outputs': 233704.85,
#                               'parameters': 0.0},
#                    'total': 467409.69},
#  'max_pooling1d_1': {'energy': {'inputs': 467409.69,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 467409.69},
#  'max_pooling1d_2': {'energy': {'inputs': 467409.69,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 467409.69},
#  'max_pooling1d_3': {'energy': {'inputs': 467409.69,
#                                 'op_cost': 0.0,
#                                 'outputs': 233704.85,
#                                 'parameters': 0.0},
#                      'total': 467409.69},
#  'max_pooling1d_4': {'energy': {'inputs': 233704.85,
#                                 'op_cost': 0.0,
#                                 'outputs': 116852.42,
#                                 'parameters': 0.0},
#                      'total': 233704.85},
#  'q_conv1d': {'energy': {'inputs': 7303.28,
#                          'op_cost': 3391488.0,
#                          'outputs': 467409.69,
#                          'parameters': 486.89},
#               'total': 3399278.17},
#  'q_conv1d_1': {'energy': {'inputs': 233704.85,
#                            'op_cost': 217055232.0,
#                            'outputs': 467409.69,
#                            'parameters': 46984.41},
#                 'total': 217335921.26},
#  'q_conv1d_2': {'energy': {'inputs': 233704.85,
#                            'op_cost': 434110464.0,
#                            'outputs': 467409.69,
#                            'parameters': 187450.76},
#                 'total': 434531619.61},
#  'q_conv1d_3': {'energy': {'inputs': 467409.69,
#                            'op_cost': 868220928.0,
#                            'outputs': 467409.69,
#                            'parameters': 374414.64},
#                 'total': 869062752.33},
#  'q_conv1d_4': {'energy': {'inputs': 233704.85,
#                            'op_cost': 868220928.0,
#                            'outputs': 467409.69,
#                            'parameters': 748829.28},
#                 'total': 869203462.13},
#  'q_conv1d_5': {'energy': {'inputs': 467409.69,
#                            'op_cost': 1736441856.0,
#                            'outputs': 467409.69,
#                            'parameters': 1496684.79},
#                 'total': 1738405950.48},
#  'q_conv1d_6': {'energy': {'inputs': 233704.85,
#                            'op_cost': 868220928.0,
#                            'outputs': 233704.85,
#                            'parameters': 1496684.79},
#                 'total': 869951317.64},
#  'q_conv1d_7': {'energy': {'inputs': 233704.85,
#                            'op_cost': 868220928.0,
#                            'outputs': 233704.85,
#                            'parameters': 1496684.79},
#                 'total': 869951317.64},
#  'q_dense': {'energy': {'inputs': 116852.42,
#                         'op_cost': 1157627904.0,
#                         'outputs': 7790.16,
#                         'parameters': -31900711.54},
#              'total': 1125844044.88},
#  'q_dense_1': {'energy': {'inputs': 7790.16,
#                           'op_cost': 77175193.6,
#                           'outputs': 7790.16,
#                           'parameters': 45787094.87},
#                'total': 122970078.63},
#  'q_dense_2': {'energy': {'inputs': 7790.16,
#                           'op_cost': 75366.4,
#                           'outputs': 7.61,
#                           'parameters': 31168.25},
#                'total': 114324.81}}
#
# Total energy: 7122.99 uJ
